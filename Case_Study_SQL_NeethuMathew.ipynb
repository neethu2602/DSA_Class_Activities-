# %% [markdown]
# <a href="https://colab.research.google.com/github/neethu2602/DSA_Class_Activities-/blob/main/Case_Study_SQL_NeethuMathew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study on SQL

# %%
import sqlite3
import pandas as pd

# %%
def load_imdb_database(db_path):
    try:
        conn = sqlite3.connect(db_path)
        print("IMDB database loaded successfully.")
        return conn
    except sqlite3.Error as e:
        print(f"Error loading IMDB database: {e}")
        return None

# %%
db_path = "/content/imdb (1).db"
conn = load_imdb_database(db_path)

if conn:
    print("Connection successful")
    cursor = conn.cursor()
# Out:
# IMDB database loaded successfully.
# Connection successful

# %%
# Out:
# File exists? True

# %% [markdown]
# ## Following is the schema of the IMDB database. It lists all tables and their schemas.

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Database Schema:")
for table in tables:
    table_name = table[0]
    print(f"\nTable: {table_name}")

    cursor.execute(f"PRAGMA table_info({table_name});")
    schema = cursor.fetchall()

    print("Columns:")
    for column in schema:
        cid, name, dtype, notnull, dflt_value, pk = column
        print(f"  - {name} ({dtype}), NOT NULL: {bool(notnull)}, Default: {dflt_value}, Primary Key: {bool(pk)}")
# Out:
# Database Schema:
#
# Table: Movie
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - title (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - year (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - rating (REAL), NOT NULL: False, Default: None, Primary Key: False
#   - num_votes (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: Genre
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - Name (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - GID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: Language
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - Name (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - LAID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: Country
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - Name (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - CID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: Location
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - Name (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - LID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Location
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - LID (REAL), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Country
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - CID (REAL), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Language
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - LAID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Genre
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - GID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: Person
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - PID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - Name (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - Gender (TEXT), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Producer
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - PID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Director
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - PID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#
# Table: M_Cast
# Columns:
#   - index (INTEGER), NOT NULL: False, Default: None, Primary Key: False
#   - MID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - PID (TEXT), NOT NULL: False, Default: None, Primary Key: False
#   - ID (INTEGER), NOT NULL: False, Default: None, Primary Key: False

# %% [markdown]
# # Write SQL queries for the following questions

# %% [markdown]
# ## 1. Write query to list first 5 rows of Person table

# %%
q1 = 'SELECT * FROM Person LIMIT 5'
cursor.execute(q1)

res1=cursor.fetchall()
for i in res1:
  print(i)
# Out:
# (0, 'nm0000288', ' Christian Bale', 'Male')
# (1, 'nm0000949', ' Cate Blanchett', 'Female')
# (2, 'nm1212722', ' Benedict Cumberbatch', 'Male')
# (3, 'nm0365140', ' Naomie Harris', 'Female')
# (4, 'nm0785227', ' Andy Serkis', 'Male')

# %%
def q1_grader(q1):
  result = pd.read_sql_query(q1, conn)
  return result.shape == (5, 4)
print(q1_grader(q1))
# Out:
# True

# %% [markdown]
# ## 2. Write query to select title, year and rating from Movie table

# %%
q2 = "select title,year,rating from Movie"
cursor.execute(q2)
rows= cursor.fetchall()
for row in rows:
  print(row)
# Out:
# ('Mowgli', '2018', 6.6)
# ("Ocean's Eight", '2018', 6.2)
# ('Tomb Raider', '2018', 6.4)
# ('The Avengers', '2012', 8.1)
# ('Tumbbad', '2018', 8.5)
# ('Kedarnath', '2018', 5.5)
# ('Captain America: Civil War', '2016', 7.8)
# ('Andhadhun', '2018', 9.0)
# ('Lion', '2016', 8.1)
# ('Rajma Chawal', '2018', 5.7)
# ('Geostorm', '2017', 5.3)
# ('Slumdog Millionaire', '2008', 8.0)
# ('2012', 'I 2009', 5.8)
# ('Mastizaade', '2016', 2.4)
# ('Close Encounters of the Third Kind', '1977', 7.7)
# ('Manto', '2018', 7.5)
# ('Life of Pi', '2012', 7.9)
# ('A Good Day to Die Hard', '2013', 5.3)
# ('Pixels', '2015', 5.6)
# ('Stree', '2018', 8.0)
# ('Thugs of Hindostan', '2018', 3.6)
# ('Badhaai Ho', '2018', 8.2)
# ('Hotel Mumbai', '2018', 7.1)
# ('The Darjeeling Limited', '2007', 7.2)
# ('Jalebi', '2018', 5.9)
# ('Bend It Like Beckham', '2002', 6.7)
# ('Dangal', '2016', 8.5)
# ('Manmarziyaan', '2018', 7.0)
# ('The Day the Earth Stood Still', '1951', 7.8)
# ('Dragonball Evolution', '2009', 2.6)
# ('Pataakha', '2018', 7.3)
# ('I Origins', '2014', 7.4)
# ('Harold & Kumar Go to White Castle', '2004', 7.1)
# ('3 Idiots', '2009', 8.4)
# ('Taare Zameen Par', '2007', 8.4)
# ('Bajirao Mastani', '2015', 7.2)
# ('PK', '2014', 8.2)
# ('The Hundred-Foot Journey', '2014', 7.3)
# ('Gangs of Wasseypur', '2012', 8.2)
# ('Seven Years in Tibet', '1997', 7.0)
# ('Octopussy', '1983', 6.6)
# ('Chung Hing sam lam', '1994', 8.1)
# ('Sanju', '2018', 8.1)
# ('Victoria & Abdul', '2017', 6.8)
# ('Karwaan', '2018', 7.6)
# ('Mitron', '2018', 7.1)
# ('Padman', '2018', 8.1)
# ('Tigers', '2014', 7.4)
# ('Ghajini', '2008', 7.3)
# ('The Best Exotic Marigold Hotel', '2011', 7.3)
# ('Around the World in 80 Days', '2004', 5.9)
# ('The Ghost and the Darkness', '1996', 6.8)
# ('Padmaavat', '2018', 7.0)
# ('Raazi', '2018', 7.8)
# ('Bareilly Ki Barfi', '2017', 7.5)
# ('Lagaan: Once Upon a Time in India', '2001', 8.1)
# ('Lust Stories', '2018', 6.6)
# ('My Name Is Khan', '2010', 8.0)
# ('Love Sonia', '2018', 7.2)
# ('Batti Gul Meter Chalu', '2018', 6.0)
# ('Loveyatri', '2018', 2.9)
# ('Don 2', '2011', 7.1)
# ('Rang De Basanti', '2006', 8.2)
# ('Love Per Square Foot', '2018', 7.2)
# ('Ugly', '2013', 8.1)
# ('Bahubali: The Beginning', '2015', 8.2)
# ('Anand', '1971', 8.8)
# ('Baahubali 2: The Conclusion', '2017', 8.3)
# ('Sui Dhaaga: Made in India', '2018', 6.8)
# ('FryDay', '2018', 5.9)
# ('Se, jie', '2007', 7.6)
# ('Gold', 'I 2018', 7.6)
# ('Bhavesh Joshi Superhero', '2018', 7.6)
# ('Sonu Ke Titu Ki Sweety', '2018', 7.2)
# ('Satyameva Jayate', '2018', 5.8)
# ('Race 3', '2018', 2.1)
# ('The Accidental Husband', '2008', 5.6)
# ('Million Dollar Arm', '2014', 7.0)
# ('Nasha', '2013', 3.3)
# ('Dabba', '2013', 7.8)
# ('Vikram Vedha', '2017', 8.8)
# ('Trapped', 'XVII 2016', 7.6)
# ('Parmanu: The Story of Pokhran', '2018', 7.8)
# ('Barfi!', '2012', 8.1)
# ('Auntie Mame', '1958', 8.0)
# ('Beyond the Clouds', '2017', 7.0)
# ('Tamasha', '2015', 7.2)
# ('Mukkabaaz', '2017', 8.1)
# ('Bride & Prejudice', '2004', 6.2)
# ('Dhadak', '2018', 4.4)
# ('Mom', 'I 2017', 7.3)
# ('A Passage to India', '1984', 7.4)
# ('Happy Phirr Bhag Jayegi', '2018', 4.6)
# ('Kabhi Khushi Kabhie Gham...', '2001', 7.5)
# ('Masaan', '2015', 8.1)
# ("Viceroy's House", '2017', 6.7)
# ('Laila Majnu', '2018', 7.8)
# ('Gurgaon', '2017', 6.7)
# ('Dear Zindagi', '2016', 7.7)
# ('Newton', '2017', 7.7)
# ('Aiyaary', '2018', 5.2)
# ('Nayakan', '1987', 8.8)
# ('Baazaar', '2018', 6.9)
# ('Raid', '2018', 7.4)
# ('Dil Dhadakne Do', '2015', 6.8)
# ('October', 'II 2018', 7.6)
# ('Talvar', '2015', 8.2)
# ('Shahid', '2012', 8.3)
# ('Raees', '2017', 6.9)
# ('Kahaani', '2012', 8.2)
# ('One Less God', '2017', 5.8)
# ('Gunday', '2014', 2.1)
# ('Beavis and Butt-Head Do America', '1996', 6.8)
# ('Bajrangi Bhaijaan', '2015', 8.0)
# ('Parched', '2015', 7.6)
# ('Jagga Jasoos', '2017', 6.4)
# ('Agneepath', '2012', 7.0)
# ('Mary Kom', '2014', 6.8)
# ('Udta Punjab', '2016', 7.8)
# ('Shaadi Mein Zaroor Aana', '2017', 7.8)
# ('Street Fighter: The Legend of Chun-Li', '2009', 3.7)
# ('Black', '2005', 8.2)
# ('Soorma', '2018', 7.5)
# ('Raman Raghav 2.0', '2016', 7.3)
# ('Krrish', '2006', 6.4)
# ('Airlift', '2016', 8.1)
# ('Devdas', 'I 2002', 7.6)
# ('Ittefaq', '2017', 7.2)
# ('Ae Dil Hai Mushkil', '2016', 5.8)
# ('Blackmail', 'I 2018', 7.0)
# ('Pink', 'III 2016', 8.2)
# ('Go Goa Gone', '2013', 6.6)
# ('Drishyam', '2015', 8.3)
# ('Dostana', '2008', 6.5)
# ('Anbe Sivam', '2003', 8.8)
# ('Veere Di Wedding', '2018', 3.1)
# ('Dil Juunglee', '2018', 4.5)
# ('Dhoom:3', '2013', 5.4)
# ('Secret Superstar', '2017', 8.0)
# ('A Wednesday', '2008', 8.2)
# ('Goliyon Ki Rasleela Ram-Leela', '2013', 6.4)
# ('B.A. Pass', '2012', 6.5)
# ('Sultan', '2016', 7.1)
# ('Toilet - Ek Prem Katha', '2017', 7.3)
# ('Garbage', 'I 2018', 4.2)
# ('Dilwale Dulhania Le Jayenge', '1995', 8.2)
# ('Dev.D', '2009', 8.0)
# ('Mulk', 'I 2018', 6.1)
# ('Efter brylluppet', '2006', 7.8)
# ('Tiger Zinda Hai', '2017', 6.1)
# ('Kal Ho Naa Ho', '2003', 8.0)
# ('Kapoor & Sons', '2016', 7.7)
# ('Halkaa', '2018', 7.3)
# ('Kaabil', '2017', 7.1)
# ('Shivaay', '2016', 6.3)
# ('Dilwale', '2015', 5.2)
# ('Monsoon Wedding', '2001', 7.4)
# ('Raabta', '2017', 4.0)
# ('Talaash', '2012', 7.3)
# ('Badlapur', '2015', 7.5)
# ('The Other Side of the Door', '2016', 5.3)
# ('Rockstar', '2011', 7.7)
# ('Om Shanti Om', '2007', 6.7)
# ('Kuch Kuch Hota Hai', '1998', 7.7)
# ('Jab We Met', '2007', 7.9)
# ('Te3n', '2016', 7.2)
# ('Jab Harry Met Sejal', '2017', 5.4)
# ('Haider', '2014', 8.2)
# ('The Lovers', '2013', 4.6)
# ('Tubelight', '2017', 4.1)
# ('Welcome to New York', '2018', 2.3)
# ('Veer-Zaara', '2004', 7.9)
# ('Delhi Belly', '2011', 7.6)
# ('Piku', '2015', 7.6)
# ('Jodhaa Akbar', '2008', 7.6)
# ('A Gentleman', '2017', 6.2)
# ('Ra.One', '2011', 4.8)
# ('Mersal', '2017', 8.1)
# ('Hichki', '2018', 7.5)
# ('Zindagi Na Milegi Dobara', '2011', 8.1)
# ('Rab Ne Bana Di Jodi', '2008', 7.2)
# ('Dishoom', '2016', 5.1)
# ('Paan Singh Tomar', '2012', 8.2)
# ('Qarib Qarib Singlle', '2017', 7.0)
# ('Kai po che!', '2013', 7.6)
# ('Yeh Jawaani Hai Deewani', '2013', 7.0)
# ('Sanam Teri Kasam', '2016', 7.3)
# ('Myeong-ryang', '2014', 7.2)
# ('Swades: We, the People', '2004', 8.3)
# ('Kaalakaandi', '2018', 6.2)
# ('Naam Shabana', '2017', 6.3)
# ('Jab Tak Hai Jaan', '2012', 6.8)
# ('102 Not Out', '2018', 7.5)
# ('The Challenger', 'I 2015', 5.7)
# ('Baaghi 2', '2018', 5.1)
# ('Namaste England', '2018', 1.3)
# ('Sholay', '1975', 8.2)
# ('Omerta', '2017', 7.0)
# ('Nanu Ki Jaanu', '2018', 6.5)
# ('The Little Princess', '1939', 7.3)
# ('Mard Ko Dard Nahin Hota', '2018', 7.5)
# ('Pari', 'I 2018', 6.6)
# ('Chak De! India', '2007', 8.2)
# ('Queen', '2013', 8.3)
# ('Chennai Express', '2013', 6.0)
# ('Black Friday', '2004', 8.6)
# ('Love Aaj Kal', '2009', 6.8)
# ('Detective Byomkesh Bakshy!', '2015', 7.6)
# ('Dhoom:2', '2006', 6.5)
# ('The Namesake', '2006', 7.5)
# ('Loev', '2015', 5.9)
# ('Fitoor', '2016', 5.4)
# ('Half Girlfriend', '2017', 4.3)
# ('Pihu', 'I 2018', 6.6)
# ('Haraamkhor', '2015', 6.4)
# ('Shubh Mangal Saavdhan', '2017', 6.9)
# ('The Guru', '2002', 5.4)
# ('Baar Baar Dekho', '2016', 5.3)
# ('Hate Story IV', '2018', 3.4)
# ('Munna Bhai M.B.B.S.', '2003', 8.2)
# ('Baby', 'I 2015', 8.1)
# ('Bing feng: Chong sheng zhi men', '2014', 4.8)
# ('The House Next Door', '2017', 6.8)
# ('Mohabbatein', '2000', 7.1)
# ('Phantom', 'I 2015', 5.8)
# ('Chef', '2017', 5.6)
# ('Love Games', '2016', 4.4)
# ('Brij Mohan Amar Rahe', '2017', 7.1)
# ('Ankhon Dekhi', '2013', 8.0)
# ('Bhaiaji Superhit', '2018', 5.7)
# ('Chal Bhaag', '2014', 4.3)
# ('Salaam Bombay!', '1988', 8.0)
# ('Kabali', '2016', 6.4)
# ('Hindi Medium', '2017', 7.8)
# ('Sivaji', '2007', 7.5)
# ('Khosla Ka Ghosla!', '2006', 8.3)
# ('Maqbool', '2003', 8.2)
# ('Special Chabbis', '2013', 8.0)
# ('Fashion', '2008', 7.0)
# ('Krrish 3', '2013', 5.3)
# ('Paltan', '2018', 5.5)
# ('Oye Lucky! Lucky Oye!', '2008', 7.8)
# ('Fan', 'I 2016', 7.2)
# ('One Night Stand', 'I 2016', 3.2)
# ('Yamla Pagla Deewana Phir Se...', '2018', 5.3)
# ('Pyaar Ka Punchnama', '2011', 7.7)
# ('Madaari', '2016', 7.6)
# ('OMG: Oh My God!', '2012', 8.2)
# ('Phamous', '2018', 4.5)
# ('Befikre', '2016', 3.9)
# ('Trishna', '2011', 6.0)
# ('Wake Up Sid', '2009', 7.6)
# ('Singham', '2011', 6.8)
# ('Don', 'I 2006', 7.2)
# ('Margarita with a Straw', '2014', 7.3)
# ('Kites', 'I 2010', 6.1)
# ('Dum Laga Ke Haisha', '2015', 7.5)
# ('Khoobsurat', '2014', 6.4)
# ('Horror Story', 'I 2013', 4.4)
# ('Aashiqui 2', '2013', 7.0)
# ('Guzaarish', '2010', 7.5)
# ('Kaho Naa... Pyaar Hai', '2000', 6.9)
# ('Happy New Year', 'I 2014', 5.2)
# ('Outsourced', '2006', 7.0)
# ('Rahasya', '2015', 7.6)
# ('7 Khoon Maaf', '2011', 6.1)
# ('Gulaal', '2009', 8.1)
# ('Missing', 'I 2018', 5.8)
# ('A Death in the Gunj', '2016', 7.5)
# ('Hate Story', '2012', 5.3)
# ('Genius', 'I 2018', 4.9)
# ('Bombay Talkies', '2013', 6.7)
# ('Student of the Year', '2012', 5.5)
# ('Golmaal Again', '2017', 5.0)
# ('Dil Chahta Hai', '2001', 8.2)
# ('Ship of Theseus', '2012', 8.1)
# ('No One Killed Jessica', '2011', 7.2)
# ('Pyaar Ka Punchnama 2', '2015', 7.3)
# ('Badrinath Ki Dulhania', '2017', 6.2)
# ('Rangoon', 'II 2017', 5.8)
# ('Jism 2', '2012', 3.0)
# ('Mohenjo Daro', '2016', 5.8)
# ('Nawabzaade', '2018', 5.0)
# ('Dhoom', '2004', 6.7)
# ('Ek Tha Tiger', '2012', 5.5)
# ('Bombay Velvet', '2015', 5.7)
# ('Main Hoon Na', '2004', 7.0)
# ('Aligarh', '2015', 7.8)
# ('Vicky Donor', '2012', 7.8)
# ('Rustom', '2016', 7.1)
# ('Bang Bang', 'I 2014', 5.5)
# ('Company', '2002', 8.0)
# ('Akira', 'I 2016', 5.9)
# ('Jaane Tu... Ya Jaane Na', '2008', 7.5)
# ('Simran', '2017', 5.4)
# ('Katti Batti', '2015', 4.9)
# ('Roy', '2015', 3.3)
# ('Omkara', '2006', 8.1)
# ('City Lights', '2014', 7.3)
# ('Ekk Deewana Tha', '2012', 5.9)
# ('Bhaag Milkha Bhaag', '2013', 8.2)
# ('Ek Hasina Thi', '2004', 7.6)
# ('Guru', '2007', 7.8)
# ('Mubarakan', '2017', 5.6)
# ('Kurbaan', '2009', 5.7)
# ('Once Again', '2018', 7.3)
# ('Judwaa 2', '2017', 3.9)
# ('Kuchh Bheege Alfaaz', '2018', 7.7)
# ('Koi... Mil Gaya', '2003', 7.1)
# ('Baaghi', '2016', 5.2)
# ('Hera Pheri', '2000', 8.2)
# ('The Attacks of 26/11', '2013', 6.8)
# ('Indian', '1996', 8.1)
# ('Johnny Gaddaar', '2007', 7.9)
# ('Hotel Salvation', '2016', 7.2)
# ('Kaminey', '2009', 7.4)
# ('Ajji', '2017', 7.1)
# ('Dil Se..', '1998', 7.7)
# ('2 States', '2014', 6.9)
# ('The Other End of the Line', '2008', 6.2)
# ('Madras Cafe', '2013', 7.7)
# ('Kabhi Alvida Naa Kehna', '2006', 6.1)
# ('Ladies vs. Ricky Bahl', '2011', 6.0)
# ('Ragini MMS 2', '2014', 3.9)
# ('Hey Ram', '2000', 8.0)
# ('Neerja', '2016', 7.7)
# ('No Smoking', '2007', 7.2)
# ('Raanjhanaa', '2013', 7.6)
# ('Chashme Baddoor', '2013', 5.4)
# ('Cocktail', '2012', 6.2)
# ('Mujhse Dosti Karoge!', '2002', 5.1)
# ('Fanaa', '2006', 7.2)
# ('Race 2', '2013', 5.3)
# ('Udaan', '2010', 8.2)
# ('The Ghazi Attack', '2017', 7.6)
# ('M.S. Dhoni: The Untold Story', '2016', 7.7)
# ('Chandni Chowk to China', '2009', 4.0)
# ('Dhobi Ghat', '2010', 7.1)
# ('Lucknow Central', '2017', 6.1)
# ('Mirzya', '2016', 4.7)
# ('Josh', '2000', 6.2)
# ('Kahaani 2', '2016', 6.6)
# ('Sir', 'I 2018', 7.0)
# ('Anniyan', '2005', 8.2)
# ('Xun Long Jue', '2015', 6.0)
# ('Tere Mere Sapne', '1996', 6.2)
# ('1920 London', '2016', 4.1)
# ('La mujer de mi hermano', '2005', 6.2)
# ('Angrezi Mein Kehte Hain', '2018', 6.8)
# ('Playback', '1996', 4.0)
# ('Hunterrr', '2015', 7.0)
# ('Hate Story 3', '2015', 4.5)
# ('Force 2', '2016', 6.3)
# ('Wazir', 'I 2016', 7.1)
# ('Highway', 'I 2014', 7.6)
# ('Andaz Apna Apna', '1994', 8.2)
# ('Band Baaja Baaraat', '2010', 7.2)
# ('Dil To Pagal Hai', '1997', 7.1)
# ('Lamhe', '1991', 7.4)
# ('Lipstick Under My Burkha', '2016', 6.9)
# ('Brothers', 'I 2015', 6.7)
# ('Happy Bhag Jayegi', '2016', 6.4)
# ('Tees Maar Khan', '2010', 2.6)
# ('Meri Pyaari Bindu', '2017', 5.7)
# ('Madly', '2016', 6.3)
# ('Do Dooni Chaar', '2010', 7.6)
# ('Baazigar', '1993', 7.8)
# ('Rocky Handsome', '2016', 6.8)
# ('Gabbar is Back', '2015', 7.2)
# ('Singh Is Bliing', '2015', 5.3)
# ('English Vinglish', '2012', 7.9)
# ('Phobia', 'I 2016', 6.9)
# ('Mangal Pandey: The Rising', '2005', 6.7)
# ('Shanghai', '2012', 7.2)
# ('Dark wind', '2017', 9.0)
# ('Guest iin London', '2017', 5.4)
# ('Rocky', '1981', 6.9)
# ('Baadshaho', '2017', 5.0)
# ('Kaante', '2002', 6.6)
# ('Sold', '2016', 6.8)
# ('Rock On!!', '2008', 7.8)
# ('We Are Family', '2010', 5.6)
# ('Ek Villain', '2014', 6.5)
# ('Raja Natwarlal', '2014', 6.1)
# ('Tanu Weds Manu', '2011', 6.7)
# ('Bioscopewala', '2018', 7.8)
# ('Maine Pyar Kiya', '1989', 7.4)
# ('3 Storeys', '2018', 7.2)
# ('Sarkar 3', '2017', 4.8)
# ('Al-risâlah', '1976', 8.9)
# ('Dobaara: See Your Evil', '2017', 4.1)
# ('Satya', '1998', 8.2)
# ('Love and Shukla', '2017', 7.3)
# ('Tikli and Laxmi Bomb', '2017', 7.2)
# ('Bhoomi', '2017', 5.4)
# ('Awarapan', '2007', 7.2)
# ('Jolly LLB 2', '2017', 7.3)
# ('Game 6', '2005', 5.9)
# ('Umrika', '2015', 6.7)
# ('Tanu Weds Manu Returns', '2015', 7.7)
# ('Delhi-6', '2009', 6.0)
# ('Paheli', '2005', 6.7)
# ('That Girl in Yellow Boots', '2010', 6.7)
# ('Kaagaz Ke Phool', '1959', 8.1)
# ('Any Body Can Dance 2', '2015', 5.5)
# ('Bewakoofiyaan', '2014', 5.5)
# ('The Song of Scorpions', '2017', 6.5)
# ('Mera Naam Joker', '1970', 8.0)
# ('Mumbai Meri Jaan', '2008', 7.8)
# ('Tumhari Sulu', '2017', 7.0)
# ('Saawariya', '2007', 5.4)
# ('Saheb Biwi Aur Gangster 3', '2018', 4.4)
# ('Alone', 'VI 2015', 3.8)
# ('Desi Boyz', '2011', 5.9)
# ('Raajneeti', '2010', 7.1)
# ('Hisss', '2010', 3.0)
# ('Shaitan', '2011', 7.3)
# ('Jai Gangaajal', '2016', 5.7)
# ('Eega', '2012', 7.8)
# ('The Dirty Picture', '2011', 6.6)
# ('I Hate Luv Storys', '2010', 5.6)
# ('Court', '2014', 7.7)
# ('Gol Maal', '1979', 8.6)
# ('Dolly Ki Doli', '2015', 4.6)
# ('Sangam', 'I 1964', 7.6)
# ('Teri Bhabhi Hai Pagle', '2018', 5.5)
# ('Life in a Metro', '2007', 7.4)
# ('Khal Nayak', '1993', 7.2)
# ('Unfreedom', '2014', 6.2)
# ('Vishwaroopam 2', '2018', 6.1)
# ('Grand Masti', '2013', 4.4)
# ('A Flying Jatt', '2016', 3.4)
# ('Mission Kashmir', '2000', 6.8)
# ('Kambakkht Ishq', '2009', 3.9)
# ('Aurangzeb', '2013', 6.6)
# ('Namastey London', '2007', 7.3)
# ('Singham Returns', '2014', 5.7)
# ('X: Past Is Present', '2015', 5.6)
# ('Heroine', '2012', 5.1)
# ('Dhanak', '2015', 8.0)
# ('Murder', '2004', 5.4)
# ('Mardaani', '2014', 7.3)
# ('B.A. Pass 2', '2017', 2.2)
# ('Titli', '2014', 7.6)
# ('Yaadein...', '2001', 4.5)
# ('Fukrey Returns', '2017', 6.5)
# ('Freaky Ali', '2016', 5.0)
# ('Shorgul', '2016', 5.7)
# ('Thuppakki', '2012', 7.9)
# ('Bandit Queen', '1994', 7.6)
# ("Neal 'N' Nikki", '2005', 3.3)
# ('Sarkar', '2005', 7.7)
# ('Lakshya', '2004', 7.9)
# ('The Stoneman Murders', '2009', 7.4)
# ('Monsoon Shootout', '2013', 6.4)
# ('Hum Dil De Chuke Sanam', '1999', 7.5)
# ('NH10', '2015', 7.2)
# ('Helicopter Eela', '2018', 5.0)
# ('Joker', '2012', 2.6)
# ('Anjaana Anjaani', '2010', 5.8)
# ('Irada', '2017', 6.3)
# ('Boom', 'I 2003', 2.3)
# ('John Day', '2013', 5.7)
# ('Shamitabh', '2015', 6.8)
# ('Murder 2', '2011', 6.2)
# ('Vodka Diaries', '2018', 5.7)
# ('Happy Ending', '2014', 5.4)
# ('OK Jaanu', '2017', 5.1)
# ('Pizza', 'I 2014', 6.2)
# ('Patel Ki Punjabi Shaadi', '2017', 3.8)
# ('Mohalla Assi', '2015', 7.5)
# ('Shaurya: It Takes Courage to Make Right... Right', '2008', 7.3)
# ('Action Jackson', 'I 2014', 3.3)
# ('Kyaa Kool Hain Hum 3', '2016', 1.9)
# ('Akaash Vani', '2013', 6.3)
# ('Vaastav: The Reality', '1999', 8.0)
# ('Housefull 3', '2016', 5.2)
# ('Noor', 'I 2017', 4.0)
# ('Asoka', '2001', 6.7)
# ('Kick', '2014', 5.4)
# ('Yuva', '2004', 7.4)
# ('Heropanti', '2014', 5.4)
# ('Humpty Sharma Ki Dulhania', '2014', 6.0)
# ('Daddy', 'III 2017', 6.4)
# ('High Jack', '2018', 5.3)
# ('Water', 'I 2005', 7.8)
# ('Bollywood/Hollywood', '2002', 6.0)
# ('Tu Hai Mera Sunday', '2016', 7.8)
# ('Lupt', '2018', 6.9)
# ('Lootera', 'I 2013', 7.3)
# ('Heyy Babyy', '2007', 6.1)
# ("Kuldip Patwal: I Didn't Do It!", '2017', 7.6)
# ('Behen Hogi Teri', '2017', 5.4)
# ('Race', 'I 2008', 6.6)
# ('Hope Aur Hum', '2018', 6.5)
# ('Silvat', '2018', 8.0)
# ('Chalte Chalte', '2003', 6.6)
# ('Daas Dev', '2018', 5.1)
# ('Once Upon a Time in Mumbaai', '2010', 7.4)
# ('Kaun?', '1999', 7.7)
# ('Hostel', '2011', 5.1)
# ('Baasha', '1995', 8.3)
# ('Miss Teacher', '2016', 3.1)
# ('Fever', 'I 2016', 4.9)
# ('Fiza', '2000', 6.2)
# ('Nil Battey Sannata', '2015', 8.5)
# ('Paanch', '2003', 7.7)
# ('Beiimaan Love', '2016', 2.9)
# ('Bhool Bhulaiyaa', '2007', 7.3)
# ('Hasee Toh Phasee', '2014', 6.8)
# ('Babumoshai Bandookbaaz', '2017', 7.0)
# ('The Hero of Color City', '2014', 4.1)
# ('Finding Fanny', '2014', 5.8)
# ('Jaane Bhi Do Yaaro', '1983', 8.5)
# ('Commando 2', '2017', 5.2)
# ('Adisaya Piravi', '1990', 6.8)
# ('Phillauri', '2017', 6.1)
# ('Roja', '1992', 8.2)
# ('Darr', '1993', 7.8)
# ('Ghanchakkar', '2013', 5.7)
# ('Hamari Adhuri Kahani', '2015', 6.7)
# ('Mahabharat', '2013', 5.4)
# ('Billu', '2009', 6.2)
# ('Jo Jeeta Wohi Sikandar', '1992', 8.2)
# ('Dhan Dhana Dhan Goal', '2007', 4.9)
# ('Knock Out', '2010', 6.0)
# ('Lage Raho Munna Bhai', '2006', 8.1)
# ('Zed Plus', '2014', 6.4)
# ('Hum Tumhare Hain Sanam', '2002', 5.5)
# ('North West Frontier', '1959', 7.2)
# ('Welcome', 'I 2007', 6.8)
# ('The Blue Umbrella', '2005', 7.6)
# ('Aakrosh', '2010', 7.0)
# ('Munna Michael', '2017', 3.4)
# ('Socha Na Tha', '2005', 7.5)
# ('Rocket Singh: Salesman of the Year', '2009', 7.5)
# ('Manorama Six Feet Under', '2007', 7.7)
# ('Satyagraha', 'I 2013', 6.0)
# ('Kaal', '2005', 4.6)
# ('Fire', '1996', 7.3)
# ('Shootout at Wadala', '2013', 5.9)
# ('Pardes', '1997', 7.0)
# ('Mujhse Shaadi Karogi', '2004', 6.8)
# ('Rangeela', '1995', 7.5)
# ('Agent Vinod', '2012', 5.1)
# ('Main Tera Hero', '2014', 5.3)
# ('Vishwaroopam', '2013', 8.4)
# ('Shaandaar', '2015', 3.7)
# ('Ki & Ka', '2016', 5.8)
# ('Chittagong', '2012', 7.2)
# ('Ankur Arora Murder Case', '2013', 6.5)
# ('Chup Chup Ke', '2006', 6.7)
# ('Aitraaz', '2004', 6.8)
# ('Bullett Raja', '2013', 5.0)
# ('Commando', '2013', 6.1)
# ('Bodyguard', '2011', 4.6)
# ('LSD: Love, Sex Aur Dhokha', '2010', 7.1)
# ('Mere Brother Ki Dulhan', '2011', 5.9)
# ('Bachna Ae Haseeno', '2008', 6.2)
# ('Welcome to Karachi', '2015', 4.4)
# ('Luv Shuv Tey Chicken Khurana', '2012', 6.6)
# ('Luv Ka the End', '2011', 4.8)
# ('Athadu', '2005', 8.3)
# ('Table No.21', '2013', 7.1)
# ('Nayak: The Real Hero', '2001', 7.8)
# ('Chupke Chupke', '1975', 8.4)
# ('Holiday', '2014', 7.4)
# ('Great Grand Masti', '2016', 3.7)
# ('Jaane Kahan Se Aayi Hai', '2010', 4.0)
# ('Bluffmaster!', '2005', 6.7)
# ('Cheeni Kum', '2007', 6.8)
# ('Players', '2012', 4.1)
# ('Aankhen', '2002', 7.6)
# ('Agneepath', '1990', 7.7)
# ('Vivah', '2006', 6.6)
# ('Dabangg', '2010', 6.3)
# ('Ek Main Aur Ekk Tu', '2012', 5.8)
# ('Warrior Savitri', '2016', 5.0)
# ('Aryan: Unbreakable', '2006', 4.6)
# ('1942: A Love Story', '1994', 7.3)
# ('Bol Bachchan', '2012', 5.5)
# ('ABCD Any Body Can Dance', '2013', 6.4)
# ('Tere Bin Laden', '2010', 7.2)
# ('Thank You', 'I 2011', 4.7)
# ('D-Day', 'I 2013', 7.2)
# ('Teen Patti', '2010', 4.1)
# ('Himmatwala', '2013', 1.7)
# ('Kill Dil', '2014', 4.4)
# ('Mirror Game', '2017', 6.1)
# ('Paa', '2009', 7.2)
# ('Baghban', '2003', 7.4)
# ('Ribbon', '2017', 6.9)
# ('Action Replayy', '2010', 4.2)
# ('Pyaar Impossible!', '2010', 4.7)
# ('Karan Arjun', '1995', 6.9)
# ('Sadma', '1983', 8.5)
# ('Salaam Namaste', '2005', 6.2)
# ('Hate Story 2', '2014', 4.4)
# ('Kochadaiiyaan', '2014', 6.5)
# ('Wanted', '2009', 6.6)
# ('A Sublime Love Story: Barsaat', '2005', 4.1)
# ('Badmaa$h Company', '2010', 6.0)
# ('Mr. India', '1987', 7.8)
# ('Angry Indian Goddesses', '2015', 6.9)
# ('Rudhramadevi', '2015', 6.1)
# ('Dhruva', '2016', 8.0)
# ('Sarrainodu', '2016', 6.4)
# ('Housefull', '2010', 5.5)
# ('Thaandavam', '2012', 6.1)
# ('Phir Hera Pheri', '2006', 6.6)
# ('De Dana Dan', '2009', 5.3)
# ('Saajan', '1991', 7.3)
# ('Gunda', '1998', 7.4)
# ('Mother India', '1957', 8.1)
# ('Nautanki Saala!', '2013', 5.8)
# ('Maroon', '2016', 5.3)
# ('Prem Ratan Dhan Payo', '2015', 4.7)
# ('Baadshah', '1999', 6.9)
# ('Rehnaa Hai Terre Dil Mein', '2001', 7.5)
# ('My Brother... Nikhil', '2005', 7.4)
# ('Force', '2011', 6.4)
# ('Sarkar Raj', '2008', 6.8)
# ('Kartoos', '1999', 5.3)
# ('Sarfarosh', '1999', 8.2)
# ('Blue', 'I 2009', 3.8)
# ('Samsara', '2001', 7.8)
# ('Tezz', '2012', 3.9)
# ('Rock On 2', '2016', 5.0)
# ('Salaam-E-Ishq', '2007', 5.2)
# ('Kismat Konnection', '2008', 5.2)
# ('1921', '2018', 4.3)
# ('Bairavaa', '2017', 6.2)
# ("Midnight's Children", '2012', 6.2)
# ('Maachis', '1996', 7.8)
# ('Chalo Dilli', '2011', 6.8)
# ('Welcome to Sajjanpur', '2008', 6.9)
# ('Nishabd', '2007', 5.5)
# ('Shree', '2013', 6.4)
# ('Deewangee', '2002', 6.6)
# ('Insan', '2005', 5.0)
# ('Kabhi Haan Kabhi Naa', '1994', 7.9)
# ('Yevadu', '2014', 5.4)
# ('Veergati', '1995', 5.4)
# ("'D'", '2005', 6.9)
# ('LoveShhuda', '2016', 4.5)
# ('1920: Evil Returns', '2012', 4.9)
# ('Manjhi: The Mountain Man', '2015', 8.0)
# ('Hum Aapke Hain Koun...!', '1994', 7.5)
# ('Siddharth', '2013', 7.3)
# ('Union Leader', '2017', 7.8)
# ('Rang Rasiya', '2008', 7.1)
# ('Main Aur Charles', '2015', 6.3)
# ('16 December', '2002', 6.9)
# ('Qurbani', '1980', 7.1)
# ('Sonali Cable', '2014', 5.6)
# ('Rakhwala', '1989', 5.1)
# ('Anupama', '1966', 7.5)
# ('De surprise', '2015', 6.7)
# ('Zinda', '2006', 4.9)
# ('Ramaiya Vastavaiya', '2013', 5.7)
# ('Milan', '1967', 7.0)
# ('Abhimaan', '1973', 8.0)
# ('Geet', '1970', 7.3)
# ('Zanjeer', '2013', 3.3)
# ('Aunty No. 1', '1998', 4.2)
# ('Gopi Kishan', '1994', 5.5)
# ('Fun2shh... Dudes in the 10th Century', '2003', 4.5)
# ('Hum Aapke Dil Mein Rehte Hain', '1999', 5.8)
# ('Zamane Se Kya Darna', '1994', 5.7)
# ('Raat', '1992', 7.2)
# ('Hatya', '1988', 7.1)
# ('Sangram', '1993', 3.3)
# ('Kasam', '2001', 4.3)
# ('Teri Meri Kahaani', '2012', 4.8)
# ('Bombay', '1995', 8.1)
# ('Dhamaal', '2007', 7.2)
# ('Dishkiyaoon', '2014', 5.3)
# ('MP3: Mera Pehla Pehla Pyaar', '2007', 7.1)
# ('Ready', '2011', 4.7)
# ('Hulchul', '1995', 4.7)
# ('Farishtay', '1991', 4.9)
# ('Kati Patang', '1970', 7.2)
# ('Tum Mere Ho', '1990', 5.1)
# ('I Am Kalam', '2010', 8.0)
# ('Baabul', '2006', 5.5)
# ('Kidnap', '2008', 4.6)
# ('Junooniyat', '2016', 4.3)
# ('Dulhe Raja', '1998', 6.6)
# ('Amaanat', '1994', 5.5)
# ('Maine Dil Tujhko Diya', '2002', 3.8)
# ('Aisha', 'I 2010', 5.0)
# ('Inteha', '2003', 5.4)
# ('Firaaq', '2008', 7.4)
# ('Army', '1996', 4.4)
# ('Humshakals', '2014', 1.8)
# ('Hum Tum', '2004', 7.0)
# ('Aandhi', '1975', 8.2)
# ('Dus', '2005', 5.5)
# ('Buddha in a Traffic Jam', '2016', 6.9)
# ('Drona', '2008', 2.1)
# ('Gangster', '2006', 7.1)
# ('Border', 'I 1997', 7.9)
# ('Gumrah', '1993', 6.4)
# ('Love Story 2050', '2008', 2.6)
# ('Baankey Ki Crazy Baraat', '2015', 6.5)
# ('Zameen', '2003', 5.3)
# ('Sadak', '1991', 7.1)
# ('Main Khiladi Tu Anari', '1994', 6.9)
# ('Dhoondte Reh Jaoge', '2009', 5.6)
# ('Eena Meena Deeka', '1994', 4.6)
# ('Love Story', '1981', 6.5)
# ('Ankhen', '1968', 7.1)
# ('Karz', '1980', 7.5)
# ('Dora', '2017', 5.4)
# ('Hum Saath-Saath Hain: We Stand United', '1999', 6.2)
# ('Ek Phool Do Mali', '1969', 6.7)
# ('Little Terrors', '2014', 7.2)
# ('Jeena Sirf Merre Liye', '2002', 4.6)
# ('Kaashi in Search of Ganga', '2018', 7.2)
# ('Pyaasa', '1957', 8.5)
# ('R... Rajkumar', '2013', 5.2)
# ('Sanam Teri Kasam', '1982', 6.3)
# ('Izzat Ki Roti', '1993', 5.2)
# ('Traffic', 'I 2016', 6.7)
# ('Meri Biwi Ka Jawab Nahin', '2004', 4.6)
# ('Luck by Chance', '2009', 7.1)
# ('Waiting', 'III 2015', 7.2)
# ('Shalimar', '1978', 6.3)
# ('Jab Jab Phool Khile', '1965', 7.1)
# ('Aamir', '2008', 7.7)
# ('Deewaar', '1975', 8.1)
# ('Tere Naam', '2003', 7.1)
# ('Jugnu', '1973', 6.9)
# ('Matrubhoomi: A Nation Without Women', '2003', 7.7)
# ('Khatron Ke Khiladi', '1988', 4.8)
# ('Tum Mile', '2009', 5.0)
# ('Raju Ban Gaya Gentleman', '1992', 6.9)
# ('Ranna', '2015', 6.3)
# ('Singh Is Kinng', '2008', 5.8)
# ('Teraa Surroor', '2016', 2.8)
# ('Hamara Dil Aapke Paas Hai', '2000', 5.6)
# ('Imtihaan', '1994', 5.3)
# ('Meri Nimmo', '2018', 7.2)
# ('Rascals', '2011', 2.9)
# ('Aa Gale Lag Jaa', '1973', 7.1)
# ('Aalavandhan', '2001', 7.1)
# ('Kis Kisko Pyaar Karoon', '2015', 5.7)
# ("Liar's Dice", '2013', 6.9)
# ('Jayantabhai Ki Luv Story', '2013', 5.3)
# ('Khilona Bana Khalnayak', '1995', 7.0)
# ('Khoon Bhari Maang', '1988', 6.7)
# ('Ishaqzaade', '2012', 6.6)
# ('Khudgarz', '1987', 5.9)
# ('Gumnaam', '1965', 7.2)
# ('Break Ke Baad', '2010', 5.2)
# ('Bazaar', '1982', 7.3)
# ('Fukrey', '2013', 6.9)
# ('Samadhi', '1972', 7.5)
# ('Kurbaan', '1991', 4.2)
# ('Duplicate', '1998', 5.5)
# ('Thupparivaalan', '2017', 7.5)
# ('Aladin', '2009', 4.7)
# ('Ram Gopal Varma Ki Aag', '2007', 1.9)
# ('C.I.D.', '1956', 7.5)
# ('Umrao Jaan', '2006', 5.5)
# ('Six X', '2016', 6.7)
# ('Matru ki Bijlee ka Mandola', '2013', 5.7)
# ('Global Baba', '2016', 5.5)
# ('Dushman Duniya Ka', '1996', 4.6)
# ('Kurukshetra', '2000', 6.1)
# ('Dedh Ishqiya', '2014', 7.1)
# ('Fool N Final', '2007', 3.4)
# ('Kadhal Desam', '1996', 6.9)
# ('Shakti', '1982', 7.8)
# ('Filth and Wisdom', '2008', 5.6)
# ('Humraaz', '2002', 6.3)
# ('Bank Chor', '2017', 5.9)
# ('Dushman', '1971', 7.0)
# ('Main Krishna Hoon', '2013', 5.9)
# ('U Me Aur Hum', '2008', 6.0)
# ('Dil Toh Baccha Hai Ji', '2011', 5.7)
# ('Vidhaata', '1982', 7.1)
# ('Roti Kapada Aur Makaan', '1974', 7.0)
# ('Shola Aur Shabnam', '1992', 6.7)
# ('Rukh', '2017', 6.5)
# ('Purani Jeans', '2014', 6.1)
# ('Baazi', '1995', 6.6)
# ('Aaja Nachle', '2007', 6.4)
# ('Chaudhvin Ka Chand', '1960', 7.2)
# ('Chameli', '2003', 7.1)
# ('Aadhi Bhagavan', '2013', 5.4)
# ('Ananda Ashram', '1977', 7.2)
# ('Bhopal: A Prayer for Rain', '2014', 7.3)
# ('Dance Dance', '1987', 6.0)
# ('Anaarkali of Aarah', '2017', 6.5)
# ('Khamoshi: The Musical', '1996', 7.6)
# ('Bol', '2011', 8.3)
# ('Guide', '1965', 8.5)
# ('Ek Paheli Leela', '2015', 3.8)
# ('Children of War', '2014', 6.8)
# ('Karzzzz', '2008', 2.2)
# ('Don', '1978', 7.8)
# ('Gali Guleiyan', '2017', 7.8)
# ('Raavan', '2010', 5.4)
# ('Haré Rama Haré Krishna', '1971', 7.3)
# ('Girlfriend', '2004', 3.3)
# ('China Gate', '1998', 6.7)
# ('Chocolate: Deep Dark Secrets', '2005', 4.8)
# ('Dear Dad', 'I 2016', 6.4)
# ('Dasvidaniya', '2008', 7.8)
# ('Sangharsh', '1999', 7.1)
# ('Pataal Bhairavi', '1985', 5.7)
# ('Jai Santoshi Maa', '1975', 6.8)
# ('Jis Desh Mein Ganga Rehta Hain', '2000', 4.9)
# ('Arth', '1982', 8.0)
# ('Aarakshan', '2011', 6.2)
# ('Shool', '1999', 7.7)
# ('Saat Uchakkey', '2016', 5.7)
# ('Parzania', '2005', 7.7)
# ('Khushi', 'I 2003', 4.5)
# ('Naseeb', '1981', 7.1)
# ('Bhindi Baazaar', '2011', 6.2)
# ('Bulandi', '2000', 5.4)
# ('Shaadi Ke Side Effects', '2014', 5.6)
# ('Chor Machaye Shor', '1974', 6.6)
# ('Sarbjit', '2016', 7.3)
# ('Raja Hindustani', '1996', 6.1)
# ('Silsila', '1981', 7.4)
# ('Shabd', '2005', 5.2)
# ('Yodha', '1991', 4.4)
# ("Jaan-E-Mann: Let's Fall in Love... Again", '2006', 6.4)
# ('Phir Teri Kahani Yaad Aayee', '1993', 6.0)
# ('Blood Money', 'II 2012', 5.1)
# ('Right Yaaa Wrong', '2010', 6.4)
# ('Waqt Hamara Hai', '1993', 6.2)
# ('Seeta Aur Geeta', '1972', 6.9)
# ('Dil Ne Jise Apna Kaha', '2004', 4.5)
# ('Kunwara', '2000', 5.1)
# ('The Silence', 'III 2015', 7.2)
# ('Chameli Ki Shaadi', '1986', 7.6)
# ('Garam Masala', '2005', 6.8)
# ('Angoor', '1982', 8.4)
# ('Mahal', '1949', 7.1)
# ('Johny Mera Naam', '1970', 7.4)
# ('Page 3', '2005', 7.3)
# ('Tum Bin...: Love Will Find a Way', '2001', 7.5)
# ('Phir Bhi Dil Hai Hindustani', '2000', 6.3)
# ('Pusher', '2010', 6.2)
# ('3G - A Killer Connection', '2013', 3.7)
# ('Achanak', '1998', 4.3)
# ('Roop Ki Rani Choron Ka Raja', '1993', 4.9)
# ('Raaz', '2002', 6.5)
# ('Saathiya', '2002', 6.9)
# ('Bhabhi', '1991', 4.6)
# ('Maa', '1976', 6.4)
# ('Prem Deewane', '1992', 5.2)
# ('Saheb Biwi Aur Gangster', '2011', 7.2)
# ('Kalyug', '2005', 6.5)
# ('Awara Paagal Deewana', '2002', 6.4)
# ('Indu Sarkar', '2017', 6.0)
# ('Geraftaar', '1985', 6.1)
# ('Filmistaan', '2012', 7.3)
# ('Love', '1991', 6.0)
# ('Bekhudi', '1992', 4.9)
# ('Dalaal', '1993', 6.0)
# ('Ghayal Once Again', '2016', 6.5)
# ('Login', '2012', 6.3)
# ('Good Boy, Bad Boy', '2007', 3.8)
# ('Mohra', '1994', 7.1)
# ('Machine', '2017', 2.7)
# ('Rise of the Zombie', '2013', 4.0)
# ('Sargam', '1979', 6.7)
# ('Haqeeqat', '1964', 7.8)
# ('Gang', '2000', 6.3)
# ('Dil Dosti Etc', '2007', 7.0)
# ('Heer Ranjha', '1992', 5.4)
# ('Strangers', 'III 2007', 5.1)
# ('Gundaraj', '1995', 4.4)
# ('Aan Milo Sajna', '1970', 6.5)
# ('Andaaz', '2003', 5.6)
# ('Tejasvini', '1994', 6.7)
# ('Stanley Ka Dabba', '2011', 7.9)
# ('Yaar Gaddar', '1994', 4.4)
# ('Style', '2001', 6.7)
# ('Dongri Ka Raja', '2016', 4.3)
# ('Sahasam', '2013', 6.6)
# ('Main Aurr Mrs Khanna', '2009', 3.6)
# ('LOC: Kargil', '2003', 5.2)
# ('Sanam Re', '2016', 3.2)
# ('Gyakusatsu kikan', '2017', 6.4)
# ('Majboor', '1974', 7.2)
# ('Major Saab', '1998', 5.3)
# ('Satte Pe Satta', '1982', 7.2)
# ('Khatta Meetha', '2010', 5.8)
# ('Ek Thi Daayan', '2013', 5.7)
# ('Yeh Saali Zindagi', '2011', 7.5)
# ('Lekar Hum Deewana Dil', '2014', 4.9)
# ('Mere Baap Pehle Aap', '2008', 5.3)
# ('Pyaar Tune Kya Kiya...', '2001', 5.7)
# ('Aastha: In the Prison of Spring', '1997', 6.4)
# ('Issaq', '2013', 4.6)
# ('Fareb', '2005', 4.1)
# ('Ek Chalis Ki Last Local', '2007', 7.3)
# ('Rowdy Rathore', '2012', 5.8)
# ('Iqbal', '2005', 8.1)
# ('Phas Gaye Re Obama', '2010', 7.5)
# ('Samraat', '1982', 6.0)
# ('Zamaana Deewana', '1995', 5.1)
# ('Ilaaka', '1989', 4.7)
# ('Dus Kahaniyaan', '2007', 5.8)
# ('Adhurs', '2010', 6.8)
# ('Housefull 2', '2012', 5.4)
# ('Earth', '1998', 7.8)
# ('Son of Sardaar', '2012', 4.0)
# ('Amar Akbar Anthony', '1977', 7.5)
# ('Satta', '2003', 6.9)
# ('Anita & Me', '2002', 6.5)
# ('Rann', '2010', 7.0)
# ('Yeh Lamhe Judaai Ke', '2004', 4.3)
# ('Kyaa Kool Hai Hum', '2005', 6.1)
# ('King Uncle', '1993', 5.2)
# ('Inteqam: The Perfect Game', '2004', 5.4)
# ('Jai Ho', 'I 2014', 5.3)
# ('Begum Jaan', '2017', 5.5)
# ('Shirdi Ke Sai Baba', '1977', 7.0)
# ('International Khiladi', '1999', 5.0)
# ('Mahaan', '1983', 6.2)
# ('Ta Ra Rum Pum', '2007', 5.6)
# ('Henna', '1991', 6.4)
# ('New York', '2009', 6.8)
# ('Mere Yaar Ki Shaadi Hai', '2002', 5.3)
# ('Phool Aur Patthar', '1966', 6.6)
# ("What's Your Raashee?", '2009', 4.7)
# ('Yun Hota Toh Kya Hota', '2006', 6.9)
# ('Hawaa Hawaai', '2014', 7.4)
# ('Qahar', '1997', 4.0)
# ('Dushman', '1998', 6.9)
# ('Aarzoo', '1999', 5.7)
# ('London Dreams', '2009', 5.4)
# ('Deewana Mastana', '1997', 6.7)
# ('Footpath', '2003', 5.4)
# ('Khoj', '2017', 7.0)
# ('Aaj Ki Taaza Khabar', '1973', 7.4)
# ('Shirdi Sai Baba', '2001', 3.5)
# ('...Yahaan', '2005', 7.5)
# ('Oh Darling Yeh Hai India', '1995', 4.4)
# ('Jism', '2003', 5.2)
# ('Deewana', '1992', 7.0)
# ('Veer', '2010', 4.7)
# ('Golmaal: Fun Unlimited', '2006', 7.4)
# ('Ajab Prem Ki Ghazab Kahani', '2009', 6.3)
# ('Ghulam', '1998', 7.3)
# ('Kranti', '2002', 3.8)
# ('Super Nani', '2014', 4.7)
# ('Aadmi Khilona Hai', '1993', 5.2)
# ('31st October', '2015', 5.8)
# ('Dum Maaro Dum', '2011', 6.2)
# ('Irandam Ulagam', '2013', 5.8)
# ('Ghar', '1978', 6.9)
# ('Dabangg 2', '2012', 4.9)
# ('Duvvada Jagannadham', '2017', 5.4)
# ('Hungama', '2003', 7.5)
# ('Firangi', '2017', 4.7)
# ('Hum', '1991', 6.9)
# ('Hawa', '2003', 3.4)
# ('Jewel Thief', '1967', 7.9)
# ('Veerey Ki Wedding', '2018', 3.1)
# ('Ram Aur Shyam', '1967', 7.4)
# ('Chhota Bheem Himalayan Adventure', '2016', 6.2)
# ('Rakhta Charitra 2', '2010', 6.4)
# ('Chhoti Si Baat', '1976', 8.3)
# ('Inkaar', '2013', 6.1)
# ('Club 60', '2013', 7.3)
# ('Hulchul', '2004', 6.9)
# ('Ghazab', '1982', 6.7)
# ('Hum Kisi Se Kum Nahin', '2002', 4.4)
# ('Vijeta', '1996', 4.2)
# ('Koyla', '1997', 6.3)
# ('Anjaam', '1994', 7.0)
# ('Bhoothnath Returns', '2014', 6.8)
# ('Daai zek lou', '2003', 6.7)
# ('Jaal: The Trap', '2003', 4.1)
# ('Rajkumar', '1964', 7.0)
# ('Dil Tera Aashiq', '1993', 5.1)
# ('Ittefaq', '1969', 7.4)
# ('Bhupathi', '2007', 6.6)
# ('Kudrat', '1981', 7.1)
# ('Welcome Back', '2015', 4.2)
# ('Hawaizaada', '2015', 5.6)
# ('Mausam', '2011', 4.8)
# ('Meeruthiya Gangsters', '2015', 7.2)
# ('Main Tulsi Tere Aangan Ki', '1978', 7.1)
# ('Khhotte Sikkay', '1974', 6.7)
# ('Yeh Hai Bakrapur', '2014', 3.8)
# ('Shootout at Lokhandwala', '2007', 7.1)
# ('Laal Rang', '2016', 8.2)
# ('Deewane', '2000', 4.7)
# ('Ankur', '1974', 8.2)
# ('Do Anjaane', '1976', 6.9)
# ('Anjaan', '2014', 4.9)
# ('Ishq', '1997', 6.9)
# ('Aaj Ka Goonda Raaj', '1992', 5.5)
# ('Karz: The Burden of Truth', '2002', 3.9)
# ('Khajoor Pe Atke', '2018', 5.3)
# ('Jilla', '2014', 6.1)
# ('Tales of the KamaSutra 2: Monsoon', '1999', 3.7)
# ('Julie 2', '2017', 2.8)
# ('Bhoothnath', '2008', 6.3)
# ('Anokha Bandhan', '1982', 7.2)
# ('Souten', '1983', 5.6)
# ('Virasat', '1997', 7.5)
# ('Vettaiyaadu Vilaiyaadu', '2006', 8.0)
# ('Qayamat Se Qayamat Tak', '1988', 7.6)
# ('Sin-ui hansu', '2014', 6.7)
# ('Ishqiya', '2010', 7.3)
# ('Game', 'I 2011', 5.1)
# ('Doosara Aadmi', '1977', 6.8)
# ('Ranchi Diaries', '2017', 7.2)
# ('London Paris New York', '2012', 5.7)
# ('Agyaat', '2009', 2.9)
# ('Namak Haraam', '1973', 7.3)
# ('Lal Patthar', '1971', 6.8)
# ('Hera Pheri', '1976', 6.9)
# ('Adventures of Tarzan', '1985', 5.3)
# ('Raincoat', '2004', 7.6)
# ('Chandra Mukhi', '1993', 3.9)
# ('Netaji Subhas Chandra Bose: The Forgotten Hero', '2005', 7.5)
# ('Izzatdaar', '1990', 5.3)
# ('Banarasi Babu', '1997', 4.5)
# ('Woh Lamhe', '2006', 6.7)
# ('13B: Fear Has a New Address', '2009', 7.2)
# ('Shree 420', '1955', 8.1)
# ('Kuch Naa Kaho', '2003', 5.5)
# ('Mounam Pesiyadhe', '2002', 7.7)
# ('Ijaazat', '1987', 8.3)
# ('Yeh Dil', '2003', 4.2)
# ('Dilwaala', '1986', 3.7)
# ('Mr Joe B. Carvalho', '2014', 3.7)
# ('Madhumati', '1958', 8.1)
# ('Journey Bombay to Goa: Laughter Unlimited', '2007', 4.4)
# ('Sri Siddhartha Gautama', '2013', 7.1)
# ('Teesri Manzil', '1966', 7.7)
# ('Devar', '1966', 7.4)
# ('Hazaaron Khwaishein Aisi', '2003', 8.0)
# ('Chance Pe Dance', '2010', 4.7)
# ('Aiyyaa', '2012', 4.4)
# ('Raag Desh', '2017', 8.2)
# ('Divya Shakti', '1993', 4.0)
# ('Mehboob Ki Mehndi', '1971', 7.1)
# ('Dil Kya Kare', '1999', 5.2)
# ('Dulha Mil Gaya', '2010', 4.4)
# ('Barsaat', '1949', 7.9)
# ('Waqt', '1965', 7.8)
# ('Wajood', '1998', 6.8)
# ('Kalicharan', '1976', 6.6)
# ('Wajah Tum Ho', '2016', 4.4)
# ('Dhadkan', '2000', 6.8)
# ('Hadh Kar Di Aapne', '2000', 5.3)
# ('Hum Tum Aur Ghost', '2010', 4.8)
# ('Teen Aur Aadha', '2018', 8.4)
# ('Khelein Hum Jee Jaan Sey', '2010', 5.9)
# ('Prem Pratigyaa', '1989', 5.9)
# ('The Deceivers', '1988', 6.1)
# ('Kaalo', '2010', 3.1)
# ('Refugee', '2000', 5.5)
# ('Samay: When Time Strikes', '2003', 6.9)
# ('Jhootha Hi Sahi', '2010', 6.2)
# ('Woh Kaun Thi?', '1964', 7.7)
# ('Tu Chor Main Sipahi', '1996', 5.5)
# ('Yamla Pagla Deewana', '2011', 5.7)
# ('City of Life', '2009', 7.1)
# ('Hey Bro', '2015', 4.8)
# ('Saala Khadoos', '2016', 7.6)
# ('Gadar: Ek Prem Katha', '2001', 7.1)
# ('Golmaal 3', '2010', 5.4)
# ('Khuda Gawah', '1992', 6.6)
# ('Nanak Shah Fakir', '2014', 8.8)
# ('Ungli', '2014', 5.8)
# ('Police Force: An Inside Story', '2004', 5.2)
# ('Pretty Polly', '1967', 6.7)
# ('I Am', 'II 2010', 7.0)
# ('Tumsa Nahin Dekha', '2004', 4.7)
# ('Jangal Mein Mangal', '1972', 6.9)
# ('Jagte Raho', '1956', 8.4)
# ('Bombay to Goa', '1972', 6.9)
# ('Superman', '1987', 4.2)
# ('Gunga Jumna', '1961', 7.6)
# ('Vaada Raha... I Promise', '2009', 6.1)
# ('The Dark Side of Life: Mumbai City', '2018', 8.2)
# ('The Legend of Bhagat Singh', '2002', 8.1)
# ('Miss Lovely', '2012', 6.6)
# ('Judwaa', '1997', 6.0)
# ('Daava', '1997', 5.3)
# ('Gippi', '2013', 5.6)
# ('Total Siyapaa', '2014', 5.0)
# ('99', 'I 2009', 7.3)
# ('Rakhta Charitra', '2010', 7.6)
# ('Alag: He Is Different.... He Is Alone...', '2006', 4.1)
# ('Saaya', '2003', 5.8)
# ('Kal Kissne Dekha', '2009', 3.6)
# ('Tamanna', '1998', 7.1)
# ('Dum', '2003', 5.6)
# ('Mickey Virus', '2013', 6.1)
# ('Samrat & Co.', '2014', 6.4)
# ('All Is Well', '2015', 3.8)
# ('Mela', '2000', 3.8)
# ('Khiladi 786', '2012', 4.4)
# ('Gauru: Journey of Courage', '2016', 8.8)
# ('I, Me aur Main', '2013', 4.6)
# ('Ek Ladka Ek Ladki', '1992', 5.8)
# ('Deadline: Sirf 24 Ghante', '2006', 6.4)
# ('Sahib Bibi Aur Ghulam', '1962', 8.4)
# ('Veerana', '1988', 6.7)
# ('Jazbaa', '2015', 5.8)
# ('Azhar', '2016', 5.8)
# ('Tauba Tauba', '2004', 2.7)
# ('Krodh', '2000', 4.3)
# ('Chori Chori', '2003', 4.9)
# ('Keemat: They Are Back', '1998', 6.1)
# ('Yalgaar', '1992', 5.4)
# ('Zubaan', '2015', 6.2)
# ('Baarish Aur Chowmein', '2018', 6.8)
# ('Golmaal Returns', '2008', 5.0)
# ('Chalo Ishq Ladaaye', '2002', 4.4)
# ('Pehchaan', '1993', 4.5)
# ('Do Raaste', '1969', 7.0)
# ('Avtaar', '1983', 7.2)
# ('Taqdeerwala', '1995', 6.6)
# ('Mera Saaya', '1966', 7.7)
# ('Phir Milenge', '2004', 6.2)
# ('1971', '2007', 8.0)
# ('Jai Vikraanta', '1995', 5.4)
# ('Khakee', '2004', 7.5)
# ('Autohead', '2016', 6.1)
# ('Jattu Engineer', '2017', 6.2)
# ('Saagar', '1985', 7.2)
# ('Dirty Politics', '2015', 2.6)
# ('God Tussi Great Ho', '2008', 3.6)
# ('Sanam', '1997', 4.9)
# ('Dil Vil Pyar Vyar', '2002', 5.3)
# ('Golimar', '2010', 5.9)
# ('Chalti Ka Naam Gaadi', '1958', 8.0)
# ('Shagird', '2011', 7.0)
# ('Boss', 'I 2013', 5.5)
# ('Hero No. 1', '1997', 6.1)
# ('Partner', '2007', 5.7)
# ('Mission Istaanbul: Darr Ke Aagey Jeet Hai!', '2008', 3.4)
# ('Budhia Singh: Born to Run', '2016', 7.8)
# ('Khamoshiyan', '2015', 4.1)
# ('Aksar 2', '2017', 4.1)
# ('Murder 3', '2013', 4.9)
# ('Parinda', '1989', 7.9)
# ('Karthik Calling Karthik', '2010', 7.0)
# ('Xcuse Me', '2003', 5.7)
# ('Kashmir Ki Kali', '1964', 7.1)
# ('Khandan', '1965', 6.8)
# ('Paap Ki Duniya', '1988', 5.7)
# ('Shor in the City', '2010', 7.3)
# ('Fida', '2004', 5.4)
# ("Trip to Bhangarh: Asia's Most Haunted Place", '2014', 2.6)
# ('Lafangey Parindey', '2010', 5.3)
# ('Kisaan', '2009', 5.5)
# ('Insaniyat', '1994', 3.3)
# ('Bangistan', '2015', 4.6)
# ('Ek Doctor Ki Maut', '1990', 8.4)
# ('Cash', '2007', 3.5)
# ('Khuddar', '1994', 5.3)
# ('Not a Love Story', '2011', 5.0)
# ('Angaaray', '1998', 5.9)
# ('Sanam Teri Kasam', '2009', 5.1)
# ('Fugly', '2014', 4.7)
# ('Jodi', '1999', 6.2)
# ('Yeh Vaada Raha', '1982', 7.1)
# ('Bombay Boys', '1998', 6.9)
# ('Bhagam Bhag', '2006', 6.4)
# ('Eklavya', '2007', 6.2)
# ('Main Prem Ki Diwani Hoon', '2003', 4.0)
# ("It's Entertainment", '2014', 4.7)
# ('Shuddh Desi Romance', '2013', 5.8)
# ('Jackpot', 'II 2013', 2.2)
# ('Tadipaar', '1993', 6.0)
# ('Jurm', '2005', 5.6)
# ('Mausam', '1975', 8.1)
# ('Ishq Forever', '2016', 3.9)
# ('Dacait', '1987', 6.7)
# ('100 Days', '1991', 6.5)
# ('Snegithiye', '2000', 6.8)
# ('David', 'I 2013', 6.3)
# ('Kasoor', '2001', 6.1)
# ('Bees Saal Baad', '1962', 7.1)
# ('Always Kabhi Kabhi', '2011', 4.3)
# ('Suraj', '1966', 7.2)
# ('Running Shaadi', '2017', 6.8)
# ('Phata Poster Nikhla Hero', '2013', 4.9)
# ('Mr. X', '2015', 3.8)
# ('Chillar Party', '2011', 7.5)
# ('Mere Dad Ki Maruti', '2013', 6.5)
# ('Apaharan', '2005', 7.4)
# ('Bhoot Returns', '2012', 2.5)
# ('The Train: Some Lines Should Never Be Crossed...', '2007', 4.3)
# ('Athidhi', '2007', 5.7)
# ('Ravan Raaj: A True Story', '1995', 7.3)
# ('Jodi No.1', '2001', 5.9)
# ('Ghayal', '1990', 7.7)
# ('Yamla Pagla Deewana 2', '2013', 3.5)
# ('Amazon Obhijaan', '2017', 5.0)
# ('Johnny', '1980', 7.3)
# ('Rudraksh', '2004', 2.7)
# ('Patthar Ke Phool', '1991', 5.7)
# ('The Killer', '2006', 4.6)
# ('Ragini MMS', '2011', 5.0)
# ('Tashan', '2008', 3.9)
# ('Gangaajal', '2003', 7.9)
# ('Khubsoorat', '1980', 7.7)
# ('Aks', '2001', 5.9)
# ('Jaal', '1986', 5.7)
# ('Ek Ajnabee', '2005', 5.3)
# ('Milenge Milenge', '2010', 4.1)
# ('Raaj Tilak', '1984', 6.7)
# ('Duniya', '1984', 7.0)
# ('Guddu', '1995', 4.5)
# ('Sultanat', '2014', 6.3)
# ('Sunday', 'I 2008', 5.3)
# ('Shiva', '1989', 8.1)
# ('Pratiggya', '1975', 7.3)
# ('Khamosh', '1986', 7.5)
# ('Money Hai Toh Honey Hai', '2008', 2.8)
# ('Hattrick', '2007', 4.2)
# ('Jannat 2', '2012', 6.1)
# ('Puli', '2015', 4.7)
# ('Chachi 420', '1997', 7.4)
# ('Ram Jaane', '1995', 5.5)
# ('Veeram', '2017', 6.8)
# ('Kyun! Ho Gaya Na...', '2004', 4.3)
# ('Vikram', 'I 1986', 7.3)
# ('Corporate', '2006', 6.5)
# ('Dil Aashna Hai ...The Heart Knows', '1992', 5.1)
# ('Gunaah', '2002', 3.4)
# ('Pyari Behna', '1985', 6.6)
# ('Mr. and Mrs. Iyer', '2002', 8.0)
# ('Phörpa', '1999', 6.9)
# ('Kabul Express', '2006', 6.8)
# ('Jeete Hain Shaan Se', '1988', 4.7)
# ('Brahmachari', 'I 1968', 6.9)
# ('Gulaab Gang', '2014', 6.1)
# ('Guddi', '1971', 7.4)
# ('Jaanwar', '1999', 6.3)
# ('Raaz Reboot', '2016', 4.5)
# ('Tera Intezaar', '2017', 1.7)
# ('Arjun: The Warrior Prince', '2012', 6.9)
# ('Yeh Raaste Hain Pyaar Ke', '2001', 4.1)
# ('Rahul', '2001', 5.4)
# ('Boot Polish', '1954', 8.1)
# ('Wedding Anniversary', 'I 2017', 5.4)
# ('Shatranj', '1993', 6.5)
# ('Shortkut - The Con Is On', '2009', 3.4)
# ('Days of Tafree', '2016', 7.7)
# ('Bhouri', '2016', 6.9)
# ('Mann', '1999', 6.3)
# ('Julie', '2004', 4.2)
# ('Santa Banta Pvt Ltd', '2016', 3.0)
# ('Rudaali', '1993', 7.2)
# ('Madurey', '2004', 4.6)
# ('Mumbai Delhi Mumbai', '2014', 5.9)
# ('Pehla Nasha', '1993', 5.2)
# ('Jolly LLB', '2013', 7.5)
# ('Maine Pyaar Kyun Kiya', '2005', 5.6)
# ('Patiala House', '2011', 5.9)
# ('Taal', '1999', 6.8)
# ('Jhankaar Beats', '2003', 7.2)
# ('Kaanchi', '2014', 4.5)
# ('Chal Mere Bhai', '2000', 4.7)
# ('Desh Premee', '1982', 6.0)
# ('Department', '2012', 3.3)
# ('Machhli Jal Ki Rani Hai', '2014', 4.3)
# ('Pinjar: Beyond Boundaries...', '2003', 8.1)
# ('Thanedaar', '1990', 5.7)
# ('Hide & Seek', '2010', 4.1)
# ('Kondaveeti Raja', '1986', 7.1)
# ('Zakhmi Dil', '1994', 5.2)
# ('7 Aum Arivu', '2011', 6.1)
# ('S/O Satyamurthy', '2015', 6.8)
# ('Ab Tumhare Hawale Watan Saathiyo', '2004', 4.8)
# ('Akele Hum Akele Tum', '1995', 7.1)
# ('Balu Mahi', '2017', 6.6)
# ('Jail', '2009', 6.2)
# ('Student No. 1', '2001', 6.8)
# ('Anji', '2004', 5.7)
# ('Shaapit: The Cursed', '2010', 5.6)
# ('Hawas', '2004', 2.7)
# ('Pyaar Koi Khel Nahin', '1999', 3.4)
# ('Kadhalar Dinam', '1999', 6.2)
# ('Mahaanta: The Film', '1997', 4.6)
# ('Zakhm', '1998', 8.0)
# ('36 China Town', '2006', 5.6)
# ('Amal', '2007', 7.6)
# ('Chandni Bar', '2001', 7.6)
# ('Janbaaz', '1986', 6.2)
# ('Ram Balram', 'I 1980', 6.4)
# ('Chhota Chetan', '1998', 5.8)
# ('Amit Sahni Ki List', '2014', 5.5)
# ('Ankush', '1986', 7.6)
# ('Halla Bol', '2008', 6.1)
# ('Poster Boys', '2017', 5.6)
# ('Raju Chacha', '2000', 5.1)
# ('Masterji', '1985', 6.6)
# ('Farz', '1967', 6.4)
# ('Jungle', '2000', 6.2)
# ('Baazi', '1984', 6.4)
# ('I See You', '2006', 4.3)
# ('Shab', '2017', 4.4)
# ('Ferrari Ki Sawaari', '2012', 6.4)
# ('Anth', '1994', 5.5)
# ('Watan Ke Rakhwale', '1987', 6.1)
# ('Darna Mana Hai', '2003', 6.3)
# ('Do Knot Disturb', '2009', 3.7)
# ('Kareeb', '1998', 6.6)
# ('Raakh', '1989', 7.7)
# ('Naina', '2005', 4.3)
# ('Humse Badhkar Kaun: The Entertainer', '1998', 3.9)
# ('Platform', '1993', 3.9)
# ('Rishtey', '2002', 4.6)
# ('Tere Bin Laden: Dead Or Alive', '2016', 4.3)
# ('Parampara', '1993', 5.9)
# ('Luck', 'I 2009', 4.8)
# ('Maya', '1993', 5.7)
# ('Chaalbaaz', '1989', 6.8)
# ('Tum Bin 2', '2016', 4.9)
# ('Yaariyan', '2014', 2.7)
# ('Baazi', '1951', 7.4)
# ('Makdee', '2002', 7.4)
# ('Chingaari', '2006', 4.6)
# ('Paap', '2003', 5.2)
# ('The Xpose', '2014', 3.3)
# ('Bheja Fry', '2007', 7.7)
# ('Taxi No. 9 2 11: Nau Do Gyarah', '2006', 7.2)
# ('Yeh Zindagi Ka Safar', '2001', 3.3)
# ('Dil Pardesi Ho Gayaa', '2003', 4.8)
# ('Darwaza', '1978', 5.9)
# ('Baton Baton Mein', '1979', 7.6)
# ('The Burning Train', '1980', 6.8)
# ('Bewafaa', '2005', 4.6)
# ('Dil Hai Ki Manta Nahin', '1991', 7.4)
# ('Soni', '2018', 7.7)
# ('Prem Rog', '1982', 7.2)
# ('Peepli Live', '2010', 7.4)
# ('Pyar Ka Mandir', '1988', 6.5)
# ('The Warrior', '2001', 6.8)
# ('Aatma', '2013', 3.7)
# ('Revolver Rani', '2014', 4.8)
# ('Ek Chhotisi Love Story', '2002', 2.9)
# ('Rajput', '1982', 6.5)
# ('Super Model', '2013', 2.0)
# ('Amrapali', '1966', 6.7)
# ('Aap Ki Kasam', '1974', 7.0)
# ('Disco Dancer', '1982', 6.4)
# ('Chaahat', '1996', 5.6)
# ('Kammatti Paadam', '2016', 8.1)
# ('Uvaa', '2015', 5.0)
# ('Mumbai 125 KM 3D', '2014', 2.8)
# ('Dhokha', '2007', 6.3)
# ('Teesra Kaun?', '1994', 5.4)
# ('Teree Sang: A Kidult Love Story', '2009', 6.2)
# ('Barsaat Ki Raat', '1960', 7.0)
# ('Yakeen', '2005', 5.2)
# ('Main, Meri Patni... Aur Woh!', '2005', 7.3)
# ('Karam', '2005', 5.6)
# ('Dillagi', '1999', 5.4)
# ('Indrajeet', '1991', 4.7)
# ('Dharmatma', '1975', 6.7)
# ('Mamta', '1966', 7.2)
# ('Dor', '2006', 8.0)
# ('Khilona', '1970', 7.2)
# ('Rough Book', '2016', 7.5)
# ('III Smoking Barrels', '2017', 8.7)
# ('Chatrapathi', '2005', 7.6)
# ('Dil Bole Hadippa!', '2009', 4.6)
# ('Jannat: In Search of Heaven...', '2008', 6.9)
# ('Apoorva Sagodharargal', '1989', 8.3)
# ('Krodhi', '1981', 6.6)
# ('Yeh Hai Jalwa', '2002', 4.8)
# ('Thammudu', '1999', 7.8)
# ('Jurm', '1990', 6.2)
# ('Hotel', '1981', 6.0)
# ('Desh Drohi', '2008', 1.8)
# ('Footsteps in the Dark', '1941', 6.9)
# ('Shastra', '1996', 5.0)
# ('The Shaukeens', '2014', 5.2)
# ('The Great New Wonderful', '2005', 5.7)
# ('Darna Zaroori Hai', '2006', 5.4)
# ('Dharti', '2011', 7.2)
# ('Dil Tera Diwana', '1996', 5.1)
# ('Mangalashtak Once More', '2013', 7.0)
# ('Mahakaal', '1993', 4.5)
# ('Hote Hote Pyar Hogaya', '1999', 5.2)
# ('Nanhe Jaisalmer: A Dream Come True', '2007', 6.1)
# ('Guddu Ki Gun', '2015', 4.8)
# ('Naam', '1986', 7.7)
# ('Baabarr', '2009', 5.1)
# ('Jawani Diwani', '1972', 7.0)
# ('Pitaah', '2002', 6.5)
# ('Naajayaz', '1995', 5.6)
# ('Prem Geet', '1981', 7.8)
# ('Darr @ the Mall', '2014', 5.0)
# ('Laali Ki Shaadi Mein Laaddoo Deewana', '2017', 5.2)
# ('Criminal', '1995', 5.7)
# ('Khoj', '1989', 7.1)
# ('Gemini', '2002', 6.1)
# ('Parvarish', '1977', 7.0)
# ('Gharwali Baharwali', '1998', 4.5)
# ('Hum Hain Rahi Pyar Ke', '1993', 7.4)
# ('Ajooba', '1991', 5.2)
# ('Sehar', '2005', 7.8)
# ('Gallit Gondhal, Dillit Mujra', '2009', 7.5)
# ('Naam Gum Jaayega', '2005', 5.9)
# ('Daayraa', '1996', 7.2)
# ('Bezubaan Ishq', '2015', 4.1)
# ('Daulat Ki Jung', '1992', 6.0)
# ('Zokkomon', '2011', 4.2)
# ('Isi Life Mein...!', '2010', 5.8)
# ('Amrit', '1986', 6.8)
# ('Gaddaar', '1995', 4.3)
# ('23rd March 1931: Shaheed', '2002', 5.1)
# ('Aagey Se Right', '2009', 5.1)
# ('Krishna Cottage', '2004', 5.1)
# ('Ram-Avtar', '1988', 4.5)
# ('Salaakhen', '1998', 5.3)
# ('Pyaar Ishq Aur Mohabbat', '2001', 4.1)
# ('Fight Club: Members Only', '2006', 3.3)
# ('Jodi Breakers', '2012', 3.5)
# ('Jis Desh Men Ganga Behti Hai', '1960', 7.4)
# ('Lakshmi', '2014', 8.1)
# ('Aa Gaya Hero', '2017', 3.7)
# ('Shaan', '1980', 7.1)
# ('Gori Tere Pyaar Mein!', '2013', 5.0)
# ('Veerappan', '2016', 5.2)
# ('Chakravyuh', '2012', 6.9)
# ('Dhaai Akshar Prem Ke', '2000', 3.8)
# ('Chori Chori', '1956', 7.8)
# ('Plan', '2004', 4.3)
# ('Periyanna', '1999', 4.4)
# ('Dil Hai Betaab', '1993', 4.6)
# ('Masoom', '1996', 6.0)
# ('Amanush', '1975', 6.9)
# ('Yeh Mohabbat Hai', '2002', 5.4)
# ('Arpan', '1983', 6.2)
# ('Subedar Joginder Singh', '2018', 7.5)
# ('Bhaag Johnny', '2015', 5.1)
# ('Heer Raanjha', '1970', 7.0)
# ('Fuddu', '2016', 5.6)
# ('Naya Daur', '1957', 8.1)
# ('Papa Kahte Hain', '1996', 5.1)
# ('Chhupa Rustam: A Musical Thriller', '2001', 4.4)
# ('Samarasimha Reddy', '1999', 7.1)
# ('Valley of Flowers', '2006', 7.0)
# ('Roti', '1974', 6.9)
# ('Vedi', '2011', 3.7)
# ('Khuda Kasam', '2010', 4.0)
# ('Mr. Azaad', '1994', 4.1)
# ('Jaanam Samjha Karo', '1999', 4.9)
# ('Satya 2', '2013', 6.0)
# ('Policegiri', '2013', 4.1)
# ('Awaara', '1951', 8.0)
# ('Dilwale', '1994', 5.6)
# ('Chaar Sahibzaade', '2014', 8.3)
# ('Raaz 3: The Third Dimension', '2012', 4.0)
# ('Raja Babu', '1994', 6.4)
# ('Zila Ghaziabad', '2013', 3.6)
# ('Yeshwant', '1997', 7.3)
# ('Aakrosh', '1980', 8.0)
# ('Joru Ka Ghulam', '2000', 5.1)
# ('Koshish', '1972', 8.7)
# ('Satyamev Jayate', '1987', 7.1)
# ('Pukar', '1983', 6.2)
# ('Hey Ram Hamne Gandhi Ko maar Diya', '2018', 8.3)
# ('Ashaant', '1993', 6.3)
# ('Sansar', '1987', 7.0)
# ('Once Upon a Time in Mumbai Dobaara!', '2013', 4.8)
# ('Sharaabi', '1984', 7.4)
# ('Anjali', '1990', 8.3)
# ('Youngistaan', '2014', 5.2)
# ('Phir Se...', '2018', 5.8)
# ('Aashiq', '2001', 3.9)
# ('The Pool', 'I 2007', 7.0)
# ('Agni Sakshi', '1996', 6.1)
# ('Vaalee', '1999', 7.9)
# ('Khan kluay', '2006', 6.2)
# ('Apartment: Rent at Your Own Risk', '2010', 3.4)
# ('Thamizhan', '2002', 5.4)
# ('Aag', '1994', 4.8)
# ('Hello', 'II 2008', 3.4)
# ('Coolie', 'I 1983', 6.7)
# ('Dharam Kanta', '1982', 6.3)
# ('Ab Tak Chhappan 2', '2015', 5.8)
# ('Zindagi 50 50', '2013', 2.8)
# ("Deewaar: Let's Bring Our Heroes Home", '2004', 6.2)
# ('My Friend Ganesha', '2007', 4.9)
# ('I.D.', '2012', 6.9)
# ('Vansh', '1992', 6.1)
# ('Kohram', '1999', 5.4)
# ('Tezaab', '1988', 7.0)
# ('Maatr', '2017', 4.4)
# ('No Problem', 'I 2010', 4.2)
# ('Aankhen', '1993', 6.7)
# ('Dil Hai Tumhaara', '2002', 5.4)
# ('Kyaa Super Kool Hain Hum', '2012', 5.0)
# ('Karamati Coat', '1993', 7.9)
# ('Naqaab', '2007', 5.4)
# ('Mumbai Se Aaya Mera Dost', '2003', 3.4)
# ('Maharathi', '2008', 7.2)
# ('Train Station', 'I 2015', 6.0)
# ('Professor', '1962', 7.0)
# ('Roadside Romeo', '2008', 5.3)
# ('The Wishing Tree', '2017', 5.7)
# ('Gang of Ghosts', '2014', 3.7)
# ('Aa Dekhen Zara', '2009', 5.1)
# ('Singam 2', '2013', 6.3)
# ('LIE', '2017', 5.9)
# ('404: Error Not Found', '2011', 7.2)
# ('Tahkhana', '1986', 5.2)
# ('Masoom', '1983', 8.5)
# ('Aashiqui', '1990', 6.3)
# ('Waqt Ki Awaz', '1988', 6.5)
# ('The Last Lear', '2007', 7.1)
# ('Jajantaram Mamantaram', '2003', 5.7)
# ('Mirch Masala', '1987', 7.8)
# ('Saraswatichandra', '1968', 6.5)
# ('MSG: The Messenger of God', '2015', 6.7)
# ('Pyar Ka Devta', '1990', 4.8)
# ('Saaransh', '1984', 8.2)
# ('Ghulami', '1985', 7.1)
# ('Punjab 1984', '2014', 8.5)
# ('ROAR: Tigers of the Sundarbans', '2014', 5.7)
# ('Kabhie Kabhie', '1976', 7.5)
# ('Besharam', '2013', 3.6)
# ('Yuvvraaj', '2008', 4.2)
# ('Hanuman', '2005', 7.1)
# ('Maanikya', '2014', 6.5)
# ('6-5=2', '2014', 4.8)
# ('Crash Test Aglaé', '2017', 6.5)
# ('Ardh Satya', '1983', 8.2)
# ('Sheshnaag', '1990', 4.8)
# ('Kyo Kii... Main Jhuth Nahin Bolta', '2001', 5.3)
# ('Bas Ek Pal', '2006', 5.9)
# ('Guddu Rangeela', '2015', 5.3)
# ('Jia aur Jia', '2017', 4.9)
# ('Winner', '2003', 6.3)
# ('Lajja', '2001', 6.8)
# ('Zeher', '2005', 5.4)
# ('Hero', 'V 2015', 3.7)
# ('Yeh Dillagi', '1994', 6.6)
# ('Bunty Aur Babli', '2005', 6.2)
# ('Hum Tum Pe Marte Hain', '1999', 5.3)
# ('Azaad', '1978', 7.2)
# ('Hawayein', '2003', 6.0)
# ('Agni Varsha', '2002', 4.9)
# ('Bemisal', '1982', 7.1)
# ('Jal', '2013', 6.7)
# ('The Domino Effect', '2012', 6.2)
# ('Aatank Hi Aatank', '1995', 5.5)
# ('Loafer', '1996', 5.1)
# ('Masti', '2004', 6.2)
# ('Zubeidaa', '2001', 6.2)
# ('Michael Madana Kamarajan', '1990', 8.5)
# ('Raja Jani', '1972', 6.8)
# ('Thikka', '2016', 5.3)
# ('Hero Hindustani', '1998', 4.9)
# ('Honeymoon Travels Pvt. Ltd.', '2007', 6.1)
# ('Shuddhi', '2017', 8.0)
# ('Yateem', '1988', 6.3)
# ('Barah Aana', '2009', 6.9)
# ('Pehla Pehla Pyar', '1994', 5.0)
# ('Dev', '2004', 7.0)
# ('Bahurani', '1989', 6.7)
# ('Hathyar: Face to Face with Reality', '2002', 5.8)
# ('Majunu', '2001', 5.4)
# ('Khiladi 420', '2000', 5.6)
# ('My Birthday Song', '2018', 5.5)
# ('Vaah! Life Ho Toh Aisi!', '2005', 4.4)
# ('Betaab', '1983', 6.7)
# ('Aaina', '1993', 6.0)
# ('Gair', '1999', 3.7)
# ('Mantostaan', '2016', 6.1)
# ('Monsoon', 'I 2015', 3.4)
# ('Saath Saath', '1982', 7.1)
# ('Cape Karma', '2007', 4.5)
# ...
# ('Jaago', '2004', 6.7)
# ('7 1/2 Phere: More Than a Wedding', '2005', 5.3)
# ('Badlapur Boys', '2014', 4.8)
# ('The Bright Day', '2015', 5.8)
# ('Raja', '1995', 5.3)
# ('Prahaar: The Final Attack', '1991', 7.9)
# ('Mashaal', '1984', 7.5)
# ('Haathi Mere Saathi', '1971', 7.0)
# ('Loha', '1997', 5.9)
# ('Hum Kisise Kum Naheen', '1977', 7.2)
# ('Prem', '1995', 4.2)
# ('Game Over', 'IV 2017', 6.9)
# ('Chinar Daastaan-E-Ishq', '2015', 7.1)
# ('Utt Pataang', '2011', 6.0)
# ('Mammo', '1994', 7.7)
# ('Aadamkhor', '2018', 8.1)
# ('Aggar: Passion Betrayal Terror', '2007', 4.3)
# ('Amir Garib', '1974', 6.8)
# ('Mera Damad', '1995', 3.2)
# ('Ghashiram Kotwal', '1976', 6.8)
# ('Govindha Govindha', '1993', 6.8)
# ('Saat Rang Ke Sapne', '1998', 6.0)
# ('Rihaee', '1988', 7.1)
# ('Pagla Kahin Ka', '1970', 7.2)
# ('Oops!', '2003', 3.5)
# ('U R My Jaan', '2011', 6.0)
# ('Identity Card', '2014', 5.9)
# ('Bluff Master', '1963', 6.3)
# ('Mawaali', '1983', 5.4)
# ('Hulla', '2008', 6.4)
# ('Mahathma', '2009', 6.0)
# ('Rain: The Terror Within...', '2005', 3.4)
# ("Say Salaam India: 'Let's Bring the Cup Home'", '2007', 6.5)
# ('Joroo Ka Ghulam', '1972', 7.0)
# ('Hava Aney Dey', '2004', 6.2)
# ('Siskiyaan', '2005', 5.1)
# ('Khatarnaak', '1990', 5.5)
# ('Lok Parlok', '1979', 6.0)
# ('Ya Rab', '2014', 6.2)
# ('Varadanayaka', '2013', 6.2)
# ('Kitaab', '1977', 7.3)
# ('Mujhe Meri Biwi Se Bachaao', '2001', 4.3)
# ('Ehsaas: The Feeling', '2001', 5.5)
# ('Dil Pe Mat Le Yaar!!', '2000', 4.9)
# ('Kismet', '1943', 7.5)
# ('Overnight', '2007', 5.1)
# ('I Am Singh', '2011', 5.2)
# ('Aaj Ki Awaz', '1984', 5.6)
# ('Bhookailas', '1958', 7.3)
# ('Mass', '2004', 6.3)
# ('Sohni Mahiwal', '1984', 6.1)
# ('Kya Yehi Pyaar Hai', '2002', 3.8)
# ('Tohfa', '1984', 5.7)
# ('Badal', '2000', 4.9)
# ('Veera Parampare', '2010', 7.0)
# ('Naukri', '1978', 7.0)
# ('Ghar Ka Chiraag', '1989', 5.9)
# ('Aamne - Saamne', '1967', 6.3)
# ('Vetri Vizha', '1989', 7.1)
# ('Jagriti', '1956', 7.1)
# ('Moksha: Salvation', '2001', 6.4)
# ('Hyderabad Blues 2', '2004', 6.1)
# ('Rules: Pyaar Ka Superhit Formula', '2003', 6.4)
# ('Bandhe Haath', '1973', 6.2)
# ('Pratikar', '1991', 5.4)
# ('Saraswathi Sabatham', '1966', 7.6)
# ('Kaafiron Ki Namaaz', '2013', 7.0)
# ('Encounter: The Killing', '2002', 6.7)
# ('Faryad moorcheha', '2006', 6.2)
# ('Oass', '2012', 6.7)
# ('Taqdeer', '1983', 5.8)
# ('Mr. Bechara', '1996', 5.5)
# ('Love Khichdi', '2009', 5.8)
# ('Surakksha', '1979', 7.2)
# ('Wan Pipel', '1976', 6.9)
# ('Life Ki Toh Lag Gayi', '2012', 5.8)
# ('Pehchaan: The Face of Truth', '2005', 6.1)
# ('Raat Gayi, Baat Gayi?', '2009', 6.3)
# ('Souryam', '2008', 6.0)
# ('Bas Itna Sa Khwaab Hai...', '2001', 3.9)
# ('Team: The Force', '2009', 4.3)
# ('Achhut Kanya', '1936', 7.2)
# ('Ishk Actually', '2013', 2.6)
# ('Partha', '2003', 7.2)
# ('Bindhaast', '1999', 7.1)
# ('Daisy', '1988', 7.3)
# ('Bombay 405 Miles', '1980', 7.2)
# ('Mumbai Cha Raja', '2012', 6.6)
# ('Beti No. 1', '2000', 3.7)
# ('Dharm Adhikari', '1986', 6.1)
# ('Jhanak Jhanak Payal Baaje', '1955', 7.2)
# ('Halla Gulla', '2015', 5.7)
# ('Fruit & Nut', '2009', 3.1)
# ('Janwar', '1965', 7.0)
# ('Kadamban', '2017', 5.3)
# ('Desamuduru', '2007', 6.1)
# ('Rang', '1993', 5.0)
# ('Akhiyon Se Goli Maare', '2002', 5.0)
# ('Kroadh', '1990', 5.2)
# ('Love in Simla', '1960', 7.3)
# ('Kab? Kyoon? Aur Kahan?', '1970', 7.2)
# ('Mohan Joshi Hazir Ho!', '1984', 7.1)
# ('Sheen', '2004', 6.2)
# ('Kasauti', '1974', 6.3)
# ('Gauri: The Unborn', '2007', 4.5)
# ('Gladiatorerna', '1969', 6.8)
# ('Garam Masala', '1972', 6.1)
# ('Teen Thay Bhai', '2011', 4.3)
# ('Mrugaraaju', '2001', 4.4)
# ('Aakhari Decision', '2010', 6.0)
# ('Fear', 'I 2007', 4.0)
# ('Frozen', '2007', 7.0)
# ('27 Down', '1974', 7.6)
# ('Laawaris', '1999', 4.3)
# ('Devdas', '1936', 6.4)
# ('Swami Dada', '1982', 6.4)
# ('Phool Aur Angaar', '1993', 6.8)
# ('Vinashak - Destroyer', '1998', 5.2)
# ('Waaris', '1988', 6.7)
# ('Toofan', 'I 1989', 4.8)
# ('Hello Mumbai: Salaam Mumbai', '2016', 4.2)
# ('Apna Sapna Money Money', '2006', 5.3)
# ('Hum Hain Kamaal Ke', '1993', 5.7)
# ('The Hangman', '2005', 7.0)
# ('Chala Mussaddi - Office Office', '2011', 6.0)
# ('Duet', '1994', 6.6)
# ('Meera', '1979', 7.3)
# ('Disha', '1990', 7.2)
# ('Bhageeratha', '2005', 5.6)
# ('Cycle Kick', '2011', 6.9)
# ('Andhrudu', '2005', 6.6)
# ('The 20 Questions Murder Mystery', '1950', 6.3)
# ('Three: Love, Lies, Betrayal', '2009', 5.8)
# ('Nalla', '2004', 7.2)
# ('Drohi', '1992', 6.1)
# ('Aadmi Ki Aurat Aur Anya Kahaniya', '2009', 7.8)
# ('Allari Ramudu', '2002', 4.5)
# ('Hastey Hastey Follow Your Heart', '2008', 2.2)
# ('Ankahee', '1985', 7.7)
# ('Bandhan', 'I 1969', 7.0)
# ('The Gentleman', '1994', 5.8)
# ('Hollywood', '2003', 7.1)
# ('Luv U Soniyo', '2012', 5.5)
# ('Musafir', '1957', 7.6)
# ('Yagnam', '2004', 6.2)
# ('Is Raat Ki Subah Nahin', '1996', 7.1)
# ('Paromitar Ek Din', '2000', 7.2)
# ('Chota Jadugar', '2003', 3.9)
# ('Stumped', '2003', 3.8)
# ('Missing on a Weekend', '2016', 4.6)
# ('Detective Naani', '2009', 6.4)
# ('Khoya', '2015', 8.2)
# ('Rowdy Inspector', '1992', 7.5)
# ('Yaara Silly Silly', '2015', 5.7)
# ('Humko Tumse Pyaar Hai', '2006', 5.1)
# ('Haan Maine Bhi Pyaar Kiya', '2002', 4.1)
# ('Bin Bulaye Baraati', '2011', 3.8)
# ('Bees Saal Baad', '1988', 5.2)
# ('Aghaat', '1985', 7.2)
# ('Chhal', '2002', 6.2)
# ('Saaz', '1997', 7.2)
# ('Sharada', '1957', 6.5)
# ('Pankh', '2010', 4.2)
# ('Samudram', '1999', 6.7)
# ('Toh Baat Pakki!', '2010', 5.3)
# ('Zindaggi Rocks', '2006', 4.2)
# ('Victoria No. 203: Diamonds Are Forever', '2007', 3.7)
# ('Mai', '2013', 6.9)
# ('Daal Mein Kuch Kaala Hai', '2012', 4.1)
# ('The Rally', '2017', 8.5)
# ('Coffee Bloom', '2015', 6.5)
# ('Naya Din Nai Raat', '1974', 7.1)
# ('Naukari', '1954', 7.8)
# ('Once Upon a Time in Bihar', '2015', 7.2)
# ('House No. 44', '1955', 7.4)
# ("Vaibhav Sethia: Don't", '2018', 6.9)
# ('Adharm', '1992', 5.2)
# ('Jeevan Dhaara', '1982', 7.3)
# ('Showbiz', '2007', 4.0)
# ('Andarivaadu', '2005', 4.4)
# ('Aadmi', '1993', 6.5)
# ('Sadda Adda', '2011', 7.2)
# ('Jaan Tere Naam', '1992', 6.4)
# ('Loafer', '1973', 7.1)
# ('Jigar', '1992', 4.8)
# ('Antarnaad', '1991', 5.7)
# ('Pazhani', '2008', 3.3)
# ('Kis Kis Ki Kismat', '2004', 2.6)
# ('Sapnon Ka Saudagar', '1968', 7.4)
# ('Shaheed', '1948', 6.9)
# ('Khandhar', '1984', 7.2)
# ('Parineeta', '1953', 7.5)
# ('Chase', 'I 2010', 4.8)
# ('Dahek: A Burning Passion', '1999', 5.8)
# ('Palkon Ki Chhaon Mein', '1977', 7.7)
# ('Sardari Begum', '1996', 6.9)
# ('New Delhi', '1956', 7.5)
# ('Gudgudee', '1997', 4.6)
# ('Kalaignan', '1993', 6.4)
# ('Mujhe Jeene Do', '1963', 7.9)
# ('Hotel Very Welcome', '2007', 6.5)
# ('Ab Ayega Mazaa', '1984', 6.8)
# ('Shadow', 'I 2009', 5.0)
# ('Aashiq Hoon Baharon Ka', '1977', 5.6)
# ('A Film by Aravind', '2005', 7.1)
# ('Subhash Chandra Bose', '2005', 3.0)
# ('Achanak', '1973', 7.0)
# ('Jogan', '1950', 7.4)
# ('Duvidha', '1973', 7.2)
# ('Jaan', '1996', 4.0)
# ('Mera Gaon Mera Desh', '1971', 7.2)
# ('Marte Dam Tak', '1987', 6.0)
# ('Banjaran', '1991', 5.3)
# ('Nagina', '1986', 6.6)
# ('7 Welcome to London', '2012', 5.0)
# ('Yatra', '2006', 6.1)
# ('Inspector Balram', '1991', 6.9)
# ('Baat Bann Gayi', '2013', 5.3)
# ('Go', '2007', 2.7)
# ('Do Jasoos', '1975', 6.2)
# ('Drishti', '1990', 7.3)
# ('Vazhve Mayam', '1982', 6.9)
# ('Safari', '1999', 4.6)
# ('Chaahat Ek Nasha...', '2005', 4.0)
# ('Dadar Kirti', '1980', 7.2)
# ('Hari-Bhari', '2000', 7.1)
# ('Naseem', '1995', 7.6)
# ('Satyameva Jayate', '2000', 5.3)
# ('Dekh Tamasha Dekh', '2014', 6.1)
# ('Attahaasa', '2013', 7.1)
# ('Veettilekkulla Vazhi', '2011', 6.8)
# ('Chhailla Babu', '1977', 7.0)
# ('Balwaan', '1992', 4.4)
# ('Bandh Darwaza', '1990', 5.1)
# ('Vijaypath', '1994', 5.0)
# ('Mujrim', 'I 1989', 5.8)
# ('Love You Hamesha', '2001', 5.0)
# ('Majhli Didi', '1967', 7.7)
# ('The Film Emotional Atyachar', '2010', 6.0)
# ('Chann Pardesee', '1980', 8.2)
# ('Alavuddinum Athbutha Vilakkum', '1979', 6.8)
# ('Bach ke Zara', '2008', 2.9)
# ('Raghavendra', '2003', 5.0)
# ('Ikke Pe Ikka', '1994', 4.5)
# ('Man On Mission Jaanbaaz', '2005', 8.3)
# ('Ek Hota Vidushak', '1992', 7.9)
# ('Gangoobai', '2013', 7.5)
# ('Anjaam', '2007', 6.2)
# ('Shriman Shrimati', '1982', 6.5)
# ('Maan Gaye Mughall-E-Azam', '2008', 3.1)
# ('Chudail Story', '2016', 2.9)
# ('Do Kaliyaan', '1968', 6.2)
# ('Yeh Dil Aashiqanaa', '2002', 4.4)
# ('Julie', '1975', 6.1)
# ('Sweetiee Weds NRI', '2017', 3.7)
# ('Sapne Saajan Ke', '1992', 3.4)
# ('Barefoot to Goa', '2015', 5.8)
# ('Jugaad', '2009', 5.2)
# ('Tarpan The Absolution', '1995', 7.4)
# ('Zara Si Zindagi', '1983', 7.7)
# ('Station', 'I 2014', 7.6)
# ('Vakratunda Mahakaaya', '2013', 7.5)
# ('Chhodo Kal Ki Baatein', '2012', 7.1)
# ('Vihir', '2009', 7.2)
# ('Anjaane: The Unkown', '2005', 4.1)
# ('Via Darjeeling', '2008', 5.4)
# ('Monica', '2011', 5.6)
# ('Afsana Dilwalon Ka', '2001', 3.6)
# ('Khap', '2011', 5.8)
# ('Kudiyon Ka Hai Zamaana', '2006', 3.6)
# ('Mera Dil Leke Dekho', '2006', 7.1)
# ('Ugly Aur Pagli', '2008', 3.8)
# ('Thayillamal Nannilai', '1979', 6.7)
# ("Jo Dooba So Paar: It's Love in Bihar!", '2011', 5.8)
# ('Anand Math', '1952', 7.5)
# ('Grahan', '2001', 5.2)
# ('Genesis', '1986', 7.3)
# ('Ab Dilli Dur Nahin', '1957', 7.6)
# ('Jagir', '1984', 6.5)
# ('Bol Radha Bol', '1992', 6.1)
# ('Swarg', '1990', 6.7)
# ('Bunny', '2005', 5.8)
# ('Be-Careful', '2011', 3.2)
# ('Prem Kaa Game', '2010', 3.6)
# ('Dilwale:The Brave Heart', '2001', 9.3)
# ('Lezioni di volo', '2007', 6.3)
# ('Damul', '1985', 7.6)
# ('Sadiyaan: Boundaries Divide... Love Unites', '2010', 4.5)
# ('Supari', '2003', 4.5)
# ('Uttar Dakshin', '1987', 4.8)
# ('Radio: Love on Air', '2009', 3.1)
# ('Gospel Movie: Who Is My Lord', '2017', 9.1)
# ('Badmashiyaan', '2015', 4.7)
# ('Jigyaasa', '2006', 5.1)
# ('Oraalppokkam', '2014', 8.1)
# ('Life Mein Kabhie Kabhiee', '2007', 6.2)
# ('Chorus', '1975', 7.5)
# ('Zaalim', '1994', 5.8)
# ('Ghar Ghar Ki Kahani', '1988', 5.0)
# ('Tum Se Achcha Kaun Hai', '2002', 4.7)
# ('Maidan-E-Jung', '1995', 5.4)
# ('Budtameez', '1966', 7.4)
# ('Suno Sasurjee', '2004', 2.6)
# ('Paisa Vasool', '2004', 4.3)
# ('Pasand Apni Apni', '1983', 6.6)
# ('Soch Lo', '2010', 6.6)
# ('Prematho Raa', '2001', 5.9)
# ('The Train', '2011', 4.5)
# ('Sankham', '2009', 5.3)
# ('Subah Subah', '1983', 8.1)
# ('Hari Om', '2004', 7.2)
# ('Walkaway', '2010', 7.6)
# ('Veer Savarkar', '2001', 7.7)
# ('Chintu Ji', '2009', 5.8)
# ('Do Dooni Char', '1968', 7.2)
# ('Future to Bright Hai Ji', '2012', 6.3)
# ('Chandu', '2002', 7.3)
# ('Heeralal Pannalal', '1978', 6.6)
# ('Mohandas', '2009', 6.6)
# ('Awara Baap', '1985', 4.9)
# ('Sivappathikaaram', '2006', 5.5)
# ('Naughty Boy', '1962', 5.7)
# ('Veerabhadra', '2005', 2.8)
# ('Madly Bangali', '2009', 6.9)
# ('Muqabla', '1993', 4.5)
# ('Sachaa Jhutha', '1970', 6.8)
# ('Koi Mere Dil Mein Hai', '2005', 4.8)
# ('Jung', '1996', 4.1)
# ('Mohabbat', '1997', 5.4)
# ('Chhota Bheem and the Curse of Damyaan', '2012', 6.2)
# ('Noorie', '1979', 6.1)
# ('88 Antop Hill', '2003', 4.6)
# ('Shanti Kranti', '1991', 6.8)
# ('Eduruleni Manishi', '2001', 4.4)
# ('Curry Munchers', '2011', 5.2)
# ('Jaali Note', '1960', 7.5)
# ('Ek Din Achanak', '1989', 6.9)
# ('Goopi Gawaiya Bagha Bajaiya', '2013', 7.9)
# ('Thodasa Roomani Ho Jaayen', '1990', 7.1)
# ('Jo Hum Chahein', '2011', 5.4)
# ("Shahrukh Bola 'Khoobsurat Hai Tu'... And She Believed in It", '2010', 6.2)
# ('Chhodon Naa Yaar', '2007', 4.6)
# ('Bhavni Bhavai', '1980', 7.5)
# ('Kajarya', '2013', 6.6)
# ('Shaadi Ka Laddoo', '2004', 5.3)
# ('Thee', '1981', 6.8)
# ('God Only Knows!', '2007', 5.8)
# ('Nandhi', '2002', 7.4)
# ('Uski Roti', '1970', 6.8)
# ('Ravoyi Chandamama', '1999', 4.9)
# ('Pyar Jhukta Nahin', '1985', 6.5)
# ('Haatim Tai', '1990', 5.6)
# ('Raghuveer', '1995', 4.2)
# ('Naseeb Apna Apna', '1986', 5.5)
# ('50 Lakh', '2007', 6.7)
# ('Gooli', '2008', 6.9)
# ('Popcorn Khao! Mast Ho Jao', '2004', 4.1)
# ('Sau Jhooth Ek Sach', '2004', 7.3)
# ('Sanshodhan', '1996', 7.6)
# ('Kiccha Huccha', '2010', 6.2)
# ('Meri Biwi Ki Shaadi', '1979', 6.6)
# ('The Silent Heroes', '2015', 6.7)
# ('Raakh: A Poem Masked in Blood', '2007', 3.6)
# ('Uyirile Kalanthathu', '2000', 7.8)
# ('C U at 9', '2005', 4.2)
# ('Umar', '2006', 5.7)
# ('Neel Kamal', '1947', 7.5)
# ('Aashiqui.in', '2011', 3.7)
# ('Dr. Kotnis Ki Amar Kahani', '1946', 7.2)
# ('Azaad', '2000', 6.2)
# ('Ginny Aur Johny', '1976', 7.4)
# ('5 Ghantey Mien 5 Crore', '2012', 5.2)
# ('Hip Hip Hurray', '1984', 7.5)
# ('Killer', '1992', 6.4)
# ('Enakkul Oruvan', '1984', 6.9)
# ('Diksha', '1991', 7.0)
# ('Kaisay Kahein...', '2007', 6.4)
# ('Shreemaan Aashique', '1993', 4.7)
# ('Tahalka', '1992', 5.6)
# ('Barood', '1998', 5.5)
# ('Aag Hi Aag', '1987', 5.3)
# ('Sins', '2005', 4.2)
# ('Elaan-E-Jung', '1989', 5.6)
# ('Khwaabb', '2014', 5.6)
# ('Chupke Se', '2003', 5.5)
# ('Man on Mission Fauladi', '2004', 9.6)
# ('The Great Indian Butterfly', '2007', 6.2)
# ('Padatik', '1973', 7.1)
# ('Phir Kabhi', '2008', 7.0)
# ('Love at Times Square', '2003', 3.6)
# ('Straight', 'II 2009', 5.9)
# ('Lakhon Ki Baat', '1984', 6.8)
# ('Stoovertpuram Police Station', '1991', 6.7)
# ('Dil Ka Kya Kasoor', '1992', 6.0)
# ('Daag: The Fire', '1999', 4.8)
# ('Zapatlela', '1993', 7.5)
# ('Arjun Pandit', '1999', 5.3)
# ('Khokababu', '2012', 5.7)
# ('Muskaan', '2004', 4.5)
# ('Aamaar Bhuvan', '2002', 8.0)
# ('Ghar Grihasti', '2004', 5.6)
# ('Mohre', '1987', 5.5)
# ('Madholal Keep Walking', '2009', 6.7)
# ('Meerabai Not Out', '2008', 4.0)
# ('Payback', '2010', 5.5)
# ('Lal Darja', '1997', 7.0)
# ('Aavida Maa Aavide', '1998', 6.4)
# ('Bolo Raam', '2009', 5.2)
# ('Damadamm!', '2011', 4.2)
# ('Kucch Luv Jaisaa', '2011', 4.4)
# ('Hum Dum', '2005', 7.0)
# ('Kalloori Vaasal', '1996', 5.5)
# ('Visakha Express', '2008', 4.9)
# ('Edegarike', '2012', 7.3)
# ('Ranga S.S.L.C', '2004', 6.3)
# ('Sazaye Maut', '1981', 7.4)
# ('Mr. Theertha', '2010', 7.0)
# ('Sahi Dhandhe Galat Bande', '2011', 4.8)
# ('Love Birds', '1997', 5.1)
# ('Yaad Rakhegi Duniya', '1992', 7.6)
# ('Narasimha', '1991', 5.7)
# ('Maa', 'I 1992', 6.2)
# ('Ankhiyon Ke Jharokhon Se', '1978', 7.1)
# ('Ab Ke Baras', '2002', 3.4)
# ('Ajay', '1996', 3.9)
# ('Ek Duuje Ke Liye', '1981', 7.5)
# ('Ganga', '2006', 5.0)
# ('Rudranetra', '1989', 7.0)
# ('Satrangee Parachute', '2011', 5.5)
# ('Pestonjee', '1988', 7.1)
# ('Once We Were Strangers', '1997', 6.7)
# ('Oru Kaidhiyin Diary', '1985', 7.0)
# ('Kairee', '1999', 7.7)
# ('Morning Walk', '2009', 4.6)
# ('Miss India: The Mystery', '2003', 3.6)
# ('Phir Subha Hogi', '1958', 7.7)
# ('Ooops a Desi', '2013', 7.0)
# ('Snip!', '2000', 6.3)
# ('The Prince of Light', '2000', 7.0)
# ('Doodh Ka Karz', '1990', 5.0)
# ('Izzat', '1968', 7.2)
# ('Dushmani: A Violent Love Story', '1995', 5.2)
# ('Teri Meherbaniyan', '1985', 5.3)
# ('Dance of the Wind', '1997', 6.6)
# ('Mumbai Matinee', '2003', 5.3)
# ('Mahakali Ka Insaaf', '2001', 9.6)
# ('Ek Din 24 Ghante', '2003', 4.0)
# ('The Taste of Relation', '2009', 7.2)
# ('Bhootnath', '1963', 6.4)
# ('White Rainbow', '2004', 7.2)
# ('Ottran', '2003', 5.7)
# ("Let's Enjoy", '2004', 6.6)
# ('Hamari Bahu Alka', '1982', 6.8)
# ('Masala Republic', '2014', 5.4)
# ('Bagh Bahadur', '1989', 7.9)
# ('Target', '1995', 7.8)
# ('Ghatotkachudu', '1995', 7.2)
# ('Mohabbat', '1985', 5.9)
# ('Raja Ki Ayegi Baraat', '1997', 3.8)
# ('Captain Prabhakaran', '1991', 7.1)
# ('Nigahen: Nagina Part II', '1989', 5.2)
# ('Sathyam', '2008', 5.2)
# ('Impatient Vivek', '2011', 2.3)
# ('Life! Camera Action...', '2012', 6.0)
# ('Daayen Ya Baayen', '2010', 6.1)
# ('Shuttlecock Boys', '2011', 5.9)
# ('Surkhaab', '2014', 6.5)
# ('Sirf....: Life Looks Greener on the Other Side', '2008', 6.0)
# ('Laadli Laila', '2009', 5.9)
# ('Siddharth: The Prisoner', '2009', 6.6)
# ('Kal: Yesterday and Tomorrow', '2005', 6.4)
# ('Thirupathi', '2006', 6.6)
# ('Tandoori Love', '2008', 5.2)
# ("It's Breaking News", '2007', 5.5)
# ('Maya Darpan', '1972', 6.9)
# ('Kaadhal Parisu', '1987', 6.1)
# ('Boss', '2006', 4.4)
# ('Hei ma lai ah sing', '2005', 3.8)
# ('Ashwamedham', '1992', 7.2)
# ('Kvelaferi kargad iqneba', '2009', 6.0)
# ('Seema Simham', '2002', 5.1)
# ('Angel', 'I 2011', 6.6)
# ('Junglee', '1961', 7.3)
# ('Phool Bane Angaarey', '1991', 4.9)
# ('Fakira', '1976', 6.5)
# ('Maa Tujhhe Salaam', '2002', 3.5)
# ('Le Halua Le', '2012', 6.0)
# ('Shohrat the Trap', '2018', 6.5)
# ('The Untitled Kartik Krishnan Project', '2010', 6.4)
# ('Chettaniki Kallu Levu', '1981', 7.8)
# ('Dansh', '2005', 7.2)
# ('Ram Raaj', '2008', 7.5)
# ('Aaj Ka Arjun', '1990', 4.7)
# ('Goa Dalli CID 999', '1968', 8.5)
# ('Military Officer', '1998', 9.4)
# ('Man on Mission Taqatwar', '2005', 9.5)
# ('Raasaiyya', '1995', 5.2)
# ('Finding Preet', '2006', 5.0)
# ('Ek Hi Raasta', '1993', 3.6)
# ('Mehndi', '1998', 3.5)
# ('Raja Aur Rangeeli', '1996', 9.0)
# ('Thoongathey Tambi Thoongathey', '1983', 7.0)
# ('Bewafa Sanam', '1995', 6.4)
# ('Geet Gaata Chal', '1975', 7.7)
# ('Allah-Rakha', '1986', 6.2)
# ('Anari', '1993', 4.7)
# ('Come December', '2006', 5.7)
# ('Kala Jigar', '1939', 3.3)
# ('Kanoon', '1994', 3.2)

# %%
def q2_grader(q2):
  result = pd.read_sql_query(q2, conn)
  return result.shape == (3473, 3) and result['title'][0]=='Mowgli'
print(q2_grader(q2))
# Out:
# True

# %% [markdown]
# ## 3. Write query to get title of first movie in movie table sorted by year in ascending order

# %%
q3 = "select title from Movie order by year asc limit 1"
cursor.execute(q3)
res3=cursor.fetchone()
print("first movie after sort: ",res3[0])
# Out:
# first movie after sort:  Alam Ara

# %%
def q3_grader(q3):
  result = pd.read_sql_query(q3, conn)
  return result['title']=='Alam Ara'
print(q3_grader(q3))
# Out:
# 0    True
# Name: title, dtype: bool

# %% [markdown]
# ## 4. Write query to get the very first year in which Devdas movie was released

# %%
q4 = "select title, min(year) from movie where title='Devdas'"
cursor.execute(q4)
res4=cursor.fetchone()
print("movie ",res4[0],"year ",res[1])
# Out:
# movie  Devdas year  2011

# %%
def q4_grader(q4):
  result = pd.read_sql_query(q4, conn)
  return result['year']=='1936'
print(q4_grader(q4))
# Out:
# 0    True
# Name: year, dtype: bool

# %% [markdown]
# ## 5. Write query to get the number of movies released in 2018

# %%
q5 = "select count(*) from Movie where year=2018"
cursor.execute(q5)
res=cursor.fetchone()
print("Number of movies in 2018: ",res[0])
# Out:
# Number of movies in 2018:  93

# %%
def q5_grader(q5):
  result = pd.read_sql_query(q5, conn)
  return result.iloc[0, 0] == 93
print(q5_grader(q5))
# Out:
# True

# %% [markdown]
# ## 6. Write query to get the title of the movie with most number of votes in 2012

# %%
q6 = "select title from Movie where year=2012 order by num_votes desc limit 1 "
cursor.execute(q6)
res6=cursor.fetchone()
print("Most rated movie in 2012:",res6[0])
# Out:
# Most rated movie in 2012: The Avengers

# %%
def q6_grader(q6):
  result = pd.read_sql_query(q6, conn)
  return result["title"]=="The Avengers"
print(q6_grader(q6))
# Out:
# 0    True
# Name: title, dtype: bool

# %% [markdown]
# ## 7. Write SQL query to find all the unique movie titles released in 2018

# %%
q7 = "SELECT DISTINCT title FROM Movie WHERE year = 2018"
cursor.execute(q7)
res7=cursor.fetchall()

print("Unique movies released in 2018:")
for re in res7:
    print(re[0])
# Out:
# Unique movies released in 2018:
# Mowgli
# Ocean's Eight
# Tomb Raider
# Tumbbad
# Kedarnath
# Andhadhun
# Rajma Chawal
# Manto
# Stree
# Thugs of Hindostan
# Badhaai Ho
# Hotel Mumbai
# Jalebi
# Manmarziyaan
# Pataakha
# Sanju
# Karwaan
# Mitron
# Padman
# Padmaavat
# Raazi
# Lust Stories
# Love Sonia
# Batti Gul Meter Chalu
# Loveyatri
# Love Per Square Foot
# Sui Dhaaga: Made in India
# FryDay
# Bhavesh Joshi Superhero
# Sonu Ke Titu Ki Sweety
# Satyameva Jayate
# Race 3
# Parmanu: The Story of Pokhran
# Dhadak
# Happy Phirr Bhag Jayegi
# Laila Majnu
# Aiyaary
# Baazaar
# Raid
# Soorma
# Veere Di Wedding
# Dil Juunglee
# Halkaa
# Welcome to New York
# Hichki
# Kaalakaandi
# 102 Not Out
# Baaghi 2
# Namaste England
# Nanu Ki Jaanu
# Mard Ko Dard Nahin Hota
# Hate Story IV
# Bhaiaji Superhit
# Paltan
# Yamla Pagla Deewana Phir Se...
# Phamous
# Nawabzaade
# Once Again
# Kuchh Bheege Alfaaz
# Angrezi Mein Kehte Hain
# Bioscopewala
# 3 Storeys
# Saheb Biwi Aur Gangster 3
# Teri Bhabhi Hai Pagle
# Vishwaroopam 2
# Helicopter Eela
# Vodka Diaries
# High Jack
# Lupt
# Hope Aur Hum
# Silvat
# Daas Dev
# 1921
# Kaashi in Search of Ganga
# Meri Nimmo
# Veerey Ki Wedding
# Khajoor Pe Atke
# Teen Aur Aadha
# The Dark Side of Life: Mumbai City
# Baarish Aur Chowmein
# Soni
# Subedar Joginder Singh
# Hey Ram Hamne Gandhi Ko maar Diya
# Phir Se...
# My Birthday Song
# T for Taj Mahal
# Nirdosh
# Haseena
# Leera the Soulmate
# Shaadi Teri Bajayenge Hum Band
# Aadamkhor
# Vaibhav Sethia: Don't
# Shohrat the Trap

# %%
def q7_grader(q7):
  result = pd.read_sql_query(q7, conn)
  return result.shape==(93, 1)
print(q7_grader(q7))
# Out:
# True

# %% [markdown]
# ## 8. Write SQL query to get total number of movies released between 2017 (inclusive) and 2018 (inclusive)

# %%
q8 = "select count(*) from Movie where year between 2017 and 2018"
cursor.execute(q8)
res8=cursor.fetchone()
print("Number of movies from 2017 to 2018: ",res8[0])
# Out:
# Number of movies from 2017 to 2018:  211

# %%
def q8_grader(q8):
  result = pd.read_sql_query(q8, conn)
  return result.iloc[0, 0] == 211
print(q8_grader(q8))
# Out:
# True

# %% [markdown]
# ## 9. Write SQL query to find the year in which maximum number of movies released

# %%
q9 = "SELECT year, COUNT(*) AS movie_count FROM Movie GROUP BY year ORDER BY movie_count DESC LIMIT 1"
cursor.execute(q9)
res9=cursor.fetchone()
print("maximum movies released year: ",res9[0])
# Out:
# maximum movies released year:  2005

# %%
def q9_grader(q9):
  result = pd.read_sql_query(q9, conn)
  return result["year"][0]=="2005"
print(q9_grader(q9))
# Out:
# True

# %% [markdown]
# ## 10. Write SQL query to find the title of the movie with rating>9.5 and number of votes > 90

# %%
q10 = "select title  from Movie where rating >9.5 and num_votes >90 "
cursor.execute(q10)
res10=cursor.fetchall()
print("movies with rating >9.5 and num_votes > 90: ")
for res in res10:
  print(res[0])
# Out:
# movies with rating >9.5 and num_votes > 90:
# Man on Mission Fauladi

# %%
def q10_grader(q10):
  result = pd.read_sql_query(q10, conn)
  return result["title"][0]=="Man on Mission Fauladi"
print(q10_grader(q10))
# Out:
# True

# %% [markdown]
# ## 11. Write SQL query to find the number of movies which has the word 'Dilwale' in their title

# %%
q11 = "SELECT COUNT(*) AS movie_count FROM Movie WHERE title LIKE '%Dilwale%'"
cursor.execute(q11)
res11=cursor.fetchone()
print("Number of movies with word Dilwale: ",res11[0])
# Out:
# Number of movies with word Dilwale:  4

# %%
def q11_grader(q11):
  result = pd.read_sql_query(q11, conn)
  return result.iloc[0, 0] == 4
print(q11_grader(q11))
# Out:
# True

# %% [markdown]
# ## 12. Write nested SQL query to find the CID of country which produced most number of movies

# %%
q12 = """SELECT CID FROM Country WHERE CID = (
    SELECT CID
    FROM M_country
    GROUP BY CID
    ORDER BY COUNT(*) DESC
    LIMIT 1
)
"""
cursor.execute(q12)
res12=cursor.fetchone()
print("CID of country which produced most number of movies: ",res12[0])
# Out:
# CID of country which produced most number of movies:  2

# %%
def q12_grader(q12):
  result = pd.read_sql_query(q12, conn)
  return result.iloc[0]==2.0
print(q12_grader(q12))
# Out:
# CID    True
# Name: 0, dtype: bool

# %% [markdown]
# ## 13. Write nested SQL query to the country which produced most number of movies (use both Courty table and M_Country table)

# %%
q13 = """SELECT C.Name
FROM Country C
WHERE C.CID = (
    SELECT MC.CID
    FROM M_Country MC
    GROUP BY MC.CID
    ORDER BY COUNT(MC.MID) DESC
    LIMIT 1
);
"""
cursor.execute(q13)
res14=cursor.fetchone()
print("country which produced most number of movies :",res14[0])
# Out:
# country which produced most number of movies : India

# %%
def q13_grader(q13):
  result = pd.read_sql_query(q13, conn)
  return result.iloc[0, 0] == "India"
print(q13_grader(q13))
# Out:
# True

# %% [markdown]
# ## 14. Write SQL query to get the year and number of movies per year having number of movies per year is greater than 100

# %%
q14 = """SELECT year, COUNT(*) AS num_movies
FROM Movie
GROUP BY year
HAVING COUNT(*) > 100
ORDER BY num_movies DESC;
"""
cursor.execute(q14)
res14=cursor.fetchall()
for re in res14:
  print("year:",re[0],"number of movies: ",re[1])
# Out:
# year: 2005 number of movies:  128
# year: 2013 number of movies:  127
# year: 2017 number of movies:  118
# year: 2016 number of movies:  118
# year: 2014 number of movies:  118
# year: 2010 number of movies:  117
# year: 2015 number of movies:  109
# year: 2011 number of movies:  109
# year: 2012 number of movies:  108
# year: 2007 number of movies:  104
# year: 2008 number of movies:  103
# year: 2004 number of movies:  103
# year: 2003 number of movies:  101

# %%
def q14_grader(q14):
  result = pd.read_sql_query(q14, conn)
  return result.shape==(13,2)
print(q14_grader(q14))
# Out:
# True

# %% [markdown]
# ## 15. Write SQL query to get the Name and Language ID (LAID) corresponding to Malayalam language

# %%
q15 = """select Name,LAID from Language
 where Name='Malayalam'"""

cursor.execute(q15)
res15=cursor.fetchone()
print(" Name : ",res15[0],"LAID: ",res15[1])
# Out:
#  Name :  Malayalam LAID:  19

# %%
def q15_grader(q15):
  result = pd.read_sql_query(q15, conn)
  print(result)
  return result[["Name", "LAID"]].values.tolist() == [['Malayalam', 19]]
print(q15_grader(q15))
# Out:
#    index       Name  LAID
# 0     19  Malayalam    19
# True

# %% [markdown]
# ## 16. Write SQL query to do inner join with movie table and M_Language table with MID colums

# %%
q16 = """SELECT M.MID, M.Title, ML.LAID
FROM Movie M
INNER JOIN M_Language ML ON M.MID = ML.MID;
"""
cursor.execute(q16)
res16=cursor.fetchall()
for i in res16:
  print(i)
# Out:
# ('tt2388771', 'Mowgli', 0)
# ('tt5164214', "Ocean's Eight", 0)
# ('tt1365519', 'Tomb Raider', 0)
# ('tt0848228', 'The Avengers', 0)
# ('tt8239946', 'Tumbbad', 1)
# ('tt7027278', 'Kedarnath', 2)
# ('tt3498820', 'Captain America: Civil War', 0)
# ('tt8108198', 'Andhadhun', 2)
# ('tt3741834', 'Lion', 0)
# ('tt6747420', 'Rajma Chawal', 2)
# ('tt1981128', 'Geostorm', 0)
# ('tt1010048', 'Slumdog Millionaire', 0)
# ('tt1190080', '2012', 0)
# ('tt3726012', 'Mastizaade', 2)
# ('tt0075860', 'Close Encounters of the Third Kind', 0)
# ('tt6923462', 'Manto', 2)
# ('tt0454876', 'Life of Pi', 0)
# ('tt1606378', 'A Good Day to Die Hard', 0)
# ('tt2120120', 'Pixels', 0)
# ('tt8108202', 'Stree', 2)
# ('tt5970844', 'Thugs of Hindostan', 2)
# ('tt7725596', 'Badhaai Ho', 2)
# ('tt5461944', 'Hotel Mumbai', 0)
# ('tt0838221', 'The Darjeeling Limited', 0)
# ('tt8426854', 'Jalebi', 2)
# ('tt0286499', 'Bend It Like Beckham', 0)
# ('tt5074352', 'Dangal', 2)
# ('tt5474036', 'Manmarziyaan', 2)
# ('tt0043456', 'The Day the Earth Stood Still', 0)
# ('tt1098327', 'Dragonball Evolution', 0)
# ('tt8396128', 'Pataakha', 2)
# ('tt2884206', 'I Origins', 0)
# ('tt0366551', 'Harold & Kumar Go to White Castle', 0)
# ('tt1187043', '3 Idiots', 2)
# ('tt0986264', 'Taare Zameen Par', 2)
# ('tt3735246', 'Bajirao Mastani', 2)
# ('tt2338151', 'PK', 2)
# ('tt2980648', 'The Hundred-Foot Journey', 0)
# ('tt1954470', 'Gangs of Wasseypur', 2)
# ('tt0120102', 'Seven Years in Tibet', 0)
# ('tt0086034', 'Octopussy', 0)
# ('tt0109424', 'Chung Hing sam lam', 3)
# ('tt6452574', 'Sanju', 2)
# ('tt5816682', 'Victoria & Abdul', 0)
# ('tt7919680', 'Karwaan', 2)
# ('tt8852558', 'Mitron', 2)
# ('tt7218518', 'Padman', 2)
# ('tt3004774', 'Tigers', 2)
# ('tt1166100', 'Ghajini', 2)
# ('tt1412386', 'The Best Exotic Marigold Hotel', 0)
# ('tt0327437', 'Around the World in 80 Days', 0)
# ('tt0116409', 'The Ghost and the Darkness', 0)
# ('tt5935704', 'Padmaavat', 2)
# ('tt7098658', 'Raazi', 2)
# ('tt6967980', 'Bareilly Ki Barfi', 2)
# ('tt0169102', 'Lagaan: Once Upon a Time in India', 2)
# ('tt8439854', 'Lust Stories', 2)
# ('tt1188996', 'My Name Is Khan', 2)
# ('tt3823392', 'Love Sonia', 2)
# ('tt7720922', 'Batti Gul Meter Chalu', 2)
# ('tt7820846', 'Loveyatri', 2)
# ('tt1285241', 'Don 2', 2)
# ('tt0405508', 'Rang De Basanti', 2)
# ('tt7853242', 'Love Per Square Foot', 2)
# ('tt2882328', 'Ugly', 2)
# ('tt2631186', 'Bahubali: The Beginning', 4)
# ('tt0066763', 'Anand', 2)
# ('tt4849438', 'Baahubali 2: The Conclusion', 4)
# ('tt7147540', 'Sui Dhaaga: Made in India', 2)
# ('tt7526836', 'FryDay', 2)
# ('tt0808357', 'Se, jie', 5)
# ('tt6173990', 'Gold', 2)
# ('tt6129302', 'Bhavesh Joshi Superhero', 2)
# ('tt7581902', 'Sonu Ke Titu Ki Sweety', 2)
# ('tt8202612', 'Satyameva Jayate', 2)
# ('tt7431594', 'Race 3', 2)
# ('tt0809504', 'The Accidental Husband', 0)
# ('tt1647668', 'Million Dollar Arm', 0)
# ('tt3044882', 'Nasha', 2)
# ('tt2350496', 'Dabba', 2)
# ('tt6148156', 'Vikram Vedha', 6)
# ('tt6206564', 'Trapped', 2)
# ('tt6826438', 'Parmanu: The Story of Pokhran', 2)
# ('tt2082197', 'Barfi!', 2)
# ('tt0051383', 'Auntie Mame', 0)
# ('tt3224288', 'Beyond the Clouds', 2)
# ('tt3148502', 'Tamasha', 2)
# ('tt7180544', 'Mukkabaaz', 2)
# ('tt0361411', 'Bride & Prejudice', 0)
# ('tt7638344', 'Dhadak', 2)
# ('tt5690142', 'Mom', 2)
# ('tt0087892', 'A Passage to India', 0)
# ('tt7881542', 'Happy Phirr Bhag Jayegi', 2)
# ('tt0248126', 'Kabhi Khushi Kabhie Gham...', 2)
# ('tt4635372', 'Masaan', 2)
# ('tt4977530', "Viceroy's House", 7)
# ('tt8011276', 'Laila Majnu', 2)
# ('tt4699202', 'Gurgaon', 2)
# ('tt5946128', 'Dear Zindagi', 2)
# ('tt6484982', 'Newton', 2)
# ('tt6774212', 'Aiyaary', 2)
# ('tt0093603', 'Nayakan', 6)
# ('tt6514196', 'Baazaar', 2)
# ('tt7363076', 'Raid', 2)
# ('tt4110568', 'Dil Dhadakne Do', 2)
# ('tt7700730', 'October', 2)
# ('tt4934950', 'Talvar', 2)
# ('tt2181831', 'Shahid', 2)
# ('tt3405236', 'Raees', 2)
# ('tt1821480', 'Kahaani', 2)
# ('tt3418424', 'One Less God', 0)
# ('tt2574698', 'Gunday', 2)
# ('tt0115641', 'Beavis and Butt-Head Do America', 0)
# ('tt3863552', 'Bajrangi Bhaijaan', 2)
# ('tt3043252', 'Parched', 2)
# ('tt4129428', 'Jagga Jasoos', 2)
# ('tt1849718', 'Agneepath', 2)
# ('tt3001638', 'Mary Kom', 2)
# ('tt4434004', 'Udta Punjab', 2)
# ('tt7469726', 'Shaadi Mein Zaroor Aana', 2)
# ('tt0891592', 'Street Fighter: The Legend of Chun-Li', 0)
# ('tt0375611', 'Black', 2)
# ('tt7690638', 'Soorma', 2)
# ('tt5662932', 'Raman Raghav 2.0', 2)
# ('tt0432637', 'Krrish', 2)
# ('tt4387040', 'Airlift', 2)
# ('tt0238936', 'Devdas', 2)
# ('tt6692354', 'Ittefaq', 2)
# ('tt4559006', 'Ae Dil Hai Mushkil', 2)
# ('tt6972140', 'Blackmail', 2)
# ('tt5571734', 'Pink', 2)
# ('tt2436516', 'Go Goa Gone', 2)
# ('tt4430212', 'Drishyam', 2)
# ('tt1185420', 'Dostana', 2)
# ('tt0367495', 'Anbe Sivam', 6)
# ('tt5842616', 'Veere Di Wedding', 2)
# ('tt6071752', 'Dil Juunglee', 2)
# ('tt1833673', 'Dhoom:3', 2)
# ('tt6108090', 'Secret Superstar', 2)
# ('tt1280558', 'A Wednesday', 2)
# ('tt2215477', 'Goliyon Ki Rasleela Ram-Leela', 2)
# ('tt2408040', 'B.A. Pass', 2)
# ('tt4832640', 'Sultan', 2)
# ('tt5785170', 'Toilet - Ek Prem Katha', 2)
# ('tt7981260', 'Garbage', 0)
# ('tt0112870', 'Dilwale Dulhania Le Jayenge', 2)
# ('tt1327035', 'Dev.D', 2)
# ('tt7618184', 'Mulk', 2)
# ('tt0457655', 'Efter brylluppet', 8)
# ('tt5956100', 'Tiger Zinda Hai', 2)
# ('tt0347304', 'Kal Ho Naa Ho', 2)
# ('tt4900716', 'Kapoor & Sons', 2)
# ('tt8136908', 'Halkaa', 2)
# ('tt5460276', 'Kaabil', 2)
# ('tt3771536', 'Shivaay', 2)
# ('tt4535650', 'Dilwale', 2)
# ('tt0265343', 'Monsoon Wedding', 2)
# ('tt5542802', 'Raabta', 2)
# ('tt1787988', 'Talaash', 2)
# ('tt3678782', 'Badlapur', 2)
# ('tt3702652', 'The Other Side of the Door', 0)
# ('tt1839596', 'Rockstar', 2)
# ('tt1024943', 'Om Shanti Om', 2)
# ('tt0172684', 'Kuch Kuch Hota Hai', 2)
# ('tt1093370', 'Jab We Met', 2)
# ('tt4814290', 'Te3n', 2)
# ('tt5997666', 'Jab Harry Met Sejal', 2)
# ('tt3390572', 'Haider', 2)
# ('tt1321869', 'The Lovers', 0)
# ('tt5882970', 'Tubelight', 2)
# ('tt7275232', 'Welcome to New York', 2)
# ('tt0420332', 'Veer-Zaara', 2)
# ('tt1934231', 'Delhi Belly', 0)
# ('tt3767372', 'Piku', 2)
# ('tt0449994', 'Jodhaa Akbar', 2)
# ('tt5613834', 'A Gentleman', 2)
# ('tt1562871', 'Ra.One', 2)
# ('tt6485666', 'Mersal', 6)
# ('tt6588966', 'Hichki', 2)
# ('tt1562872', 'Zindagi Na Milegi Dobara', 2)
# ('tt1182937', 'Rab Ne Bana Di Jodi', 2)
# ('tt3679060', 'Dishoom', 2)
# ('tt1620933', 'Paan Singh Tomar', 2)
# ('tt7399470', 'Qarib Qarib Singlle', 2)
# ('tt2213054', 'Kai po che!', 2)
# ('tt2178470', 'Yeh Jawaani Hai Deewani', 2)
# ('tt5255710', 'Sanam Teri Kasam', 2)
# ('tt3541262', 'Myeong-ryang', 9)
# ('tt0367110', 'Swades: We, the People', 2)
# ('tt6102396', 'Kaalakaandi', 2)
# ('tt6170954', 'Naam Shabana', 2)
# ('tt2176013', 'Jab Tak Hai Jaan', 2)
# ('tt6580564', '102 Not Out', 2)
# ('tt1974382', 'The Challenger', 0)
# ('tt6843812', 'Baaghi 2', 2)
# ('tt7607940', 'Namaste England', 2)
# ('tt0073707', 'Sholay', 2)
# ('tt6978268', 'Omerta', 2)
# ('tt7412738', 'Nanu Ki Jaanu', 2)
# ('tt0031580', 'The Little Princess', 0)
# ('tt8055888', 'Mard Ko Dard Nahin Hota', 2)
# ('tt7329858', 'Pari', 2)
# ('tt0871510', 'Chak De! India', 2)
# ('tt3322420', 'Queen', 2)
# ('tt2112124', 'Chennai Express', 2)
# ('tt0400234', 'Black Friday', 2)
# ('tt1275863', 'Love Aaj Kal', 2)
# ('tt3447364', 'Detective Byomkesh Bakshy!', 2)
# ('tt0441048', 'Dhoom:2', 2)
# ('tt0433416', 'The Namesake', 0)
# ('tt5050788', 'Loev', 2)
# ('tt4399594', 'Fitoor', 2)
# ('tt5474042', 'Half Girlfriend', 2)
# ('tt8458202', 'Pihu', 2)
# ('tt2361746', 'Haraamkhor', 2)
# ('tt6971752', 'Shubh Mangal Saavdhan', 2)
# ('tt0280720', 'The Guru', 0)
# ('tt5197544', 'Baar Baar Dekho', 2)
# ('tt5325684', 'Hate Story IV', 2)
# ('tt0374887', 'Munna Bhai M.B.B.S.', 2)
# ('tt3848892', 'Baby', 2)
# ('tt2557256', 'Bing feng: Chong sheng zhi men', 3)
# ('tt7471004', 'The House Next Door', 4)
# ('tt0213890', 'Mohabbatein', 2)
# ('tt3469244', 'Phantom', 2)
# ('tt5745450', 'Chef', 2)
# ('tt5518128', 'Love Games', 2)
# ('tt6514010', 'Brij Mohan Amar Rahe', 2)
# ('tt3614516', 'Ankhon Dekhi', 2)
# ('tt2150177', 'Bhaiaji Superhit', 2)
# ('tt3542028', 'Chal Bhaag', 2)
# ('tt0096028', 'Salaam Bombay!', 2)
# ('tt5071886', 'Kabali', 6)
# ('tt5764096', 'Hindi Medium', 2)
# ('tt0479751', 'Sivaji', 6)
# ('tt0466460', 'Khosla Ka Ghosla!', 2)
# ('tt0379370', 'Maqbool', 2)
# ('tt2377938', 'Special Chabbis', 2)
# ('tt0964516', 'Fashion', 2)
# ('tt1029231', 'Krrish 3', 2)
# ('tt7162758', 'Paltan', 2)
# ('tt1292703', 'Oye Lucky! Lucky Oye!', 2)
# ('tt3495026', 'Fan', 2)
# ('tt5358948', 'One Night Stand', 2)
# ('tt7609114', 'Yamla Pagla Deewana Phir Se...', 2)
# ('tt1926313', 'Pyaar Ka Punchnama', 2)
# ('tt5713232', 'Madaari', 2)
# ('tt2283748', 'OMG: Oh My God!', 2)
# ('tt8338746', 'Phamous', 2)
# ('tt5108476', 'Befikre', 2)
# ('tt1836987', 'Trishna', 0)
# ('tt1324059', 'Wake Up Sid', 2)
# ('tt1948150', 'Singham', 2)
# ('tt0461936', 'Don', 2)
# ('tt2929690', 'Margarita with a Straw', 2)
# ('tt1198101', 'Kites', 0)
# ('tt3495030', 'Dum Laga Ke Haisha', 2)
# ('tt3554418', 'Khoobsurat', 2)
# ('tt3177332', 'Horror Story', 2)
# ('tt2203308', 'Aashiqui 2', 2)
# ('tt1438298', 'Guzaarish', 2)
# ('tt0234000', 'Kaho Naa... Pyaar Hai', 2)
# ('tt2461132', 'Happy New Year', 2)
# ('tt0425326', 'Outsourced', 0)
# ('tt3337550', 'Rahasya', 2)
# ('tt1629376', '7 Khoon Maaf', 2)
# ('tt1261047', 'Gulaal', 2)
# ('tt7384848', 'Missing', 2)
# ('tt5918074', 'A Death in the Gunj', 0)
# ('tt2309987', 'Hate Story', 2)
# ('tt7722258', 'Genius', 2)
# ('tt2797242', 'Bombay Talkies', 2)
# ('tt2172071', 'Student of the Year', 2)
# ('tt1806913', 'Golmaal Again', 2)
# ('tt0292490', 'Dil Chahta Hai', 2)
# ('tt1773764', 'Ship of Theseus', 0)
# ('tt1734110', 'No One Killed Jessica', 2)
# ('tt4430136', 'Pyaar Ka Punchnama 2', 2)
# ('tt6277440', 'Badrinath Ki Dulhania', 2)
# ('tt4909752', 'Rangoon', 2)
# ('tt2226666', 'Jism 2', 2)
# ('tt3859980', 'Mohenjo Daro', 2)
# ('tt8060624', 'Nawabzaade', 2)
# ('tt0422091', 'Dhoom', 2)
# ('tt2016894', 'Ek Tha Tiger', 2)
# ('tt2979920', 'Bombay Velvet', 2)
# ('tt0347473', 'Main Hoon Na', 2)
# ('tt5121000', 'Aligarh', 2)
# ('tt2317337', 'Vicky Donor', 2)
# ('tt5165344', 'Rustom', 0)
# ('tt2905838', 'Bang Bang', 2)
# ('tt0296574', 'Company', 2)
# ('tt5465370', 'Akira', 2)
# ('tt0473367', 'Jaane Tu... Ya Jaane Na', 2)
# ('tt6405126', 'Simran', 2)
# ('tt4467262', 'Katti Batti', 2)
# ('tt2976182', 'Roy', 2)
# ('tt0488414', 'Omkara', 2)
# ('tt3709344', 'City Lights', 2)
# ('tt2126282', 'Ekk Deewana Tha', 2)
# ('tt2356180', 'Bhaag Milkha Bhaag', 2)
# ('tt0352314', 'Ek Hasina Thi', 2)
# ('tt0499375', 'Guru', 2)
# ('tt6272828', 'Mubarakan', 2)
# ('tt1185442', 'Kurbaan', 2)
# ('tt4232066', 'Once Again', 2)
# ('tt5456546', 'Judwaa 2', 2)
# ('tt7617988', 'Kuchh Bheege Alfaaz', 2)
# ('tt0254481', 'Koi... Mil Gaya', 2)
# ('tt4864932', 'Baaghi', 2)
# ('tt0242519', 'Hera Pheri', 2)
# ('tt2635622', 'The Attacks of 26/11', 2)
# ('tt0116630', 'Indian', 6)
# ('tt1077248', 'Johnny Gaddaar', 2)
# ('tt5997928', 'Hotel Salvation', 2)
# ('tt1274295', 'Kaminey', 2)
# ('tt6471054', 'Ajji', 2)
# ('tt0164538', 'Dil Se..', 2)
# ('tt2372678', '2 States', 2)
# ('tt1049405', 'The Other End of the Line', 0)
# ('tt2855648', 'Madras Cafe', 2)
# ('tt0449999', 'Kabhi Alvida Naa Kehna', 2)
# ('tt1954598', 'Ladies vs. Ricky Bahl', 2)
# ('tt2609218', 'Ragini MMS 2', 2)
# ('tt0222012', 'Hey Ram', 6)
# ('tt5286444', 'Neerja', 2)
# ('tt0995740', 'No Smoking', 2)
# ('tt2359810', 'Raanjhanaa', 2)
# ('tt2229848', 'Chashme Baddoor', 2)
# ('tt2168910', 'Cocktail', 2)
# ('tt0272736', 'Mujhse Dosti Karoge!', 2)
# ('tt0439662', 'Fanaa', 2)
# ('tt1375789', 'Race 2', 2)
# ('tt1639426', 'Udaan', 2)
# ('tt6299040', 'The Ghazi Attack', 2)
# ('tt4169250', 'M.S. Dhoni: The Untold Story', 2)
# ('tt1091229', 'Chandni Chowk to China', 2)
# ('tt1433810', 'Dhobi Ghat', 2)
# ('tt5697870', 'Lucknow Central', 2)
# ('tt4940456', 'Mirzya', 2)
# ('tt0151150', 'Josh', 2)
# ('tt5477608', 'Kahaani 2', 2)
# ('tt7142506', 'Sir', 2)
# ('tt0376127', 'Anniyan', 6)
# ('tt4276752', 'Xun Long Jue', 5)
# ('tt0117878', 'Tere Mere Sapne', 2)
# ('tt5638500', '1920 London', 2)
# ('tt0463345', 'La mujer de mi hermano', 10)
# ('tt6613812', 'Angrezi Mein Kehte Hain', 2)
# ('tt0114142', 'Playback', 0)
# ('tt4333674', 'Hunterrr', 2)
# ('tt4865436', 'Hate Story 3', 2)
# ('tt5156746', 'Force 2', 2)
# ('tt0315642', 'Wazir', 2)
# ('tt2980794', 'Highway', 2)
# ('tt0109117', 'Andaz Apna Apna', 2)
# ('tt1610452', 'Band Baaja Baaraat', 2)
# ('tt0118983', 'Dil To Pagal Hai', 2)
# ('tt0102258', 'Lamhe', 2)
# ('tt4807830', 'Lipstick Under My Burkha', 2)
# ('tt3802576', 'Brothers', 2)
# ('tt5472758', 'Happy Bhag Jayegi', 2)
# ('tt1572311', 'Tees Maar Khan', 2)
# ('tt5472374', 'Meri Pyaari Bindu', 2)
# ('tt4874298', 'Madly', 0)
# ('tt1714832', 'Do Dooni Chaar', 2)
# ('tt0106333', 'Baazigar', 2)
# ('tt3410408', 'Rocky Handsome', 2)
# ('tt2424988', 'Gabbar is Back', 2)
# ('tt3696192', 'Singh Is Bliing', 2)
# ('tt2181931', 'English Vinglish', 2)
# ('tt5743656', 'Phobia', 2)
# ('tt0346457', 'Mangal Pandey: The Rising', 2)
# ('tt2072227', 'Shanghai', 2)
# ('tt6143422', 'Dark wind', 2)
# ('tt6173826', 'Guest iin London', 2)
# ('tt0215132', 'Rocky', 2)
# ('tt4906960', 'Baadshaho', 2)
# ('tt0294662', 'Kaante', 2)
# ('tt1411956', 'Sold', 0)
# ('tt1230165', 'Rock On!!', 2)
# ('tt1428459', 'We Are Family', 2)
# ('tt3175038', 'Ek Villain', 2)
# ('tt3483712', 'Raja Natwarlal', 2)
# ('tt1694542', 'Tanu Weds Manu', 2)
# ('tt8223250', 'Bioscopewala', 2)
# ('tt0100095', 'Maine Pyar Kiya', 2)
# ('tt4552546', '3 Storeys', 2)
# ('tt5742874', 'Sarkar 3', 2)
# ('tt0075143', 'Al-risâlah', 11)
# ('tt4552486', 'Dobaara: See Your Evil', 2)
# ('tt0195231', 'Satya', 2)
# ('tt7647198', 'Love and Shukla', 2)
# ('tt5983262', 'Tikli and Laxmi Bomb', 2)
# ('tt6265988', 'Bhoomi', 2)
# ('tt1020937', 'Awarapan', 2)
# ('tt5982852', 'Jolly LLB 2', 2)
# ('tt0425055', 'Game 6', 0)
# ('tt2614722', 'Umrika', 2)
# ('tt2140465', 'Tanu Weds Manu Returns', 2)
# ('tt1043451', 'Delhi-6', 2)
# ('tt0451850', 'Paheli', 2)
# ('tt1580704', 'That Girl in Yellow Boots', 2)
# ('tt0052954', 'Kaagaz Ke Phool', 2)
# ('tt3679000', 'Any Body Can Dance 2', 2)
# ('tt3483646', 'Bewakoofiyaan', 2)
# ('tt5178120', 'The Song of Scorpions', 2)
# ('tt0066070', 'Mera Naam Joker', 2)
# ('tt1266583', 'Mumbai Meri Jaan', 2)
# ('tt6791730', 'Tumhari Sulu', 2)
# ('tt0758053', 'Saawariya', 2)
# ('tt7695014', 'Saheb Biwi Aur Gangster 3', 2)
# ('tt4271730', 'Alone', 2)
# ('tt1985981', 'Desi Boyz', 2)
# ('tt1291465', 'Raajneeti', 2)
# ('tt1244093', 'Hisss', 0)
# ('tt1836912', 'Shaitan', 2)
# ('tt4979082', 'Jai Gangaajal', 2)
# ('tt2258337', 'Eega', 4)
# ('tt1954206', 'The Dirty Picture', 2)
# ('tt1667838', 'I Hate Luv Storys', 2)
# ('tt3717068', 'Court', 1)
# ('tt0079221', 'Gol Maal', 2)
# ('tt4332114', 'Dolly Ki Doli', 2)
# ('tt0058547', 'Sangam', 2)
# ('tt8484590', 'Teri Bhabhi Hai Pagle', 2)
# ('tt0800956', 'Life in a Metro', 2)
# ('tt0107311', 'Khal Nayak', 2)
# ('tt2049630', 'Unfreedom', 0)
# ('tt2677064', 'Vishwaroopam 2', 6)
# ('tt2476154', 'Grand Masti', 2)
# ('tt5235880', 'A Flying Jatt', 2)
# ('tt0248185', 'Mission Kashmir', 2)
# ('tt1144804', 'Kambakkht Ishq', 2)
# ('tt2804026', 'Aurangzeb', 2)
# ('tt0795434', 'Namastey London', 2)
# ('tt2309764', 'Singham Returns', 2)
# ('tt5207116', 'X: Past Is Present', 2)
# ('tt1949548', 'Heroine', 2)
# ('tt4088588', 'Dhanak', 2)
# ('tt0405507', 'Murder', 2)
# ('tt3495000', 'Mardaani', 2)
# ('tt8581230', 'B.A. Pass 2', 2)
# ('tt3019620', 'Titli', 2)
# ('tt0248617', 'Yaadein...', 2)
# ('tt6712014', 'Fukrey Returns', 2)
# ('tt5943306', 'Freaky Ali', 2)
# ('tt5752374', 'Shorgul', 2)
# ('tt2187153', 'Thuppakki', 6)
# ('tt0109206', 'Bandit Queen', 2)
# ('tt0470869', "Neal 'N' Nikki", 0)
# ('tt0432047', 'Sarkar', 2)
# ('tt0323013', 'Lakshya', 2)
# ('tt1183946', 'The Stoneman Murders', 2)
# ('tt2198235', 'Monsoon Shootout', 2)
# ('tt0150992', 'Hum Dil De Chuke Sanam', 2)
# ('tt3742284', 'NH10', 2)
# ('tt8427036', 'Helicopter Eela', 2)
# ('tt1918886', 'Joker', 2)
# ('tt1499201', 'Anjaana Anjaani', 2)
# ('tt6467738', 'Irada', 2)
# ('tt0330082', 'Boom', 0)
# ('tt2699840', 'John Day', 2)
# ('tt3836958', 'Shamitabh', 2)
# ('tt1918965', 'Murder 2', 2)
# ('tt6275262', 'Vodka Diaries', 2)
# ('tt3017412', 'Happy Ending', 2)
# ('tt5764024', 'OK Jaanu', 2)
# ('tt3794302', 'Pizza', 2)
# ('tt3209826', 'Patel Ki Punjabi Shaadi', 2)
# ('tt4949324', 'Mohalla Assi', 2)
# ('tt1101665', 'Shaurya: It Takes Courage to Make Right... Right', 2)
# ('tt0403935', 'Action Jackson', 2)
# ('tt5290620', 'Kyaa Kool Hain Hum 3', 2)
# ('tt2423132', 'Akaash Vani', 2)
# ('tt0220832', 'Vaastav: The Reality', 2)
# ('tt4559046', 'Housefull 3', 2)
# ('tt5775220', 'Noor', 2)
# ('tt0249371', 'Asoka', 2)
# ('tt2372222', 'Kick', 2)
# ('tt0382383', 'Yuva', 2)
# ('tt3142232', 'Heropanti', 2)
# ('tt3678938', 'Humpty Sharma Ki Dulhania', 2)
# ('tt6926486', 'Daddy', 2)
# ('tt8175968', 'High Jack', 2)
# ('tt0240200', 'Water', 2)
# ('tt0303785', 'Bollywood/Hollywood', 0)
# ('tt4990516', 'Tu Hai Mera Sunday', 2)
# ('tt8698956', 'Lupt', 2)
# ('tt2224317', 'Lootera', 2)
# ('tt0806088', 'Heyy Babyy', 2)
# ('tt7172308', "Kuldip Patwal: I Didn't Do It!", 2)
# ('tt6537508', 'Behen Hogi Teri', 2)
# ('tt1017456', 'Race', 2)
# ('tt8324474', 'Hope Aur Hum', 2)
# ('tt5020726', 'Silvat', 2)
# ('tt0346723', 'Chalte Chalte', 2)
# ('tt4979110', 'Daas Dev', 2)
# ('tt1395054', 'Once Upon a Time in Mumbaai', 2)
# ('tt0195002', 'Kaun?', 2)
# ('tt1825801', 'Hostel', 2)
# ('tt0139876', 'Baasha', 6)
# ('tt5686868', 'Miss Teacher', 2)
# ('tt4022278', 'Fever', 2)
# ('tt0248012', 'Fiza', 2)
# ('tt5005684', 'Nil Battey Sannata', 2)
# ('tt0356982', 'Paanch', 2)
# ('tt5227468', 'Beiimaan Love', 2)
# ('tt0995031', 'Bhool Bhulaiyaa', 2)
# ('tt3173910', 'Hasee Toh Phasee', 2)
# ('tt6711660', 'Babumoshai Bandookbaaz', 2)
# ('tt0498351', 'The Hero of Color City', 0)
# ('tt3142688', 'Finding Fanny', 0)
# ('tt0085743', 'Jaane Bhi Do Yaaro', 2)
# ('tt5954088', 'Commando 2', 2)
# ('tt0318275', 'Adisaya Piravi', 6)
# ('tt5502766', 'Phillauri', 2)
# ('tt0105271', 'Roja', 6)
# ('tt0109555', 'Darr', 2)
# ('tt2246724', 'Ghanchakkar', 2)
# ('tt3483612', 'Hamari Adhuri Kahani', 2)
# ('tt3415692', 'Mahabharat', 2)
# ('tt1230448', 'Billu', 2)
# ('tt0104561', 'Jo Jeeta Wohi Sikandar', 2)
# ('tt1120897', 'Dhan Dhana Dhan Goal', 2)
# ('tt1558578', 'Knock Out', 2)
# ('tt0456144', 'Lage Raho Munna Bhai', 2)
# ('tt4190220', 'Zed Plus', 2)
# ('tt0222024', 'Hum Tumhare Hain Sanam', 2)
# ('tt0053126', 'North West Frontier', 0)
# ('tt0488798', 'Welcome', 2)
# ('tt0457802', 'The Blue Umbrella', 2)
# ('tt1708453', 'Aakrosh', 2)
# ('tt6117702', 'Munna Michael', 2)
# ('tt0451919', 'Socha Na Tha', 2)
# ('tt1434447', 'Rocket Singh: Salesman of the Year', 2)
# ('tt0920464', 'Manorama Six Feet Under', 2)
# ('tt2275802', 'Satyagraha', 2)
# ('tt0415908', 'Kaal', 2)
# ('tt0116308', 'Fire', 0)
# ('tt2301155', 'Shootout at Wadala', 2)
# ('tt0119861', 'Pardes', 2)
# ('tt0418362', 'Mujhse Shaadi Karogi', 2)
# ('tt0114234', 'Rangeela', 2)
# ('tt1395025', 'Agent Vinod', 2)
# ('tt2762334', 'Main Tera Hero', 2)
# ('tt2199711', 'Vishwaroopam', 6)
# ('tt4007558', 'Shaandaar', 2)
# ('tt4744086', 'Ki & Ka', 2)
# ('tt1785333', 'Chittagong', 2)
# ('tt2912578', 'Ankur Arora Murder Case', 2)
# ('tt0464160', 'Chup Chup Ke', 2)
# ('tt0418460', 'Aitraaz', 2)
# ('tt2551378', 'Bullett Raja', 2)
# ('tt2658126', 'Commando', 2)
# ('tt1729637', 'Bodyguard', 2)
# ('tt1608777', 'LSD: Love, Sex Aur Dhokha', 2)
# ('tt1740710', 'Mere Brother Ki Dulhan', 2)
# ('tt1182972', 'Bachna Ae Haseeno', 2)
# ('tt4023852', 'Welcome to Karachi', 12)
# ('tt2186933', 'Luv Shuv Tey Chicken Khurana', 2)
# ('tt1918927', 'Luv Ka the End', 2)
# ('tt0471571', 'Athadu', 4)
# ('tt2229842', 'Table No.21', 2)
# ('tt0291376', 'Nayak: The Real Hero', 2)
# ('tt0072783', 'Chupke Chupke', 2)
# ('tt2556308', 'Holiday', 2)
# ('tt4675030', 'Great Grand Masti', 2)
# ('tt1194232', 'Jaane Kahan Se Aayi Hai', 2)
# ('tt0476527', 'Bluffmaster!', 2)
# ('tt0976026', 'Cheeni Kum', 2)
# ('tt1784589', 'Players', 2)
# ('tt0306434', 'Aankhen', 2)
# ('tt0098999', 'Agneepath', 2)
# ('tt0494290', 'Vivah', 2)
# ('tt1620719', 'Dabangg', 2)
# ('tt1703958', 'Ek Main Aur Ekk Tu', 2)
# ('tt4642936', 'Warrior Savitri', 2)
# ('tt0454396', 'Aryan: Unbreakable', 2)
# ('tt0109010', '1942: A Love Story', 2)
# ('tt1728986', 'Bol Bachchan', 2)
# ('tt2321163', 'ABCD Any Body Can Dance', 2)
# ('tt1629391', 'Tere Bin Laden', 2)
# ('tt1720254', 'Thank You', 2)
# ('tt2385104', 'D-Day', 2)
# ('tt1183917', 'Teen Patti', 2)
# ('tt2344678', 'Himmatwala', 2)
# ('tt3380264', 'Kill Dil', 2)
# ('tt4300776', 'Mirror Game', 2)
# ('tt1532957', 'Paa', 2)
# ('tt0337578', 'Baghban', 2)
# ('tt6997642', 'Ribbon', 2)
# ('tt1396208', 'Action Replayy', 2)
# ('tt1351224', 'Pyaar Impossible!', 2)
# ('tt0113526', 'Karan Arjun', 2)
# ('tt0086230', 'Sadma', 2)
# ('tt0456165', 'Salaam Namaste', 2)
# ('tt3619772', 'Hate Story 2', 2)
# ('tt2339505', 'Kochadaiiyaan', 6)
# ('tt1084972', 'Wanted', 2)
# ('tt0444767', 'A Sublime Love Story: Barsaat', 2)
# ('tt1602476', 'Badmaa$h Company', 2)
# ('tt0093578', 'Mr. India', 2)
# ('tt3368222', 'Angry Indian Goddesses', 2)
# ('tt2807410', 'Rudhramadevi', 4)
# ('tt6027478', 'Dhruva', 4)
# ('tt5457772', 'Sarrainodu', 2)
# ('tt1573072', 'Housefull', 2)
# ('tt2271641', 'Thaandavam', 6)
# ('tt0419058', 'Phir Hera Pheri', 2)
# ('tt1255951', 'De Dana Dan', 2)
# ('tt0102825', 'Saajan', 2)
# ('tt0497915', 'Gunda', 2)
# ('tt0050188', 'Mother India', 2)
# ('tt2341766', 'Nautanki Saala!', 2)
# ('tt6118058', 'Maroon', 2)
# ('tt3595298', 'Prem Ratan Dhan Payo', 2)
# ('tt0211934', 'Baadshah', 2)
# ('tt0299108', 'Rehnaa Hai Terre Dil Mein', 2)
# ('tt0419992', 'My Brother... Nikhil', 0)
# ('tt1992138', 'Force', 2)
# ('tt0490210', 'Sarkar Raj', 2)
# ('tt0220594', 'Kartoos', 2)
# ('tt0200087', 'Sarfarosh', 2)
# ('tt1223922', 'Blue', 2)
# ('tt0196069', 'Samsara', 13)
# ('tt1706317', 'Tezz', 2)
# ('tt2137241', 'Rock On 2', 2)
# ('tt0485272', 'Salaam-E-Ishq', 2)
# ('tt1105733', 'Kismat Konnection', 2)
# ('tt6958030', '1921', 2)
# ('tt6201292', 'Bairavaa', 6)
# ('tt1714866', "Midnight's Children", 0)
# ('tt0116950', 'Maachis', 2)
# ('tt1884268', 'Chalo Dilli', 2)
# ('tt1221139', 'Welcome to Sajjanpur', 2)
# ('tt0824375', 'Nishabd', 2)
# ('tt2826126', 'Shree', 2)
# ('tt0337971', 'Deewangee', 2)
# ('tt0438875', 'Insan', 2)
# ('tt0110222', 'Kabhi Haan Kabhi Naa', 2)
# ('tt2211173', 'Yevadu', 4)
# ('tt0395802', 'Veergati', 2)
# ('tt0454435', "'D'", 2)
# ('tt5209420', 'LoveShhuda', 2)
# ('tt2222550', '1920: Evil Returns', 2)
# ('tt3449292', 'Manjhi: The Mountain Man', 2)
# ('tt0110076', 'Hum Aapke Hain Koun...!', 2)
# ('tt2932606', 'Siddharth', 2)
# ('tt6395306', 'Union Leader', 2)
# ('tt1239276', 'Rang Rasiya', 2)
# ('tt4024944', 'Main Aur Charles', 2)
# ('tt0313844', '16 December', 2)
# ('tt0246879', 'Qurbani', 2)
# ('tt2871010', 'Sonali Cable', 2)
# ('tt0098167', 'Rakhwala', 2)
# ('tt0137361', 'Anupama', 2)
# ('tt3409440', 'De surprise', 14)
# ('tt0488906', 'Zinda', 2)
# ('tt2357926', 'Ramaiya Vastavaiya', 2)
# ('tt0061974', 'Milan', 2)
# ('tt0069671', 'Abhimaan', 2)
# ('tt0065764', 'Geet', 2)
# ('tt2357489', 'Zanjeer', 2)
# ('tt0118654', 'Aunty No. 1', 2)
# ('tt0109922', 'Gopi Kishan', 2)
# ('tt0391165', 'Fun2shh... Dudes in the 10th Century', 2)
# ('tt0189592', 'Hum Aapke Dil Mein Rehte Hain', 2)
# ('tt0339936', 'Zamane Se Kya Darna', 2)
# ('tt0266875', 'Raat', 2)
# ('tt0363666', 'Hatya', 2)
# ('tt0267905', 'Sangram', 2)
# ('tt0317811', 'Kasam', 2)
# ('tt2354407', 'Teri Meri Kahaani', 2)
# ('tt0112553', 'Bombay', 6)
# ('tt0845448', 'Dhamaal', 2)
# ('tt3539966', 'Dishkiyaoon', 2)
# ('tt0860454', 'MP3: Mera Pehla Pehla Pyaar', 2)
# ('tt1708532', 'Ready', 2)
# ('tt0172574', 'Hulchul', 2)
# ('tt0187004', 'Farishtay', 2)
# ('tt0065936', 'Kati Patang', 2)
# ('tt0173369', 'Tum Mere Ho', 2)
# ('tt1805263', 'I Am Kalam', 2)
# ('tt0419468', 'Baabul', 2)
# ('tt1034449', 'Kidnap', 2)
# ('tt3840534', 'Junooniyat', 2)
# ('tt0210659', 'Dulhe Raja', 2)
# ('tt0109091', 'Amaanat', 2)
# ('tt0326600', 'Maine Dil Tujhko Diya', 2)
# ('tt1509732', 'Aisha', 2)
# ('tt0385782', 'Inteha', 2)
# ('tt1263679', 'Firaaq', 2)
# ('tt0115568', 'Army', 2)
# ('tt3036740', 'Humshakals', 2)
# ('tt0378072', 'Hum Tum', 2)
# ('tt0178186', 'Aandhi', 2)
# ('tt0415768', 'Dus', 2)
# ('tt1890363', 'Buddha in a Traffic Jam', 2)
# ('tt1060249', 'Drona', 2)
# ('tt0495032', 'Gangster', 2)
# ('tt0118751', 'Border', 2)
# ('tt0107060', 'Gumrah', 2)
# ('tt0490170', 'Love Story 2050', 2)
# ('tt4177040', 'Baankey Ki Crazy Baraat', 2)
# ('tt0382385', 'Zameen', 2)
# ('tt0156985', 'Sadak', 2)
# ('tt0110438', 'Main Khiladi Tu Anari', 2)
# ('tt1391544', 'Dhoondte Reh Jaoge', 2)
# ('tt0109710', 'Eena Meena Deeka', 2)
# ('tt0234141', 'Love Story', 2)
# ('tt0147811', 'Ankhen', 2)
# ('tt0214841', 'Karz', 2)
# ('tt6080914', 'Dora', 6)
# ('tt0216817', 'Hum Saath-Saath Hain: We Stand United', 2)
# ('tt0214665', 'Ek Phool Do Mali', 2)
# ('tt1754137', 'Little Terrors', 2)
# ('tt0337652', 'Jeena Sirf Merre Liye', 2)
# ('tt7274806', 'Kaashi in Search of Ganga', 2)
# ('tt0050870', 'Pyaasa', 2)
# ('tt2369154', 'R... Rajkumar', 2)
# ('tt0156043', 'Sanam Teri Kasam', 2)
# ('tt0172617', 'Izzat Ki Roti', 2)
# ('tt2939912', 'Traffic', 2)
# ('tt0187279', 'Meri Biwi Ka Jawab Nahin', 2)
# ('tt0886539', 'Luck by Chance', 2)
# ('tt4818930', 'Waiting', 2)
# ('tt0078241', 'Shalimar', 2)
# ('tt0305689', 'Jab Jab Phool Khile', 2)
# ('tt1241195', 'Aamir', 2)
# ('tt0072860', 'Deewaar', 2)
# ('tt0374271', 'Tere Naam', 2)
# ('tt0070253', 'Jugnu', 2)
# ('tt0379375', 'Matrubhoomi: A Nation Without Women', 2)
# ('tt0095440', 'Khatron Ke Khiladi', 2)
# ('tt1522329', 'Tum Mile', 2)
# ('tt0173102', 'Raju Ban Gaya Gentleman', 2)
# ('tt3817652', 'Ranna', 15)
# ('tt1146325', 'Singh Is Kinng', 2)
# ('tt5056470', 'Teraa Surroor', 0)
# ('tt0255212', 'Hamara Dil Aapke Paas Hai', 2)
# ('tt0121395', 'Imtihaan', 2)
# ('tt7742704', 'Meri Nimmo', 2)
# ('tt1830786', 'Rascals', 2)
# ('tt0177473', 'Aa Gale Lag Jaa', 2)
# ('tt0294264', 'Aalavandhan', 6)
# ('tt4302956', 'Kis Kisko Pyaar Karoon', 2)
# ('tt2343621', "Liar's Dice", 2)
# ('tt2622130', 'Jayantabhai Ki Luv Story', 2)
# ('tt3671294', 'Khilona Bana Khalnayak', 2)
# ('tt0151206', 'Khoon Bhari Maang', 2)
# ('tt2308773', 'Ishaqzaade', 2)
# ('tt0248135', 'Khudgarz', 2)
# ('tt0247394', 'Gumnaam', 2)
# ('tt1578261', 'Break Ke Baad', 2)
# ('tt0246456', 'Bazaar', 2)
# ('tt2806788', 'Fukrey', 2)
# ('tt0284456', 'Samadhi', 2)
# ('tt0102746', 'Kurbaan', 2)
# ('tt0164550', 'Duplicate', 2)
# ('tt7190460', 'Thupparivaalan', 6)
# ('tt1227762', 'Aladin', 2)
# ('tt0473310', 'Ram Gopal Varma Ki Aag', 2)
# ('tt0049041', 'C.I.D.', 2)
# ('tt0485522', 'Umrao Jaan', 12)
# ('tt4811706', 'Six X', 2)
# ('tt2106537', 'Matru ki Bijlee ka Mandola', 2)
# ('tt3590416', 'Global Baba', 2)
# ('tt0116153', 'Dushman Duniya Ka', 2)
# ('tt0255309', 'Kurukshetra', 2)
# ('tt2675978', 'Dedh Ishqiya', 2)
# ('tt0493417', 'Fool N Final', 2)
# ('tt0305714', 'Kadhal Desam', 6)
# ('tt0084667', 'Shakti', 2)
# ('tt1042499', 'Filth and Wisdom', 0)
# ('tt0326576', 'Humraaz', 2)
# ('tt3611266', 'Bank Chor', 2)
# ('tt0138411', 'Dushman', 2)
# ('tt1855268', 'Main Krishna Hoon', 2)
# ('tt1039995', 'U Me Aur Hum', 2)
# ('tt1727496', 'Dil Toh Baccha Hai Ji', 2)
# ('tt0084866', 'Vidhaata', 2)
# ('tt0072100', 'Roti Kapada Aur Makaan', 2)
# ('tt0105394', 'Shola Aur Shabnam', 2)
# ('tt7341406', 'Rukh', 2)
# ('tt3681414', 'Purani Jeans', 2)
# ('tt0121989', 'Baazi', 2)
# ('tt0986213', 'Aaja Nachle', 2)
# ('tt0053706', 'Chaudhvin Ka Chand', 12)
# ('tt0383975', 'Chameli', 2)
# ('tt1671446', 'Aadhi Bhagavan', 6)
# ('tt0268141', 'Ananda Ashram', 2)
# ('tt0839742', 'Bhopal: A Prayer for Rain', 0)
# ('tt0317312', 'Dance Dance', 2)
# ('tt6058394', 'Anaarkali of Aarah', 2)
# ('tt0116763', 'Khamoshi: The Musical', 2)
# ('tt1891757', 'Bol', 12)
# ('tt0059246', 'Guide', 2)
# ('tt4500734', 'Ek Paheli Leela', 2)
# ('tt3369670', 'Children of War', 2)
# ('tt1156148', 'Karzzzz', 2)
# ('tt0077451', 'Don', 2)
# ('tt2302416', 'Gali Guleiyan', 2)
# ('tt1334470', 'Raavan', 2)
# ('tt0067183', 'Haré Rama Haré Krishna', 2)
# ('tt0414714', 'Girlfriend', 2)
# ('tt0210609', 'China Gate', 2)
# ('tt0454431', 'Chocolate: Deep Dark Secrets', 2)
# ('tt5615116', 'Dear Dad', 2)
# ('tt1288638', 'Dasvidaniya', 2)
# ('tt0111068', 'Sangharsh', 2)
# ('tt0154998', 'Pataal Bhairavi', 2)
# ('tt0073191', 'Jai Santoshi Maa', 2)
# ('tt0263491', 'Jis Desh Mein Ganga Rehta Hain', 2)
# ('tt0083578', 'Arth', 2)
# ('tt1848771', 'Aarakshan', 2)
# ('tt0220757', 'Shool', 2)
# ('tt5637188', 'Saat Uchakkey', 2)
# ('tt0433425', 'Parzania', 0)
# ('tt0348656', 'Khushi', 2)
# ('tt0082797', 'Naseeb', 2)
# ('tt1667823', 'Bhindi Baazaar', 2)
# ('tt0230055', 'Bulandi', 2)
# ('tt3302962', 'Shaadi Ke Side Effects', 2)
# ('tt0175530', 'Chor Machaye Shor', 2)
# ('tt5120640', 'Sarbjit', 2)
# ('tt0117437', 'Raja Hindustani', 2)
# ('tt0083081', 'Silsila', 2)
# ('tt0409527', 'Shabd', 2)
# ('tt0267130', 'Yodha', 2)
# ('tt0456481', "Jaan-E-Mann: Let's Fall in Love... Again", 0)
# ('tt0156891', 'Phir Teri Kahani Yaad Aayee', 2)
# ('tt2246595', 'Blood Money', 2)
# ('tt1191130', 'Right Yaaa Wrong', 2)
# ('tt0290331', 'Waqt Hamara Hai', 2)
# ('tt0078222', 'Seeta Aur Geeta', 2)
# ('tt0396563', 'Dil Ne Jise Apna Kaha', 2)
# ('tt0253194', 'Kunwara', 2)
# ('tt4603640', 'The Silence', 2)
# ('tt0090812', 'Chameli Ki Shaadi', 2)
# ('tt0453671', 'Garam Masala', 2)
# ('tt0215517', 'Angoor', 2)
# ('tt0041619', 'Mahal', 2)
# ('tt0154685', 'Johny Mera Naam', 2)
# ('tt0443708', 'Page 3', 2)
# ('tt0290326', 'Tum Bin...: Love Will Find a Way', 2)
# ('tt0222270', 'Phir Bhi Dil Hai Hindustani', 2)
# ('tt1082075', 'Pusher', 2)
# ('tt2404519', '3G - A Killer Connection', 0)
# ('tt0286421', 'Achanak', 2)
# ('tt0107986', 'Roop Ki Rani Choron Ka Raja', 2)
# ('tt0307873', 'Raaz', 2)
# ('tt0330843', 'Saathiya', 2)
# ('tt0172175', 'Bhabhi', 2)
# ('tt0276309', 'Maa', 2)
# ('tt0105166', 'Prem Deewane', 2)
# ('tt2073070', 'Saheb Biwi Aur Gangster', 2)
# ('tt0499041', 'Kalyug', 2)
# ('tt0319020', 'Awara Paagal Deewana', 2)
# ('tt6620324', 'Indu Sarkar', 2)
# ('tt0089194', 'Geraftaar', 2)
# ('tt2417560', 'Filmistaan', 2)
# ('tt0392360', 'Love', 2)
# ('tt0172170', 'Bekhudi', 2)
# ('tt0106653', 'Dalaal', 2)
# ('tt4683366', 'Ghayal Once Again', 2)
# ('tt2188805', 'Login', 2)
# ('tt0489486', 'Good Boy, Bad Boy', 2)
# ('tt0110546', 'Mohra', 2)
# ('tt5785200', 'Machine', 2)
# ('tt2633598', 'Rise of the Zombie', 2)
# ('tt0246914', 'Sargam', 2)
# ('tt0154565', 'Haqeeqat', 2)
# ('tt0116391', 'Gang', 2)
# ('tt1099196', 'Dil Dosti Etc', 2)
# ('tt0104404', 'Heer Ranjha', 2)
# ('tt0882967', 'Strangers', 2)
# ('tt0375791', 'Gundaraj', 2)
# ('tt0178184', 'Aan Milo Sajna', 2)
# ('tt0346507', 'Andaaz', 2)
# ('tt0348187', 'Tejasvini', 2)
# ('tt1907761', 'Stanley Ka Dabba', 2)
# ('tt0111780', 'Yaar Gaddar', 2)
# ('tt0306855', 'Style', 2)
# ('tt6046994', 'Dongri Ka Raja', 2)
# ('tt2905768', 'Sahasam', 4)
# ('tt1174041', 'Main Aurr Mrs Khanna', 2)
# ('tt0347416', 'LOC: Kargil', 2)
# ('tt4262516', 'Sanam Re', 2)
# ('tt3615160', 'Gyakusatsu kikan', 16)
# ('tt0071800', 'Majboor', 2)
# ('tt0172761', 'Major Saab', 2)
# ('tt0084630', 'Satte Pe Satta', 2)
# ('tt1455811', 'Khatta Meetha', 2)
# ('tt2406676', 'Ek Thi Daayan', 2)
# ('tt1754920', 'Yeh Saali Zindagi', 2)
# ('tt3716142', 'Lekar Hum Deewana Dil', 2)
# ('tt1170404', 'Mere Baap Pehle Aap', 2)
# ('tt0281102', 'Pyaar Tune Kya Kiya...', 2)
# ('tt0229193', 'Aastha: In the Prison of Spring', 2)
# ('tt2215163', 'Issaq', 2)
# ('tt0444820', 'Fareb', 2)
# ('tt0995718', 'Ek Chalis Ki Last Local', 2)
# ('tt2077833', 'Rowdy Rathore', 2)
# ('tt0453729', 'Iqbal', 2)
# ('tt1773015', 'Phas Gaye Re Obama', 2)
# ('tt0265690', 'Samraat', 2)
# ('tt0115042', 'Zamaana Deewana', 2)
# ('tt0097563', 'Ilaaka', 2)
# ('tt0823451', 'Dus Kahaniyaan', 2)
# ('tt1582466', 'Adhurs', 4)
# ('tt1980986', 'Housefull 2', 2)
# ('tt0150433', 'Earth', 2)
# ('tt2178508', 'Son of Sardaar', 7)
# ('tt0075669', 'Amar Akbar Anthony', 2)
# ('tt0341562', 'Satta', 2)
# ('tt0303661', 'Anita & Me', 0)
# ('tt1451797', 'Rann', 2)
# ('tt0385351', 'Yeh Lamhe Judaai Ke', 2)
# ('tt0456500', 'Kyaa Kool Hai Hum', 2)
# ('tt0107321', 'King Uncle', 2)
# ('tt0349620', 'Inteqam: The Perfect Game', 2)
# ('tt1188982', 'Jai Ho', 2)
# ('tt5785116', 'Begum Jaan', 2)
# ('tt0300475', 'Shirdi Ke Sai Baba', 2)
# ('tt0196635', 'International Khiladi', 2)
# ('tt0085886', 'Mahaan', 2)
# ('tt0833553', 'Ta Ra Rum Pum', 2)
# ('tt0121352', 'Henna', 2)
# ('tt1328634', 'New York', 2)
# ('tt0322653', 'Mere Yaar Ki Shaadi Hai', 2)
# ('tt0139525', 'Phool Aur Patthar', 2)
# ('tt1242530', "What's Your Raashee?", 2)
# ('tt0470614', 'Yun Hota Toh Kya Hota', 2)
# ('tt3501994', 'Hawaa Hawaai', 2)
# ('tt0251356', 'Qahar', 2)
# ('tt0189492', 'Dushman', 2)
# ('tt0284811', 'Aarzoo', 2)
# ('tt0486615', 'London Dreams', 2)
# ('tt0118957', 'Deewana Mastana', 2)
# ('tt0374660', 'Footpath', 2)
# ('tt6095994', 'Khoj', 17)
# ('tt0177502', 'Aaj Ki Taaza Khabar', 2)
# ('tt0295603', 'Shirdi Sai Baba', 2)
# ('tt0473567', '...Yahaan', 2)
# ('tt0114031', 'Oh Darling Yeh Hai India', 2)
# ('tt0348843', 'Jism', 2)
# ('tt0126871', 'Deewana', 2)
# ('tt1185412', 'Veer', 2)
# ('tt0495034', 'Golmaal: Fun Unlimited', 2)
# ('tt1252596', 'Ajab Prem Ki Ghazab Kahani', 2)
# ('tt0190419', 'Ghulam', 2)
# ('tt0311411', 'Kranti', 2)
# ('tt2630076', 'Super Nani', 2)
# ('tt0106221', 'Aadmi Khilona Hai', 2)
# ('tt4386684', '31st October', 2)
# ('tt1618430', 'Dum Maaro Dum', 2)
# ('tt3107246', 'Irandam Ulagam', 6)
# ('tt0077609', 'Ghar', 2)
# ('tt2112131', 'Dabangg 2', 2)
# ('tt6734984', 'Duvvada Jagannadham', 4)
# ('tt0371735', 'Hungama', 2)
# ('tt7549484', 'Firangi', 2)
# ('tt0102071', 'Hum', 2)
# ('tt0369516', 'Hawa', 2)
# ('tt0061842', 'Jewel Thief', 2)
# ('tt7262178', 'Veerey Ki Wedding', 2)
# ('tt0062177', 'Ram Aur Shyam', 2)
# ('tt5212160', 'Chhota Bheem Himalayan Adventure', 2)
# ('tt1727535', 'Rakhta Charitra 2', 2)
# ('tt0072777', 'Chhoti Si Baat', 2)
# ('tt2094854', 'Inkaar', 2)
# ('tt2361148', 'Club 60', 2)
# ('tt0437238', 'Hulchul', 2)
# ('tt0359325', 'Ghazab', 2)
# ('tt0320097', 'Hum Kisi Se Kum Nahin', 2)
# ('tt0339864', 'Vijeta', 2)
# ('tt0136352', 'Koyla', 2)
# ('tt0109134', 'Anjaam', 2)
# ('tt3531852', 'Bhoothnath Returns', 2)
# ('tt0374184', 'Daai zek lou', 3)
# ('tt0340178', 'Jaal: The Trap', 2)
# ('tt0314557', 'Rajkumar', 2)
# ('tt0106725', 'Dil Tera Aashiq', 2)
# ('tt0064506', 'Ittefaq', 2)
# ('tt1290054', 'Bhupathi', 15)
# ('tt0154749', 'Kudrat', 2)
# ('tt3159708', 'Welcome Back', 2)
# ('tt4338154', 'Hawaizaada', 2)
# ('tt1627924', 'Mausam', 2)
# ('tt4117066', 'Meeruthiya Gangsters', 2)
# ('tt0151466', 'Main Tulsi Tere Aangan Ki', 2)
# ('tt0155805', 'Khhotte Sikkay', 2)
# ('tt3524410', 'Yeh Hai Bakrapur', 2)
# ('tt0811066', 'Shootout at Lokhandwala', 2)
# ('tt5600714', 'Laal Rang', 2)
# ('tt0255097', 'Deewane', 2)
# ('tt0071145', 'Ankur', 2)
# ('tt0074417', 'Do Anjaane', 2)
# ('tt3563156', 'Anjaan', 6)
# ('tt0133024', 'Ishq', 2)
# ('tt0247909', 'Aaj Ka Goonda Raaj', 2)
# ('tt0342624', 'Karz: The Burden of Truth', 2)
# ('tt7260848', 'Khajoor Pe Atke', 2)
# ('tt2678948', 'Jilla', 6)
# ('tt0180846', 'Tales of the KamaSutra 2: Monsoon', 0)
# ('tt5743888', 'Julie 2', 2)
# ('tt0991346', 'Bhoothnath', 2)
# ('tt0233226', 'Anokha Bandhan', 2)
# ('tt0348078', 'Souten', 2)
# ('tt0120456', 'Virasat', 2)
# ('tt0455829', 'Vettaiyaadu Vilaiyaadu', 6)
# ('tt0095936', 'Qayamat Se Qayamat Tak', 2)
# ('tt3419894', 'Sin-ui hansu', 9)
# ('tt1345777', 'Ishqiya', 2)
# ('tt1772872', 'Game', 2)
# ('tt0301215', 'Doosara Aadmi', 2)
# ('tt7154994', 'Ranchi Diaries', 2)
# ('tt2064849', 'London Paris New York', 2)
# ('tt1415252', 'Agyaat', 2)
# ('tt0070434', 'Namak Haraam', 2)
# ('tt0237395', 'Lal Patthar', 2)
# ('tt0073104', 'Hera Pheri', 2)
# ('tt0364049', 'Adventures of Tarzan', 2)
# ('tt0405266', 'Raincoat', 2)
# ('tt0106541', 'Chandra Mukhi', 2)
# ('tt0349878', 'Netaji Subhas Chandra Bose: The Forgotten Hero', 2)
# ('tt0099869', 'Izzatdaar', 2)
# ('tt0118680', 'Banarasi Babu', 2)
# ('tt0833561', 'Woh Lamhe', 2)
# ('tt1385824', '13B: Fear Has a New Address', 2)
# ('tt0048613', 'Shree 420', 2)
# ('tt0369637', 'Kuch Naa Kaho', 2)
# ('tt0386650', 'Mounam Pesiyadhe', 6)
# ('tt0091256', 'Ijaazat', 2)
# ('tt0357328', 'Yeh Dil', 2)
# ('tt0363567', 'Dilwaala', 2)
# ('tt2876408', 'Mr Joe B. Carvalho', 2)
# ('tt0050665', 'Madhumati', 2)
# ('tt1083988', 'Journey Bombay to Goa: Laughter Unlimited', 2)
# ('tt2629322', 'Sri Siddhartha Gautama', 18)
# ('tt0061073', 'Teesri Manzil', 2)
# ('tt0060306', 'Devar', 2)
# ('tt0411469', 'Hazaaron Khwaishein Aisi', 2)
# ('tt1392744', 'Chance Pe Dance', 2)
# ('tt2255934', 'Aiyyaa', 2)
# ('tt6080746', 'Raag Desh', 2)
# ('tt0337613', 'Divya Shakti', 2)
# ('tt0266757', 'Mehboob Ki Mehndi', 2)
# ('tt0216707', 'Dil Kya Kare', 2)
# ('tt1182884', 'Dulha Mil Gaya', 2)
# ('tt0041161', 'Barsaat', 2)
# ('tt0059893', 'Waqt', 2)
# ('tt0287111', 'Wajood', 2)
# ('tt0214832', 'Kalicharan', 2)
# ('tt5638474', 'Wajah Tum Ho', 2)
# ('tt0255111', 'Dhadkan', 2)
# ('tt0244528', 'Hadh Kar Di Aapne', 2)
# ('tt1465493', 'Hum Tum Aur Ghost', 2)
# ('tt7028460', 'Teen Aur Aadha', 2)
# ('tt1637691', 'Khelein Hum Jee Jaan Sey', 2)
# ('tt0102705', 'Prem Pratigyaa', 2)
# ('tt0094979', 'The Deceivers', 0)
# ('tt1808221', 'Kaalo', 2)
# ('tt0250690', 'Refugee', 2)
# ('tt0384491', 'Samay: When Time Strikes', 2)
# ('tt1322257', 'Jhootha Hi Sahi', 2)
# ('tt0232960', 'Woh Kaun Thi?', 2)
# ('tt0117983', 'Tu Chor Main Sipahi', 2)
# ('tt1773109', 'Yamla Pagla Deewana', 2)
# ('tt1159926', 'City of Life', 11)
# ('tt4512230', 'Hey Bro', 2)
# ('tt5310090', 'Saala Khadoos', 2)
# ('tt0284137', 'Gadar: Ek Prem Katha', 2)
# ('tt1562859', 'Golmaal 3', 2)
# ('tt0104607', 'Khuda Gawah', 2)
# ('tt4621100', 'Nanak Shah Fakir', 2)
# ('tt2392447', 'Ungli', 2)
# ('tt0416120', 'Police Force: An Inside Story', 2)
# ('tt0061960', 'Pretty Polly', 0)
# ('tt1629295', 'I Am', 2)
# ('tt0430702', 'Tumsa Nahin Dekha', 2)
# ('tt0435079', 'Jangal Mein Mangal', 2)
# ('tt0049378', 'Jagte Raho', 2)
# ('tt0068305', 'Bombay to Goa', 2)
# ('tt0297416', 'Superman', 2)
# ('tt0054910', 'Gunga Jumna', 2)
# ('tt1512321', 'Vaada Raha... I Promise', 2)
# ('tt9007142', 'The Dark Side of Life: Mumbai City', 2)
# ('tt0319736', 'The Legend of Bhagat Singh', 2)
# ('tt1629715', 'Miss Lovely', 2)
# ('tt0119428', 'Judwaa', 2)
# ('tt0289685', 'Daava', 2)
# ('tt2814372', 'Gippi', 2)
# ('tt2727028', 'Total Siyapaa', 2)
# ('tt1370429', '99', 2)
# ('tt1664809', 'Rakhta Charitra', 2)
# ('tt0813996', 'Alag: He Is Different.... He Is Alone...', 2)
# ('tt0371922', 'Saaya', 2)
# ('tt1324078', 'Kal Kissne Dekha', 2)
# ('tt0205445', 'Tamanna', 2)
# ('tt0314006', 'Dum', 2)
# ('tt2796318', 'Mickey Virus', 2)
# ('tt3636776', 'Samrat & Co.', 2)
# ('tt3547616', 'All Is Well', 2)
# ('tt0232079', 'Mela', 2)
# ('tt2166214', 'Khiladi 786', 2)
# ('tt7560484', 'Gauru: Journey of Courage', 2)
# ('tt2064816', 'I, Me aur Main', 2)
# ('tt0291883', 'Ek Ladka Ek Ladki', 2)
# ('tt0946999', 'Deadline: Sirf 24 Ghante', 2)
# ('tt0056436', 'Sahib Bibi Aur Ghulam', 2)
# ('tt0260494', 'Veerana', 2)
# ('tt4323504', 'Jazbaa', 2)
# ('tt4906984', 'Azhar', 2)
# ('tt0429289', 'Tauba Tauba', 2)
# ('tt0311413', 'Krodh', 2)
# ('tt0326805', 'Chori Chori', 2)
# ('tt0286752', 'Keemat: They Are Back', 2)
# ('tt0105866', 'Yalgaar', 2)
# ('tt3776484', 'Zubaan', 2)
# ('tt8932884', 'Baarish Aur Chowmein', 2)
# ('tt1092005', 'Golmaal Returns', 2)
# ('tt0348824', 'Chalo Ishq Ladaaye', 2)
# ('tt0251320', 'Pehchaan', 2)
# ('tt0064241', 'Do Raaste', 2)
# ('tt0233264', 'Avtaar', 2)
# ('tt0114615', 'Taqdeerwala', 2)
# ('tt0060689', 'Mera Saaya', 2)
# ('tt0422950', 'Phir Milenge', 2)
# ('tt0983990', '1971', 2)
# ('tt0343850', 'Jai Vikraanta', 2)
# ('tt0347332', 'Khakee', 2)
# ('tt5513098', 'Autohead', 2)
# ('tt6642396', 'Jattu Engineer', 2)
# ('tt0152256', 'Saagar', 2)
# ('tt4501576', 'Dirty Politics', 2)
# ('tt0476550', 'God Tussi Great Ho', 2)
# ('tt0152278', 'Sanam', 2)
# ('tt0335044', 'Dil Vil Pyar Vyar', 2)
# ('tt1666308', 'Golimar', 4)
# ('tt0128985', 'Chalti Ka Naam Gaadi', 2)
# ('tt1828289', 'Shagird', 2)
# ('tt2571140', 'Boss', 2)
# ('tt0119285', 'Hero No. 1', 2)
# ('tt0807758', 'Partner', 2)
# ('tt1179781', 'Mission Istaanbul: Darr Ke Aagey Jeet Hai!', 2)
# ('tt5805252', 'Budhia Singh: Born to Run', 2)
# ('tt3886444', 'Khamoshiyan', 2)
# ('tt5784860', 'Aksar 2', 2)
# ('tt2429640', 'Murder 3', 2)
# ('tt0102636', 'Parinda', 2)
# ('tt1373156', 'Karthik Calling Karthik', 2)
# ('tt0383719', 'Xcuse Me', 2)
# ('tt0058257', 'Kashmir Ki Kali', 2)
# ('tt0059354', 'Khandan', 2)
# ('tt0243472', 'Paap Ki Duniya', 2)
# ('tt1916728', 'Shor in the City', 2)
# ('tt0422236', 'Fida', 2)
# ('tt4187650', "Trip to Bhangarh: Asia's Most Haunted Place", 2)
# ('tt1606267', 'Lafangey Parindey', 2)
# ('tt1372266', 'Kisaan', 2)
# ('tt0110140', 'Insaniyat', 2)
# ('tt3422462', 'Bangistan', 2)
# ('tt0345177', 'Ek Doctor Ki Maut', 2)
# ('tt0872190', 'Cash', 2)
# ('tt0110254', 'Khuddar', 2)
# ('tt1999935', 'Not a Love Story', 2)
# ('tt0288427', 'Angaaray', 2)
# ('tt0205380', 'Sanam Teri Kasam', 2)
# ('tt3683702', 'Fugly', 2)
# ('tt0485243', 'Jodi', 6)
# ('tt0397742', 'Yeh Vaada Raha', 2)
# ('tt0168529', 'Bombay Boys', 0)
# ('tt0805184', 'Bhagam Bhag', 2)
# ('tt0459605', 'Eklavya', 2)
# ('tt0265148', 'Main Prem Ki Diwani Hoon', 2)
# ('tt2978626', "It's Entertainment", 2)
# ('tt2988272', 'Shuddh Desi Romance', 2)
# ('tt3309662', 'Jackpot', 2)
# ('tt0105515', 'Tadipaar', 2)
# ('tt0445022', 'Jurm', 2)
# ('tt0151511', 'Mausam', 2)
# ('tt4979160', 'Ishq Forever', 2)
# ('tt0266439', 'Dacait', 2)
# ('tt0101244', '100 Days', 2)
# ('tt0354922', 'Snegithiye', 6)
# ('tt2358412', 'David', 6)
# ('tt0272688', 'Kasoor', 2)
# ('tt0055783', 'Bees Saal Baad', 2)
# ('tt1937092', 'Always Kabhi Kabhi', 2)
# ('tt0061046', 'Suraj', 2)
# ('tt6296236', 'Running Shaadi', 2)
# ('tt2615584', 'Phata Poster Nikhla Hero', 2)
# ('tt3848938', 'Mr. X', 2)
# ('tt1841542', 'Chillar Party', 2)
# ('tt2323964', 'Mere Dad Ki Maruti', 2)
# ('tt0451631', 'Apaharan', 2)
# ('tt2406636', 'Bhoot Returns', 2)
# ('tt0995827', 'The Train: Some Lines Should Never Be Crossed...', 2)
# ('tt0954914', 'Athidhi', 4)
# ('tt0114236', 'Ravan Raaj: A True Story', 2)
# ('tt0278522', 'Jodi No.1', 2)
# ('tt0099652', 'Ghayal', 2)
# ('tt2510874', 'Yamla Pagla Deewana 2', 2)
# ('tt5125414', 'Amazon Obhijaan', 17)
# ('tt0187188', 'Johnny', 6)
# ('tt0366985', 'Rudraksh', 2)
# ('tt0102645', 'Patthar Ke Phool', 2)
# ('tt0833484', 'The Killer', 2)
# ('tt1890513', 'Ragini MMS', 2)
# ('tt0995752', 'Tashan', 2)
# ('tt0373856', 'Gangaajal', 2)
# ('tt0244585', 'Khubsoorat', 2)
# ('tt0289845', 'Aks', 2)
# ('tt0239495', 'Jaal', 2)
# ('tt0457875', 'Ek Ajnabee', 2)
# ('tt0443331', 'Milenge Milenge', 2)
# ('tt0087975', 'Raaj Tilak', 2)
# ('tt0301231', 'Duniya', 2)
# ('tt0172519', 'Guddu', 2)
# ('tt2082436', 'Sultanat', 2)
# ('tt1039989', 'Sunday', 2)
# ('tt0248428', 'Shiva', 4)
# ('tt0216110', 'Pratiggya', 2)
# ('tt0089413', 'Khamosh', 2)
# ('tt1126516', 'Money Hai Toh Honey Hai', 2)
# ('tt0979891', 'Hattrick', 2)
# ('tt2319889', 'Jannat 2', 2)
# ('tt3803860', 'Puli', 6)
# ('tt0233422', 'Chachi 420', 2)
# ('tt0114231', 'Ram Jaane', 2)
# ('tt5886216', 'Veeram', 2)
# ('tt0349703', 'Kyun! Ho Gaya Na...', 2)
# ('tt0320736', 'Vikram', 6)
# ('tt0488381', 'Corporate', 2)
# ('tt0101732', 'Dil Aashna Hai ...The Heart Knows', 2)
# ('tt0331256', 'Gunaah', 2)
# ('tt0155985', 'Pyari Behna', 2)
# ('tt0329393', 'Mr. and Mrs. Iyer', 0)
# ('tt0201840', 'Phörpa', 2)
# ('tt0770214', 'Kabul Express', 2)
# ('tt0361772', 'Jeete Hain Shaan Se', 2)
# ('tt0147925', 'Brahmachari', 2)
# ('tt2573750', 'Gulaab Gang', 2)
# ('tt0067164', 'Guddi', 2)
# ('tt0230347', 'Jaanwar', 2)
# ('tt5639388', 'Raaz Reboot', 2)
# ('tt5784852', 'Tera Intezaar', 2)
# ('tt2404027', 'Arjun: The Warrior Prince', 2)
# ('tt0292740', 'Yeh Raaste Hain Pyaar Ke', 2)
# ('tt0277981', 'Rahul', 2)
# ('tt0046799', 'Boot Polish', 2)
# ('tt6499258', 'Wedding Anniversary', 2)
# ('tt0108109', 'Shatranj', 2)
# ('tt1229390', 'Shortkut - The Con Is On', 2)
# ('tt5909308', 'Days of Tafree', 2)
# ('tt5978194', 'Bhouri', 2)
# ('tt0206921', 'Mann', 2)
# ('tt0421277', 'Julie', 2)
# ('tt2909396', 'Santa Banta Pvt Ltd', 0)
# ('tt0108001', 'Rudaali', 2)
# ('tt0422689', 'Madurey', 6)
# ('tt4045666', 'Mumbai Delhi Mumbai', 2)
# ('tt0172980', 'Pehla Nasha', 2)
# ('tt2621000', 'Jolly LLB', 2)
# ('tt0451803', 'Maine Pyaar Kyun Kiya', 2)
# ('tt1535467', 'Patiala House', 2)
# ('tt0152836', 'Taal', 2)
# ('tt0347278', 'Jhankaar Beats', 2)
# ('tt3038772', 'Kaanchi', 2)
# ('tt0245825', 'Chal Mere Bhai', 2)
# ('tt0083820', 'Desh Premee', 2)
# ('tt2186731', 'Department', 2)
# ('tt2208248', 'Machhli Jal Ki Rani Hai', 2)
# ('tt0347779', 'Pinjar: Beyond Boundaries...', 2)
# ('tt0098461', 'Thanedaar', 2)
# ('tt1492872', 'Hide & Seek', 2)
# ('tt0246009', 'Kondaveeti Raja', 4)
# ('tt0292742', 'Zakhmi Dil', 2)
# ('tt1725795', '7 Aum Arivu', 6)
# ('tt4596814', 'S/O Satyamurthy', 4)
# ('tt0397882', 'Ab Tumhare Hawale Watan Saathiyo', 2)
# ('tt0112313', 'Akele Hum Akele Tum', 2)
# ('tt5370442', 'Balu Mahi', 12)
# ('tt1245774', 'Jail', 2)
# ('tt1283956', 'Student No. 1', 4)
# ('tt0239235', 'Anji', 4)
# ('tt1600439', 'Shaapit: The Cursed', 2)
# ('tt0408837', 'Hawas', 2)
# ('tt0209263', 'Pyaar Koi Khel Nahin', 2)
# ('tt0213753', 'Kadhalar Dinam', 6)
# ('tt0251194', 'Mahaanta: The Film', 2)
# ('tt0211126', 'Zakhm', 2)
# ('tt0477252', '36 China Town', 2)
# ('tt0907674', 'Amal', 2)
# ('tt0267363', 'Chandni Bar', 2)
# ('tt0091284', 'Janbaaz', 2)
# ('tt0081401', 'Ram Balram', 2)
# ('tt0361436', 'Chhota Chetan', 2)
# ('tt3822600', 'Amit Sahni Ki List', 2)
# ('tt0157316', 'Ankush', 2)
# ('tt0892874', 'Halla Bol', 2)
# ('tt6352548', 'Poster Boys', 2)
# ('tt0271748', 'Raju Chacha', 2)
# ('tt0187271', 'Masterji', 2)
# ('tt0061650', 'Farz', 2)
# ('tt0251756', 'Jungle', 2)
# ('tt0086925', 'Baazi', 2)
# ('tt0857381', 'I See You', 2)
# ('tt4287778', 'Shab', 2)
# ('tt2122340', 'Ferrari Ki Sawaari', 2)
# ('tt0135140', 'Anth', 2)
# ('tt0094299', 'Watan Ke Rakhwale', 2)
# ('tt0349333', 'Darna Mana Hai', 2)
# ('tt1343362', 'Do Knot Disturb', 2)
# ('tt0189633', 'Kareeb', 2)
# ('tt0290820', 'Raakh', 2)
# ('tt0443594', 'Naina', 2)
# ('tt0286707', 'Humse Badhkar Kaun: The Entertainer', 2)
# ('tt0376080', 'Platform', 2)
# ('tt0341549', 'Rishtey', 2)
# ('tt5313980', 'Tere Bin Laden: Dead Or Alive', 2)
# ('tt0107777', 'Parampara', 2)
# ('tt1242782', 'Luck', 2)
# ('tt0137100', 'Maya', 2)
# ('tt0122427', 'Chaalbaaz', 2)
# ('tt5717110', 'Tum Bin 2', 2)
# ('tt3382148', 'Yaariyan', 2)
# ('tt0043307', 'Baazi', 2)
# ('tt0341455', 'Makdee', 2)
# ('tt0454429', 'Chingaari', 2)
# ('tt0399942', 'Paap', 2)
# ('tt3645014', 'The Xpose', 2)
# ('tt1014672', 'Bheja Fry', 2)
# ('tt0476884', 'Taxi No. 9 2 11: Nau Do Gyarah', 2)
# ('tt0298607', 'Yeh Zindagi Ka Safar', 2)
# ('tt0391079', 'Dil Pardesi Ho Gayaa', 2)
# ('tt0252358', 'Darwaza', 2)
# ('tt0157339', 'Baton Baton Mein', 2)
# ('tt0158534', 'The Burning Train', 2)
# ('tt0363472', 'Bewafaa', 2)
# ('tt0101733', 'Dil Hai Ki Manta Nahin', 2)
# ('tt6078866', 'Soni', 2)
# ('tt0084532', 'Prem Rog', 2)
# ('tt1447508', 'Peepli Live', 2)
# ('tt0155074', 'Pyar Ka Mandir', 2)
# ('tt0295682', 'The Warrior', 2)
# ('tt2389974', 'Aatma', 2)
# ('tt3290688', 'Revolver Rani', 2)
# ('tt0331479', 'Ek Chhotisi Love Story', 2)
# ('tt0155088', 'Rajput', 2)
# ('tt2375567', 'Super Model', 0)
# ('tt0060104', 'Amrapali', 2)
# ('tt0175423', 'Aap Ki Kasam', 2)
# ('tt0208903', 'Disco Dancer', 2)
# ('tt0172234', 'Chaahat', 2)
# ('tt5458088', 'Kammatti Paadam', 2)
# ('tt4541102', 'Uvaa', 2)
# ('tt2691010', 'Mumbai 125 KM 3D', 2)
# ('tt1090650', 'Dhokha', 2)
# ('tt0111384', 'Teesra Kaun?', 2)
# ('tt1485072', 'Teree Sang: A Kidult Love Story', 2)
# ('tt0053637', 'Barsaat Ki Raat', 2)
# ('tt0453978', 'Yakeen', 2)
# ('tt0485513', 'Main, Meri Patni... Aur Woh!', 2)
# ('tt0444849', 'Karam', 2)
# ('tt0225515', 'Dillagi', 2)
# ('tt0102119', 'Indrajeet', 2)
# ('tt0361505', 'Dharmatma', 2)
# ('tt0060659', 'Mamta', 2)
# ('tt0824316', 'Dor', 2)
# ('tt0148375', 'Khilona', 2)
# ('tt4358344', 'Rough Book', 2)
# ('tt5791986', 'III Smoking Barrels', 0)
# ('tt0843328', 'Chatrapathi', 4)
# ('tt1202540', 'Dil Bole Hadippa!', 2)
# ('tt1216300', 'Jannat: In Search of Heaven...', 2)
# ('tt0096827', 'Apoorva Sagodharargal', 6)
# ('tt0214866', 'Krodhi', 2)
# ('tt0328671', 'Yeh Hai Jalwa', 2)
# ('tt0240084', 'Thammudu', 4)
# ('tt0156659', 'Jurm', 2)
# ('tt0260077', 'Hotel', 2)
# ('tt1158700', 'Desh Drohi', 2)
# ('tt0033616', 'Footsteps in the Dark', 0)
# ('tt0117623', 'Shastra', 2)
# ('tt3848888', 'The Shaukeens', 2)
# ('tt0402230', 'The Great New Wonderful', 0)
# ('tt0476649', 'Darna Zaroori Hai', 2)
# ('tt1904875', 'Dharti', 7)
# ('tt0322027', 'Dil Tera Diwana', 2)
# ('tt3375154', 'Mangalashtak Once More', 1)
# ('tt0260155', 'Mahakaal', 2)
# ('tt0206020', 'Hote Hote Pyar Hogaya', 2)
# ('tt0845494', 'Nanhe Jaisalmer: A Dream Come True', 2)
# ('tt4853926', 'Guddu Ki Gun', 2)
# ('tt0091598', 'Naam', 2)
# ('tt1508950', 'Baabarr', 2)
# ('tt0155775', 'Jawani Diwani', 2)
# ('tt0305455', 'Pitaah', 2)
# ('tt0113913', 'Naajayaz', 2)
# ('tt0313495', 'Prem Geet', 2)
# ('tt3449320', 'Darr @ the Mall', 2)
# ('tt5289170', 'Laali Ki Shaadi Mein Laaddoo Deewana', 2)
# ('tt0112738', 'Criminal', 2)
# ('tt0261001', 'Khoj', 2)
# ('tt0327761', 'Gemini', 6)
# ('tt0076527', 'Parvarish', 2)
# ('tt0205968', 'Gharwali Baharwali', 2)
# ('tt0107166', 'Hum Hain Rahi Pyar Ke', 2)
# ('tt0101283', 'Ajooba', 2)
# ('tt0477857', 'Sehar', 2)
# ('tt1446071', 'Gallit Gondhal, Dillit Mujra', 2)
# ('tt0459475', 'Naam Gum Jaayega', 2)
# ('tt0116002', 'Daayraa', 2)
# ('tt4760750', 'Bezubaan Ishq', 2)
# ('tt0172300', 'Daulat Ki Jung', 2)
# ('tt1605790', 'Zokkomon', 2)
# ('tt1781838', 'Isi Life Mein...!', 2)
# ('tt0233206', 'Amrit', 2)
# ('tt0309618', 'Gaddaar', 2)
# ('tt0324951', '23rd March 1931: Shaheed', 2)
# ('tt1479667', 'Aagey Se Right', 2)
# ('tt0408976', 'Krishna Cottage', 2)
# ('tt0095955', 'Ram-Avtar', 2)
# ('tt0286936', 'Salaakhen', 2)
# ('tt0285958', 'Pyaar Ishq Aur Mohabbat', 2)
# ('tt0456413', 'Fight Club: Members Only', 2)
# ('tt2191721', 'Jodi Breakers', 2)
# ('tt0053965', 'Jis Desh Men Ganga Behti Hai', 2)
# ('tt2976176', 'Lakshmi', 2)
# ('tt5896934', 'Aa Gaya Hero', 2)
# ('tt0081491', 'Shaan', 2)
# ('tt2275794', 'Gori Tere Pyaar Mein!', 0)
# ('tt5632164', 'Veerappan', 2)
# ('tt2292625', 'Chakravyuh', 2)
# ('tt0255112', 'Dhaai Akshar Prem Ke', 2)
# ('tt0049072', 'Chori Chori', 2)
# ('tt0364604', 'Plan', 2)
# ('tt0332313', 'Periyanna', 6)
# ('tt0359157', 'Dil Hai Betaab', 19)
# ('tt0978642', 'Masoom', 2)
# ('tt0246420', 'Amanush', 2)
# ('tt0309087', 'Yeh Mohabbat Hai', 2)
# ('tt0247936', 'Arpan', 2)
# ...
# ('tt0036077', 'Kismet', 2)
# ('tt0830938', 'Overnight', 26)
# ('tt1504687', 'I Am Singh', 2)
# ('tt0158451', 'Aaj Ki Awaz', 2)
# ('tt0262281', 'Bhookailas', 4)
# ('tt0445033', 'Mass', 4)
# ('tt0152509', 'Sohni Mahiwal', 7)
# ('tt0312883', 'Kya Yehi Pyaar Hai', 2)
# ('tt0125556', 'Tohfa', 2)
# ('tt0247944', 'Badal', 2)
# ('tt2922076', 'Veera Parampare', 15)
# ('tt0244674', 'Naukri', 2)
# ('tt0363634', 'Ghar Ka Chiraag', 2)
# ('tt0178181', 'Aamne - Saamne', 2)
# ('tt0140677', 'Vetri Vizha', 6)
# ('tt0145851', 'Jagriti', 2)
# ('tt0301240', 'Moksha: Salvation', 2)
# ('tt0419828', 'Hyderabad Blues 2', 0)
# ('tt0375021', 'Rules: Pyaar Ka Superhit Formula', 2)
# ('tt0069751', 'Bandhe Haath', 2)
# ('tt0105161', 'Pratikar', 2)
# ('tt0246913', 'Saraswathi Sabatham', 6)
# ('tt3095248', 'Kaafiron Ki Namaaz', 2)
# ('tt0375733', 'Encounter: The Killing', 2)
# ('tt0949524', 'Faryad moorcheha', 27)
# ('tt2137171', 'Oass', 2)
# ('tt0158259', 'Taqdeer', 2)
# ('tt0117099', 'Mr. Bechara', 2)
# ('tt1474271', 'Love Khichdi', 2)
# ('tt0246261', 'Surakksha', 2)
# ('tt0075411', 'Wan Pipel', 14)
# ('tt2327389', 'Life Ki Toh Lag Gayi', 2)
# ('tt0473684', 'Pehchaan: The Face of Truth', 2)
# ('tt1210356', 'Raat Gayi, Baat Gayi?', 2)
# ('tt1612039', 'Souryam', 4)
# ('tt0283911', 'Bas Itna Sa Khwaab Hai...', 2)
# ('tt1454567', 'Team: The Force', 2)
# ('tt0027256', 'Achhut Kanya', 2)
# ('tt2706340', 'Ishk Actually', 2)
# ('tt2951596', 'Partha', 15)
# ('tt0272001', 'Bindhaast', 1)
# ('tt0254247', 'Daisy', 2)
# ('tt0157418', 'Bombay 405 Miles', 2)
# ('tt2354223', 'Mumbai Cha Raja', 2)
# ('tt0286504', 'Beti No. 1', 2)
# ('tt0186799', 'Dharm Adhikari', 2)
# ('tt0145856', 'Jhanak Jhanak Payal Baaje', 2)
# ('tt4920116', 'Halla Gulla', 12)
# ('tt1634329', 'Fruit & Nut', 2)
# ('tt0317751', 'Janwar', 2)
# ('tt6722870', 'Kadamban', 6)
# ('tt0843335', 'Desamuduru', 4)
# ('tt0193449', 'Rang', 2)
# ('tt0331421', 'Akhiyon Se Goli Maare', 2)
# ('tt0099953', 'Kroadh', 2)
# ('tt0318405', 'Love in Simla', 2)
# ('tt0271023', 'Kab? Kyoon? Aur Kahan?', 2)
# ('tt0087736', 'Mohan Joshi Hazir Ho!', 2)
# ('tt0410954', 'Sheen', 2)
# ('tt0071714', 'Kasauti', 2)
# ('tt0982875', 'Gauri: The Unborn', 2)
# ('tt0064371', 'Gladiatorerna', 0)
# ('tt0068620', 'Garam Masala', 2)
# ('tt1867070', 'Teen Thay Bhai', 2)
# ('tt0249818', 'Mrugaraaju', 4)
# ('tt1606162', 'Aakhari Decision', 2)
# ('tt0988036', 'Fear', 2)
# ('tt1071798', 'Frozen', 2)
# ('tt0071083', '27 Down', 2)
# ('tt0217608', 'Laawaris', 2)
# ('tt0026274', 'Devdas', 2)
# ('tt0084744', 'Swami Dada', 2)
# ('tt0107821', 'Phool Aur Angaar', 2)
# ('tt0130348', 'Vinashak - Destroyer', 2)
# ('tt0367214', 'Waaris', 2)
# ('tt0098491', 'Toofan', 2)
# ('tt5755594', 'Hello Mumbai: Salaam Mumbai', 27)
# ('tt0493437', 'Apna Sapna Money Money', 2)
# ('tt0317680', 'Hum Hain Kamaal Ke', 2)
# ('tt0417735', 'The Hangman', 2)
# ('tt1979209', 'Chala Mussaddi - Office Office', 2)
# ('tt0485204', 'Duet', 6)
# ('tt0081147', 'Meera', 2)
# ('tt0099437', 'Disha', 2)
# ('tt0978570', 'Bhageeratha', 4)
# ('tt1999857', 'Cycle Kick', 2)
# ('tt0944185', 'Andhrudu', 4)
# ('tt0043078', 'The 20 Questions Murder Mystery', 0)
# ('tt1388424', 'Three: Love, Lies, Betrayal', 2)
# ('tt2959626', 'Nalla', 15)
# ('tt0225566', 'Drohi', 2)
# ('tt1500682', 'Aadmi Ki Aurat Aur Anya Kahaniya', 2)
# ('tt1583218', 'Allari Ramudu', 4)
# ('tt1079967', 'Hastey Hastey Follow Your Heart', 2)
# ('tt0249358', 'Ankahee', 2)
# ('tt0155530', 'Bandhan', 2)
# ('tt0172487', 'The Gentleman', 2)
# ('tt1112110', 'Hollywood', 0)
# ('tt2188811', 'Luv U Soniyo', 2)
# ('tt0050734', 'Musafir', 2)
# ('tt1688092', 'Yagnam', 4)
# ('tt0308417', 'Is Raat Ki Subah Nahin', 2)
# ('tt0249866', 'Paromitar Ek Din', 17)
# ('tt0309800', 'Chota Jadugar', 6)
# ('tt0357208', 'Stumped', 2)
# ('tt5759540', 'Missing on a Weekend', 2)
# ('tt0893585', 'Detective Naani', 2)
# ('tt2613458', 'Khoya', 0)
# ('tt1579691', 'Rowdy Inspector', 4)
# ('tt5052972', 'Yaara Silly Silly', 2)
# ('tt0314186', 'Humko Tumse Pyaar Hai', 2)
# ('tt0308347', 'Haan Maine Bhi Pyaar Kiya', 2)
# ('tt1947973', 'Bin Bulaye Baraati', 2)
# ('tt0094720', 'Bees Saal Baad', 2)
# ('tt0177490', 'Aghaat', 2)
# ('tt0331453', 'Chhal', 2)
# ('tt0122233', 'Saaz', 2)
# ('tt0050956', 'Sharada', 2)
# ('tt1124386', 'Pankh', 2)
# ('tt1268906', 'Samudram', 4)
# ('tt1605778', 'Toh Baat Pakki!', 2)
# ('tt0823261', 'Zindaggi Rocks', 2)
# ('tt1095038', 'Victoria No. 203: Diamonds Are Forever', 2)
# ('tt2389486', 'Mai', 2)
# ('tt2190256', 'Daal Mein Kuch Kaala Hai', 2)
# ('tt7191668', 'The Rally', 2)
# ('tt3666258', 'Coffee Bloom', 2)
# ('tt0156833', 'Naya Din Nai Raat', 2)
# ('tt0047271', 'Naukari', 2)
# ('tt3693936', 'Once Upon a Time in Bihar', 2)
# ('tt0048181', 'House No. 44', 2)
# ('tt8338754', "Vaibhav Sethia: Don't", 0)
# ('tt0280396', 'Adharm', 2)
# ('tt0260107', 'Jeevan Dhaara', 2)
# ('tt1152845', 'Showbiz', 2)
# ('tt0431776', 'Andarivaadu', 4)
# ('tt0177483', 'Aadmi', 2)
# ('tt1941638', 'Sadda Adda', 2)
# ('tt0470381', 'Jaan Tere Naam', 2)
# ('tt0156745', 'Loafer', 2)
# ('tt0267617', 'Jigar', 2)
# ('tt0155499', 'Antarnaad', 2)
# ('tt2063749', 'Pazhani', 6)
# ('tt0442799', 'Kis Kis Ki Kismat', 27)
# ('tt0232585', 'Sapnon Ka Saudagar', 2)
# ('tt0141819', 'Shaheed', 2)
# ('tt0085785', 'Khandhar', 2)
# ('tt0046164', 'Parineeta', 2)
# ('tt1594964', 'Chase', 2)
# ('tt0217351', 'Dahek: A Burning Passion', 2)
# ('tt0299078', 'Palkon Ki Chhaon Mein', 2)
# ('tt0286942', 'Sardari Begum', 12)
# ('tt0049549', 'New Delhi', 2)
# ('tt0286664', 'Gudgudee', 2)
# ('tt0317796', 'Kalaignan', 6)
# ('tt0057332', 'Mujhe Jeene Do', 2)
# ('tt0949423', 'Hotel Very Welcome', 0)
# ('tt0178211', 'Ab Ayega Mazaa', 2)
# ('tt1499935', 'Shadow', 2)
# ('tt0178207', 'Aashiq Hoon Baharon Ka', 2)
# ('tt3319248', 'A Film by Aravind', 4)
# ('tt0459554', 'Subhash Chandra Bose', 4)
# ('tt0215466', 'Achanak', 2)
# ('tt0141441', 'Jogan', 2)
# ('tt0070009', 'Duvidha', 2)
# ('tt0151090', 'Jaan', 2)
# ('tt0232081', 'Mera Gaon Mera Desh', 2)
# ('tt0234207', 'Marte Dam Tak', 2)
# ('tt0186857', 'Banjaran', 2)
# ('tt0091601', 'Nagina', 2)
# ('tt1990976', '7 Welcome to London', 2)
# ('tt0470611', 'Yatra', 2)
# ('tt0244549', 'Inspector Balram', 19)
# ('tt2222716', 'Baat Bann Gayi', 2)
# ('tt1016177', 'Go', 2)
# ('tt0361515', 'Do Jasoos', 2)
# ('tt0099467', 'Drishti', 2)
# ('tt0187576', 'Vazhve Mayam', 6)
# ('tt0286934', 'Safari', 2)
# ('tt0447890', 'Chaahat Ek Nasha...', 2)
# ('tt0237132', 'Dadar Kirti', 17)
# ('tt0272651', 'Hari-Bhari', 2)
# ('tt0241753', 'Naseem', 2)
# ('tt0283580', 'Satyameva Jayate', 19)
# ('tt3672618', 'Dekh Tamasha Dekh', 2)
# ('tt2938702', 'Attahaasa', 15)
# ('tt1674757', 'Veettilekkulla Vazhi', 19)
# ('tt0257475', 'Chhailla Babu', 2)
# ('tt0103763', 'Balwaan', 2)
# ('tt0259877', 'Bandh Darwaza', 2)
# ('tt0111625', 'Vijaypath', 2)
# ('tt0097926', 'Mujrim', 2)
# ('tt0217632', 'Love You Hamesha', 2)
# ('tt0139447', 'Majhli Didi', 2)
# ('tt1649760', 'The Film Emotional Atyachar', 2)
# ('tt0310865', 'Chann Pardesee', 7)
# ('tt0324977', 'Alavuddinum Athbutha Vilakkum', 19)
# ('tt1825665', 'Bach ke Zara', 2)
# ('tt0924271', 'Raghavendra', 4)
# ('tt0110105', 'Ikke Pe Ikka', 2)
# ('tt4944418', 'Man On Mission Jaanbaaz', 2)
# ('tt0251067', 'Ek Hota Vidushak', 1)
# ('tt2624852', 'Gangoobai', 2)
# ('tt0875693', 'Anjaam', 2)
# ('tt0379504', 'Shriman Shrimati', 2)
# ('tt1132595', 'Maan Gaye Mughall-E-Azam', 2)
# ('tt5914630', 'Chudail Story', 2)
# ('tt0233587', 'Do Kaliyaan', 2)
# ('tt0307682', 'Yeh Dil Aashiqanaa', 2)
# ('tt0187192', 'Julie', 2)
# ('tt5544662', 'Sweetiee Weds NRI', 2)
# ('tt0105315', 'Sapne Saajan Ke', 2)
# ('tt3153580', 'Barefoot to Goa', 2)
# ('tt2066899', 'Jugaad', 2)
# ('tt0278761', 'Tarpan The Absolution', 2)
# ('tt0155408', 'Zara Si Zindagi', 2)
# ('tt2191164', 'Station', 2)
# ('tt1955036', 'Vakratunda Mahakaaya', 1)
# ('tt2343417', 'Chhodo Kal Ki Baatein', 2)
# ('tt1515210', 'Vihir', 1)
# ('tt0874854', 'Anjaane: The Unkown', 2)
# ('tt1220718', 'Via Darjeeling', 2)
# ('tt1887817', 'Monica', 2)
# ('tt0429541', 'Afsana Dilwalon Ka', 12)
# ('tt1801521', 'Khap', 2)
# ('tt0857385', 'Kudiyon Ka Hai Zamaana', 2)
# ('tt0459466', 'Mera Dil Leke Dekho', 2)
# ('tt1132606', 'Ugly Aur Pagli', 2)
# ('tt0186794', 'Thayillamal Nannilai', 6)
# ('tt2084863', "Jo Dooba So Paar: It's Love in Bihar!", 2)
# ('tt0215515', 'Anand Math', 2)
# ('tt0275381', 'Grahan', 2)
# ('tt0091105', 'Genesis', 2)
# ('tt0137341', 'Ab Dilli Dur Nahin', 2)
# ('tt0157844', 'Jagir', 2)
# ('tt0172188', 'Bol Radha Bol', 2)
# ('tt0173283', 'Swarg', 2)
# ('tt0432090', 'Bunny', 4)
# ('tt1725798', 'Be-Careful', 2)
# ('tt1610418', 'Prem Kaa Game', 2)
# ('tt3030720', 'Dilwale:The Brave Heart', 2)
# ('tt0447659', 'Lezioni di volo', 28)
# ('tt0088986', 'Damul', 2)
# ('tt1183944', 'Sadiyaan: Boundaries Divide... Love Unites', 2)
# ('tt0362204', 'Supari', 2)
# ('tt0096355', 'Uttar Dakshin', 2)
# ('tt1587424', 'Radio: Love on Air', 2)
# ('tt7496256', 'Gospel Movie: Who Is My Lord', 0)
# ('tt4511416', 'Badmashiyaan', 2)
# ('tt0819777', 'Jigyaasa', 2)
# ('tt3737442', 'Oraalppokkam', 6)
# ('tt0979913', 'Life Mein Kabhie Kabhiee', 2)
# ('tt0071317', 'Chorus', 2)
# ('tt0290940', 'Zaalim', 2)
# ('tt0231646', 'Ghar Ghar Ki Kahani', 2)
# ('tt0318956', 'Tum Se Achcha Kaun Hai', 2)
# ('tt0267703', 'Maidan-E-Jung', 2)
# ('tt0213532', 'Budtameez', 2)
# ('tt0402606', 'Suno Sasurjee', 2)
# ('tt0396782', 'Paisa Vasool', 2)
# ('tt0158071', 'Pasand Apni Apni', 2)
# ('tt1630613', 'Soch Lo', 2)
# ('tt1606319', 'Prematho Raa', 4)
# ('tt1869759', 'The Train', 19)
# ('tt1649404', 'Sankham', 4)
# ('tt5049906', 'Subah Subah', 2)
# ('tt0390079', 'Hari Om', 0)
# ('tt1390840', 'Walkaway', 0)
# ('tt0303187', 'Veer Savarkar', 2)
# ('tt1135931', 'Chintu Ji', 2)
# ('tt0060317', 'Do Dooni Char', 2)
# ('tt2253708', 'Future to Bright Hai Ji', 2)
# ('tt2951534', 'Chandu', 15)
# ('tt0258647', 'Heeralal Pannalal', 2)
# ('tt1431729', 'Mohandas', 2)
# ('tt0092599', 'Awara Baap', 2)
# ('tt2084939', 'Sivappathikaaram', 6)
# ('tt0268489', 'Naughty Boy', 2)
# ('tt0929630', 'Veerabhadra', 4)
# ('tt2248905', 'Madly Bangali', 0)
# ('tt0104941', 'Muqabla', 2)
# ('tt0148691', 'Sachaa Jhutha', 2)
# ('tt0478868', 'Koi Mere Dil Mein Hai', 2)
# ('tt0116726', 'Jung', 2)
# ('tt0217660', 'Mohabbat', 2)
# ('tt2798620', 'Chhota Bheem and the Curse of Damyaan', 2)
# ('tt0309926', 'Noorie', 2)
# ('tt0349058', '88 Antop Hill', 2)
# ('tt0173189', 'Shanti Kranti', 4)
# ('tt0319336', 'Eduruleni Manishi', 2)
# ('tt1821385', 'Curry Munchers', 0)
# ('tt0130797', 'Jaali Note', 2)
# ('tt0097268', 'Ek Din Achanak', 2)
# ('tt3073326', 'Goopi Gawaiya Bagha Bajaiya', 2)
# ('tt0250043', 'Thodasa Roomani Ho Jaayen', 2)
# ('tt2112978', 'Jo Hum Chahein', 2)
# ('tt1773042', "Shahrukh Bola 'Khoobsurat Hai Tu'... And She Believed in It", 2)
# ('tt1108831', 'Chhodon Naa Yaar', 2)
# ('tt0080435', 'Bhavni Bhavai', 22)
# ('tt3261022', 'Kajarya', 2)
# ('tt0414503', 'Shaadi Ka Laddoo', 2)
# ('tt0364698', 'Thee', 6)
# ('tt0398404', 'God Only Knows!', 0)
# ('tt2924844', 'Nandhi', 15)
# ('tt0066514', 'Uski Roti', 2)
# ('tt0269821', 'Ravoyi Chandamama', 2)
# ('tt0087958', 'Pyar Jhukta Nahin', 2)
# ('tt0242509', 'Haatim Tai', 2)
# ('tt0114225', 'Raghuveer', 2)
# ('tt0260222', 'Naseeb Apna Apna', 2)
# ('tt1111869', '50 Lakh', 2)
# ('tt2914898', 'Gooli', 15)
# ('tt0430480', 'Popcorn Khao! Mast Ho Jao', 2)
# ('tt0453842', 'Sau Jhooth Ek Sach', 2)
# ('tt0827202', 'Sanshodhan', 2)
# ('tt2950606', 'Kiccha Huccha', 15)
# ('tt0378350', 'Meri Biwi Ki Shaadi', 2)
# ('tt4309284', 'The Silent Heroes', 2)
# ('tt0476847', 'Raakh: A Poem Masked in Blood', 2)
# ('tt4971292', 'Uyirile Kalanthathu', 2)
# ('tt0488976', 'C U at 9', 2)
# ('tt0785069', 'Umar', 2)
# ('tt0039654', 'Neel Kamal', 2)
# ('tt1814619', 'Aashiqui.in', 2)
# ('tt0038491', 'Dr. Kotnis Ki Amar Kahani', 2)
# ('tt0278274', 'Azaad', 4)
# ('tt0452236', 'Ginny Aur Johny', 2)
# ('tt1563732', '5 Ghantey Mien 5 Crore', 2)
# ('tt0230294', 'Hip Hip Hurray', 2)
# ('tt0214853', 'Killer', 4)
# ('tt0319351', 'Enakkul Oruvan', 6)
# ('tt0246567', 'Diksha', 2)
# ('tt1097006', 'Kaisay Kahein...', 2)
# ('tt0227496', 'Shreemaan Aashique', 2)
# ('tt0423313', 'Tahalka', 2)
# ('tt0286488', 'Barood', 2)
# ('tt0177487', 'Aag Hi Aag', 2)
# ('tt0448121', 'Sins', 2)
# ('tt0359215', 'Elaan-E-Jung', 2)
# ('tt2429930', 'Khwaabb', 2)
# ('tt0381090', 'Chupke Se', 2)
# ('tt4946222', 'Man on Mission Fauladi', 2)
# ('tt1087852', 'The Great Indian Butterfly', 0)
# ('tt0070498', 'Padatik', 2)
# ('tt1236441', 'Phir Kabhi', 2)
# ('tt0345594', 'Love at Times Square', 2)
# ('tt1399602', 'Straight', 2)
# ('tt0157917', 'Lakhon Ki Baat', 2)
# ('tt0246255', 'Stoovertpuram Police Station', 4)
# ('tt0193102', 'Dil Ka Kya Kasoor', 2)
# ('tt0272062', 'Daag: The Fire', 2)
# ('tt0233979', 'Zapatlela', 1)
# ('tt0278315', 'Arjun Pandit', 2)
# ('tt2838554', 'Khokababu', 17)
# ('tt0409068', 'Muskaan', 2)
# ('tt0328810', 'Aamaar Bhuvan', 17)
# ('tt0415820', 'Ghar Grihasti', 2)
# ('tt0093555', 'Mohre', 2)
# ('tt1358852', 'Madholal Keep Walking', 2)
# ('tt1024852', 'Meerabai Not Out', 2)
# ('tt1740017', 'Payback', 2)
# ('tt0142521', 'Lal Darja', 17)
# ('tt0358914', 'Aavida Maa Aavide', 4)
# ('tt1584917', 'Bolo Raam', 2)
# ('tt1503640', 'Damadamm!', 2)
# ('tt1942905', 'Kucch Luv Jaisaa', 2)
# ('tt0449982', 'Hum Dum', 2)
# ('tt2373632', 'Kalloori Vaasal', 6)
# ('tt1285147', 'Visakha Express', 4)
# ('tt2997780', 'Edegarike', 15)
# ('tt0420854', 'Ranga S.S.L.C', 15)
# ('tt0125485', 'Sazaye Maut', 2)
# ('tt2950478', 'Mr. Theertha', 15)
# ('tt1630282', 'Sahi Dhandhe Galat Bande', 2)
# ('tt0353675', 'Love Birds', 6)
# ('tt0374342', 'Yaad Rakhegi Duniya', 2)
# ('tt0102513', 'Narasimha', 2)
# ('tt0246766', 'Maa', 2)
# ('tt0165625', 'Ankhiyon Ke Jharokhon Se', 2)
# ('tt0321067', 'Ab Ke Baras', 2)
# ('tt0267252', 'Ajay', 2)
# ('tt0082314', 'Ek Duuje Ke Liye', 2)
# ('tt0929754', 'Ganga', 29)
# ('tt0246204', 'Rudranetra', 4)
# ('tt1886663', 'Satrangee Parachute', 2)
# ('tt0095857', 'Pestonjee', 2)
# ('tt0158833', 'Once We Were Strangers', 0)
# ('tt0155928', 'Oru Kaidhiyin Diary', 6)
# ('tt0293304', 'Kairee', 1)
# ('tt1501301', 'Morning Walk', 2)
# ('tt0484279', 'Miss India: The Mystery', 2)
# ('tt0268533', 'Phir Subha Hogi', 2)
# ('tt3160450', 'Ooops a Desi', 2)
# ('tt0271197', 'Snip!', 2)
# ('tt0296274', 'The Prince of Light', 0)
# ('tt0395519', 'Doodh Ka Karz', 2)
# ('tt0254437', 'Izzat', 2)
# ('tt0112916', 'Dushmani: A Violent Love Story', 2)
# ('tt0350195', 'Teri Meherbaniyan', 2)
# ('tt0118924', 'Dance of the Wind', 2)
# ('tt0382188', 'Mumbai Matinee', 0)
# ('tt2963042', 'Mahakali Ka Insaaf', 2)
# ('tt0380337', 'Ek Din 24 Ghante', 2)
# ('tt1502960', 'The Taste of Relation', 2)
# ('tt0156361', 'Bhootnath', 2)
# ('tt0398390', 'White Rainbow', 0)
# ('tt0353848', 'Ottran', 6)
# ('tt0438153', "Let's Enjoy", 0)
# ('tt0157729', 'Hamari Bahu Alka', 2)
# ('tt3477498', 'Masala Republic', 2)
# ('tt0158481', 'Bagh Bahadur', 17)
# ('tt0114618', 'Target', 2)
# ('tt0267524', 'Ghatotkachudu', 4)
# ('tt0089610', 'Mohabbat', 2)
# ('tt0269758', 'Raja Ki Ayegi Baraat', 2)
# ('tt0317214', 'Captain Prabhakaran', 6)
# ('tt0187351', 'Nigahen: Nagina Part II', 2)
# ('tt1582597', 'Sathyam', 4)
# ('tt1948047', 'Impatient Vivek', 2)
# ('tt1682931', 'Life! Camera Action...', 2)
# ('tt1668078', 'Daayen Ya Baayen', 2)
# ('tt1679290', 'Shuttlecock Boys', 2)
# ('tt2591508', 'Surkhaab', 2)
# ('tt1224454', 'Sirf....: Life Looks Greener on the Other Side', 2)
# ('tt2075376', 'Laadli Laila', 2)
# ('tt1391894', 'Siddharth: The Prisoner', 2)
# ('tt0461258', 'Kal: Yesterday and Tomorrow', 2)
# ('tt2917786', 'Thirupathi', 15)
# ('tt1087526', 'Tandoori Love', 30)
# ('tt1074201', "It's Breaking News", 2)
# ('tt0068929', 'Maya Darpan', 2)
# ('tt0319621', 'Kaadhal Parisu', 6)
# ('tt0843327', 'Boss', 4)
# ('tt0441303', 'Hei ma lai ah sing', 3)
# ('tt0257416', 'Ashwamedham', 4)
# ('tt1833008', 'Kvelaferi kargad iqneba', 31)
# ('tt1583363', 'Seema Simham', 4)
# ('tt1825655', 'Angel', 2)
# ('tt0055035', 'Junglee', 2)
# ('tt0363887', 'Phool Bane Angaarey', 2)
# ('tt0298327', 'Fakira', 2)
# ('tt0307116', 'Maa Tujhhe Salaam', 2)
# ('tt2356426', 'Le Halua Le', 2)
# ('tt8085616', 'Shohrat the Trap', 2)
# ('tt1773774', 'The Untitled Kartik Krishnan Project', 0)
# ('tt0245830', 'Chettaniki Kallu Levu', 4)
# ('tt0497606', 'Dansh', 2)
# ('tt2971560', 'Ram Raaj', 2)
# ('tt0098976', 'Aaj Ka Arjun', 2)
# ('tt0290632', 'Goa Dalli CID 999', 15)
# ('tt3445640', 'Military Officer', 2)
# ('tt4944394', 'Man on Mission Taqatwar', 2)
# ('tt0318607', 'Raasaiyya', 6)
# ('tt0432288', 'Finding Preet', 0)
# ('tt0106799', 'Ek Hi Raasta', 2)
# ('tt0273804', 'Mehndi', 2)
# ('tt0363011', 'Raja Aur Rangeeli', 2)
# ('tt0322816', 'Thoongathey Tambi Thoongathey', 4)
# ('tt0439464', 'Bewafa Sanam', 2)
# ('tt0165795', 'Geet Gaata Chal', 2)
# ('tt0090611', 'Allah-Rakha', 2)
# ('tt0106270', 'Anari', 2)
# ('tt0852989', 'Come December', 2)
# ('tt0375882', 'Kala Jigar', 2)
# ('tt0375890', 'Kanoon', 2)

# %%
def q16_grader(q16):
  result = pd.read_sql_query(q16, conn)
  return result
print(q16_grader(q16))
# Out:
#               title  year  LAID
# 0            Mowgli  2018     0
# 1     Ocean's Eight  2018     0
# 2       Tomb Raider  2018     0
# 3      The Avengers  2012     0
# 4           Tumbbad  2018     1
# ...             ...   ...   ...
# 3468    Allah-Rakha  1986     2
# 3469          Anari  1993     2
# 3470  Come December  2006     2
# 3471     Kala Jigar  1939     2
# 3472         Kanoon  1994     2
#
# [3473 rows x 3 columns]

# %% [markdown]
# ## 17. Write SQL query to list title, year and rating of malayalam movies in the database by doing an inner join with movie table and M_Language table with MID column, also assuming language ID of malayalam movies as 19

# %%
q17 = """SELECT M.title, M.year, M.rating
FROM Movie M
INNER JOIN M_Language ML ON M.MID = ML.MID
WHERE ML.LAID = 19
"""
cursor.execute(q17)
res17=cursor.fetchall()
for res in res17:
  print(res)
# Out:
# ('Dil Hai Betaab', '1993', 4.6)
# ('Chemmeen', '1965', 7.8)
# ('Aryan', '1988', 7.2)
# ('Kala Pani', '1996', 8.4)
# ('Aadupuliyattam', '2016', 4.2)
# ('New Delhi', '1987', 7.7)
# ('Who', 'I 2018', 7.1)
# ('Cover Story', '2000', 5.8)
# ('Vaishali', '1988', 7.7)
# ('Maanthrikam', '1995', 6.3)
# ('Abhimanyu', '1991', 7.1)
# ('Inspector Balram', '1991', 6.9)
# ('Satyameva Jayate', '2000', 5.3)
# ('Veettilekkulla Vazhi', '2011', 6.8)
# ('Alavuddinum Athbutha Vilakkum', '1979', 6.8)
# ('The Train', '2011', 4.5)

# %%
def q17_grader(q17):
  result = pd.read_sql_query(q17, conn)
  return result.shape==(16,3)
print(q17_grader(q17))
# Out:
# True

# %%
![ -f academic.db ] && rm academic.db

conn = sqlite3.connect("academic.db")
cursor = conn.cursor()

# %% [markdown]
# ## 18. Write SQL query to Create a table named students with two columns id (integer type) and name (varchar type)

# %%
q18a = "CREATE TABLE students (id INTEGER,name VARCHAR(100))"
cursor.execute(q18a)
conn.commit()

# %%
def q18_grader_a(q18):
  try:
    cursor.execute(q18)
    return True
  except:
    pass

def q18_grader_b(q19):
  result = pd.read_sql_query(q19, conn)
  return result.columns.tolist() == ['id', 'name']

q18b = """SELECT * FROM students;"""

print(q18_grader_a(q18a) and q18_grader_b(q18b))
# Out:
# True

# %% [markdown]
# ## 19. Write SQL query to insert the values (1, 'Alice') into students table

# %%
q19_a = "INSERT INTO students VALUES (1, 'Alice')"
cursor.execute(q19_a)

# %%
def q19_grader_a(q19_a):
  try:
    cursor.execute(q19_a)
  except:
    pass
  return True

def q19_grader_b(q19_b):
  result = pd.read_sql_query(q19_b, conn)
  return result.values.tolist() == [[1, 'Alice']]

q19_b = "SELECT * FROM students"
print(q19_grader_a(q19_a) and q19_grader_b(q19_b))
# Out:
# True

# %% [markdown]
# ## 20. Write SQL Query to add the following more information to students table
#
# | ID | Name    |
# |----|---------|
# | 2  | Bob     |
# | 3  | Charlie |

# %%
q20 = ("INSERT INTO students VALUES (2, 'Bob'),(3,'Charlie')")
cursor.execute(q20)

# %%
cursor.execute("select * from students")
print(cursor.fetchall())
# Out:
# [(1, 'Alice'), (2, 'Bob'), (3, 'Charlie')]

# %%
def q20_grader(q20):
  try:
    cursor.execute(q20)
  except:
    pass
  return True

def q20_grader_b(q20_b):
  result = pd.read_sql_query(q20_b, conn)
  return result.values.tolist() == [[1, 'Alice'], [2, 'Bob'], [3, 'Charlie']]

print(q20_grader(q20) and q20_grader_b(q19_b))
# Out:
# True

# %%
# conn.close()
